# %% [markdown]
# # Instal modul yang digunakan

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# pos_tagging
# !pip install python-crfsuite
# !pip install sklearn-pycrfsuite

# %% [markdown]
# # Import data & Cleaning dasar

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/RisetHibahPemerintah/alodokter_topik.csv')

# %%
df.dtypes
# Out:
# topik             object
# Title             object
# Question          object
# Question Date     object
# Answer            object
# Answer Date       object
# By Doctor         object
# Year             float64
# dtype: object

# %%
duplicates = df[df.duplicated()]
print(duplicates)
df = df.drop_duplicates()
# Out:
# Empty DataFrame
# Columns: [topik, Title, Question, Question Date, Answer, Answer Date, By Doctor, Year]
# Index: []

# %%
null_rows = df[df.isnull().any(axis=1)]
print(null_rows)
df = df.dropna().reset_index(drop=True)
# Out:
#                          topik  \
# 3975   gangguan kecemasan umum
# 5560   gangguan tidur berjalan
# 7010          kesehatan mental
# 11713                psikologi
#
#                                                    Title  \
# 3975   Cara untuk mengatasi rasa cemas dan takut di m...
# 5560   Tidur sambil berjalan disertai mata membuka da...
# 7010   Kenapa setiap ada orang yang  lewat depan ruma...
# 11713  Kenapa setiap ada orang yang  lewat depan ruma...
#
#                                                 Question  \
# 3975   Dok . Terkadang ketika malam mau tiba saya suk...
# 5560   Halo dok, saya berumur 11 tahun, saya menderit...
# 7010   siang dok saya berada di dalam rumah setiap ad...
# 11713  siang dok saya berada di dalam rumah setiap ad...
#
#               Question Date            Answer            Answer Date  \
# 3975   22 Maret 2018, 23:56  Answer not found  Answer date not found
# 5560   23 Maret 2018, 19:56  Answer not found  Answer date not found
# 7010    6 Maret 2019, 10:26  Answer not found  Answer date not found
# 11713   6 Maret 2019, 10:26  Answer not found  Answer date not found
#
#               By Doctor  Year
# 3975   Doctor not found   NaN
# 5560   Doctor not found   NaN
# 7010   Doctor not found   NaN
# 11713  Doctor not found   NaN

# %%
df = df.drop(columns=['Title', 'Question', 'Question Date', 'Answer Date', 'By Doctor'])
df['Year'] = df['Year'].astype(int)

# %%
df.head()
# Out:
#   topik                                             Answer  Year
# 0  adhd  Alo, selamat siang     Dari penjelasan anda, a...  2024
# 1  adhd  Alo, terimakasih atas pertanyaannya.          ...  2024
# 2  adhd  Alo, terimakasih atas pertanyaannya.          ...  2024
# 3  adhd  Alo, terimakasih atas pertanyaannya.          ...  2024
# 4  adhd  Alo, terimakasih atas pertanyaannya.          ...  2024

# %% [markdown]
# # menghapus karakter spesial

# %%
import re

# Melakukan case folding pada kolom 'Answer'
def remove_tweet_special (text):
  # menghapus angka dari kalimat
  hasil = re.sub(r"\d+", " ", text)

  # menghapus tanda baca dari text
  hasil = re.sub(r'[^\w\s]', ' ', hasil)

  # # menggabungkan karakter tertentu
  # hasil = re.sub(r'\s+k\s+e\s+', ' ke ', hasil)

  # Menghilangkan karakter tunggal
  hasil = re.sub(r"\b[a-zA-Z]\b", " ", hasil)

  # menghapus spasi berlebih di awal dan akhir
  hasil = hasil.strip()

  # Menghapus beberapa spasi menjadi satu spasi
  hasil = re.sub('\s+',' ',hasil)

  return hasil

df['Answer'] = df['Answer'].apply(remove_tweet_special)
df.head()
# Out:
#   topik                                             Answer  Year
# 0  adhd  Alo selamat siang Dari penjelasan anda anda me...  2024
# 1  adhd  Alo terimakasih atas pertanyaannya ADHD sering...  2024
# 2  adhd  Alo terimakasih atas pertanyaannya Sering mera...  2024
# 3  adhd  Alo terimakasih atas pertanyaannya Mudah gelis...  2024
# 4  adhd  Alo terimakasih atas pertanyaannya ADHD attent...  2024

# %% [markdown]
# # Casefolding

# %%
# Melakukan case folding pada kolom 'Answer'
def casefolding (text):
  # mengubah kalimat menjadi huruf kecil
  lower_case = text.lower()

  return lower_case

df['Answer'] = df['Answer'].apply(casefolding)
df.head()
# Out:
#   topik                                             Answer  Year
# 0  adhd  alo selamat siang dari penjelasan anda anda me...  2024
# 1  adhd  alo terimakasih atas pertanyaannya adhd sering...  2024
# 2  adhd  alo terimakasih atas pertanyaannya sering mera...  2024
# 3  adhd  alo terimakasih atas pertanyaannya mudah gelis...  2024
# 4  adhd  alo terimakasih atas pertanyaannya adhd attent...  2024

# %% [markdown]
# ### Intall swifter

# %%
# !pip install swifter
# Out:
# Collecting swifter
#   Downloading swifter-1.4.0.tar.gz (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 9.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (2.0.3)
# Requirement already satisfied: psutil>=5.6.6 in /usr/local/lib/python3.10/dist-packages (from swifter) (5.9.5)
# Requirement already satisfied: dask[dataframe]>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (2023.8.1)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (4.66.4)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (2023.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (24.1)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (8.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (1.25.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask[dataframe]>=2.10.0->swifter) (3.19.2)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=1.2.0->dask[dataframe]>=2.10.0->swifter) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->swifter) (1.16.0)
# Building wheels for collected packages: swifter
#   Building wheel for swifter (setup.py) ... done
#   Created wheel for swifter: filename=swifter-1.4.0-py3-none-any.whl size=16507 sha256=7ad1f1db988a9a7b497f5431960331e751b1423c36488c13ad3c4a8283c3fb00
#   Stored in directory: /root/.cache/pip/wheels/e4/cf/51/0904952972ee2c7aa3709437065278dc534ec1b8d2ad41b443
# Successfully built swifter
# Installing collected packages: swifter
# Successfully installed swifter-1.4.0

# %% [markdown]
# # Normalisasi teks

# %%
# Fungsi untuk membaca file normalization.txt dan membuat dictionary
def load_normalization_dict(file_path):
    normalization_dict = {}
    with open(file_path, 'r') as file:
        for line in file:
            key, value = line.strip().split(':')
            normalization_dict[key] = value
    return normalization_dict

# Fungsi untuk mengganti kata-kata dalam teks berdasarkan dictionary
def normalize_text(text, normalization_dict):
    words = text.split()
    normalized_words = []
    for word in words:
        # Ganti kata jika ada dalam kamus normalisasi
        if word in normalization_dict:
            normalized_words.append(normalization_dict[word])
        else:
            normalized_words.append(word)
    return ' '.join(normalized_words)

# Memuat dictionary normalisasi dari file
normalization_dict = load_normalization_dict('/content/drive/MyDrive/Colab Notebooks/RisetHibahPemerintah/normalisasi.txt')

# Normalisasi kolom 'Answer'
df['Normalized_Answer'] = df['Answer'].apply(lambda x: normalize_text(x, normalization_dict))
df['Normalized_Answer'] = df['Normalized_Answer'].apply(remove_tweet_special)

# # Tampilkan DataFrame setelah normalisasi
# print(df)

# %% [markdown]
# # Stop word

# %%
# Import library
import nltk
from nltk.corpus import stopwords
import string
import pandas as pd

# Pastikan untuk mengunduh stopwords dari NLTK
nltk.download('stopwords')

# Inisialisasi stop words dan tambahkan tanda baca sebagai stop words tambahan
stop_words = set(stopwords.words('indonesian')) | set(string.punctuation)

# ---------------------------- Baca stopword manual dari file txt  ------------------------------------
def read_manual_stopwords(file_path):
    with open(file_path, 'r') as file:
        manual_stopwords = file.read().splitlines()
    return set(manual_stopwords)

# Path ke file .txt yang berisi daftar kata-kata yang tidak diperlukan
manual_stopwords_file = '/content/drive/MyDrive/Colab Notebooks/RisetHibahPemerintah/manual_stopword.txt'

# Membaca daftar kata-kata yang tidak diperlukan dari file .txt
manual_stopwords = read_manual_stopwords(manual_stopwords_file)

# Tambahkan manual stopwords ke dalam stop_words
stop_words.update(manual_stopwords)

# Fungsi untuk menghapus stop words dari sebuah teks
def remove_stop_words(text):
    # Tokenisasi teks
    words = text.split()
    # Hapus stop words
    filtered_words = [word for word in words if word.lower() not in stop_words]
    # Gabungkan kembali kata-kata yang telah difilter menjadi sebuah string
    return ' '.join(filtered_words)

# Terapkan fungsi remove_stop_words pada kolom 'Answer'
df['Answer_sw'] = df['Normalized_Answer'].apply(remove_stop_words)
df['Answer_sw'] = df['Answer_sw'].apply(remove_tweet_special)

# Tampilkan DataFrame yang telah diubah
df[['Normalized_Answer','Answer_sw']].head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#                                    Normalized_Answer  \
# 0  alo selamat siang dari penjelasan anda anda me...
# 1  alo terimakasih atas pertanyaannya adhd sering...
# 2  alo terimakasih atas pertanyaannya sering mera...
# 3  alo terimakasih atas pertanyaannya mudah gelis...
# 4  alo terimakasih atas pertanyaannya adhd attent...
#
#                                            Answer_sw
# 0  penjelasan susah fokus susah fokus menandakan ...
# 1  pertanyaannya adhd gejalanya kisaran usia geja...
# 2  pertanyaannya cemas gugup tegang sulit konsent...
# 3  pertanyaannya mudah gelisah rungsing sulit fok...
# 4  pertanyaannya adhd attention deficit hyperacti...

# %% [markdown]
# # Tokenization

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize

# NLTK word tokenize
def word_tokenize_wrapper(text):
  return word_tokenize(text)

df['Answer_tkn'] = df['Answer_sw'].apply(word_tokenize_wrapper)
df[['Answer_sw','Answer_tkn']].head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#                                            Answer_sw  \
# 0  penjelasan susah fokus susah fokus menandakan ...
# 1  pertanyaannya adhd gejalanya kisaran usia geja...
# 2  pertanyaannya cemas gugup tegang sulit konsent...
# 3  pertanyaannya mudah gelisah rungsing sulit fok...
# 4  pertanyaannya adhd attention deficit hyperacti...
#
#                                           Answer_tkn
# 0  [penjelasan, susah, fokus, susah, fokus, menan...
# 1  [pertanyaannya, adhd, gejalanya, kisaran, usia...
# 2  [pertanyaannya, cemas, gugup, tegang, sulit, k...
# 3  [pertanyaannya, mudah, gelisah, rungsing, suli...
# 4  [pertanyaannya, adhd, attention, deficit, hype...

# %% [markdown]
# # Bigram

# %%
import nltk
from nltk import bigrams
from collections import Counter

# Pastikan nltk sudah mendownload data yang diperlukan
nltk.download('punkt')

# Membuat kolom baru untuk bigram
df['Bigrams'] = df['Answer_tkn'].apply(lambda x: list(bigrams(x)))

# Menggabungkan semua bigram ke dalam satu list
all_bigrams = [bigram for sublist in df['Bigrams'] for bigram in sublist]

# Menghitung frekuensi bigram
bigram_freq = Counter(all_bigrams)

# Menampilkan bigram yang paling umum
most_common_bigrams = bigram_freq.most_common(100)
most_common_bigrams
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [(('dokter', 'spesialis'), 4783),
#  (('gangguan', 'kecemasan'), 4447),
#  (('gangguan', 'mental'), 4369),
#  (('obat', 'obatan'), 3931),
#  (('gangguan', 'kejiwaan'), 3760),
#  (('gangguan', 'kepribadian'), 3744),
#  (('depresi', 'gangguan'), 3265),
#  (('dokter', 'psikiater'), 3123),
#  (('langsung', 'dokter'), 2855),
#  (('gangguan', 'bipolar'), 2836),
#  (('mengalami', 'gangguan'), 2465),
#  (('hidup', 'sehat'), 2422),
#  (('suasana', 'hati'), 2422),
#  (('berkonsultasi', 'dokter'), 2367),
#  (('aktivitas', 'sehari'), 2337),
#  (('gangguan', 'cemas'), 2334),
#  (('psikolog', 'psikiater'), 2301),
#  (('keluhan', 'alami'), 2143),
#  (('kesehatan', 'mental'), 2143),
#  (('gaya', 'hidup'), 2033),
#  (('kondisi', 'alami'), 1920),
#  (('pemeriksaan', 'fisik'), 1918),
#  (('pasca', 'trauma'), 1777),
#  (('spesialis', 'kejiwaan'), 1754),
#  (('serangan', 'panik'), 1716),
#  (('mengganggu', 'aktivitas'), 1713),
#  (('informasi', 'membantu'), 1678),
#  (('gejala', 'gejala'), 1656),
#  (('gangguan', 'stres'), 1650),
#  (('gangguan', 'kesehatan'), 1591),
#  (('stres', 'pasca'), 1586),
#  (('pemeriksaan', 'penunjang'), 1483),
#  (('bipolar', 'gangguan'), 1468),
#  (('dokter', 'dokter'), 1452),
#  (('efek', 'samping'), 1440),
#  (('berat', 'badan'), 1438),
#  (('kecemasan', 'gangguan'), 1344),
#  (('gangguan', 'tidur'), 1338),
#  (('gangguan', 'panik'), 1322),
#  (('sulit', 'tidur'), 1252),
#  (('gangguan', 'depresi'), 1250),
#  (('nafsu', 'makan'), 1241),
#  (('pola', 'hidup'), 1232),
#  (('psikiater', 'dokter'), 1223),
#  (('keluhan', 'keluhan'), 1202),
#  (('penyebab', 'keluhan'), 1177),
#  (('kondisi', 'gangguan'), 1167),
#  (('psikiater', 'psikolog'), 1165),
#  (('pemeriksaan', 'dokter'), 1156),
#  (('pemeriksaan', 'langsung'), 1151),
#  (('keluhan', 'rasakan'), 1137),
#  (('jiwa', 'psikiater'), 1126),
#  (('spesialis', 'jiwa'), 1098),
#  (('makan', 'makanan'), 1096),
#  (('disebabkan', 'gangguan'), 1053),
#  (('membantu', 'salam'), 1040),
#  (('trauma', 'gangguan'), 1023),
#  (('kejiwaan', 'gangguan'), 1000),
#  (('informasi', 'bermanfaat'), 998),
#  (('berpikir', 'positif'), 986),
#  (('penanganan', 'sesuai'), 968),
#  (('faktor', 'genetik'), 962),
#  (('pemberian', 'obat'), 958),
#  (('jantung', 'berdebar'), 949),
#  (('kegiatan', 'positif'), 942),
#  (('fisik', 'pemeriksaan'), 935),
#  (('kejiwaan', 'psikiater'), 935),
#  (('sakit', 'kepala'), 925),
#  (('makanan', 'bergizi'), 924),
#  (('memeriksakan', 'dokter'), 917),
#  (('putus', 'asa'), 908),
#  (('perasaan', 'sedih'), 903),
#  (('berkonsultasi', 'langsung'), 889),
#  (('gangguan', 'mood'), 888),
#  (('mengalami', 'depresi'), 878),
#  (('menyebabkan', 'gangguan'), 872),
#  (('mengelola', 'stres'), 872),
#  (('perubahan', 'suasana'), 861),
#  (('gangguan', 'psikologis'), 855),
#  (('berbeda', 'beda'), 844),
#  (('dokter', 'pemeriksaan'), 843),
#  (('gangguan', 'jiwa'), 842),
#  (('kehidupan', 'sehari'), 841),
#  (('gejala', 'gangguan'), 839),
#  (('sekian', 'informasi'), 829),
#  (('keluhan', 'muncul'), 820),
#  (('olahraga', 'teratur'), 809),
#  (('makanan', 'sehat'), 806),
#  (('pola', 'pikir'), 804),
#  (('berkonsultasi', 'psikiater'), 797),
#  (('mudah', 'lelah'), 796),
#  (('kondisi', 'medis'), 794),
#  (('konsumsi', 'makanan'), 793),
#  (('pikiran', 'negatif'), 789),
#  (('air', 'putih'), 787),
#  (('kesehatan', 'jiwa'), 786),
#  (('gangguan', 'skizoafektif'), 779),
#  (('gejala', 'depresi'), 774),
#  (('meditasi', 'yoga'), 771),
#  (('peristiwa', 'traumatis'), 753)]

# %%
df[['Answer_tkn','Bigrams']].head()
# Out:
#                                           Answer_tkn  \
# 0  [penjelasan, susah, fokus, susah, fokus, menan...
# 1  [pertanyaannya, adhd, gejalanya, kisaran, usia...
# 2  [pertanyaannya, cemas, gugup, tegang, sulit, k...
# 3  [pertanyaannya, mudah, gelisah, rungsing, suli...
# 4  [pertanyaannya, adhd, attention, deficit, hype...
#
#                                              Bigrams
# 0  [(penjelasan, susah), (susah, fokus), (fokus, ...
# 1  [(pertanyaannya, adhd), (adhd, gejalanya), (ge...
# 2  [(pertanyaannya, cemas), (cemas, gugup), (gugu...
# 3  [(pertanyaannya, mudah), (mudah, gelisah), (ge...
# 4  [(pertanyaannya, adhd), (adhd, attention), (at...

# %% [markdown]
# # Lemmatization

# %%
# !pip install Sastrawi
# !pip install PySastrawi
# Out:
# Collecting PySastrawi
#   Downloading PySastrawi-1.2.0-py2.py3-none-any.whl (210 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.6/210.6 kB 3.9 MB/s eta 0:00:00
# Installing collected packages: PySastrawi
# Successfully installed PySastrawi-1.2.0

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter
import pandas as pd

# Inisialisasi stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# Fungsi untuk stemming
def stemmed_wrapper(term):
    return stemmer.stem(term)

# Membuat kamus term
term_dict = {}

# Membentuk set dari semua term untuk menghindari duplikasi dan mengurangi jumlah iterasi
unique_terms = set()
for doc in df['Answer_tkn']:
    for term in doc:
        unique_terms.add(term)

# Melakukan stemming dengan swifter dan mengupdate term_dict
unique_terms = list(unique_terms)  # Konversi kembali ke list agar bisa digunakan dengan swifter
df_terms = pd.DataFrame(unique_terms, columns=['term'])
df_terms['stemmed'] = df_terms['term'].swifter.apply(stemmed_wrapper)

# Konversi kembali ke dictionary
term_dict = pd.Series(df_terms.stemmed.values, index=df_terms.term).to_dict()

# # Menampilkan hasil
# for term, stemmed in term_dict.items():
#     print(term, ":", stemmed)
#     print(len(term_dict))
#     print("------------------------")
# Out:
# Pandas Apply:   0%|          | 0/24723 [00:00<?, ?it/s]

# %%
# Fungsi untuk mendapatkan term yang telah di-stemming
def get_stemmed_term(doc):
    return [term_dict.get(term, term) for term in doc]

# Mengaplikasikan fungsi ke DataFrame
df['Answer_lemma'] = df['Answer_tkn'].apply(get_stemmed_term)

# Menampilkan hasil
df[['Answer_tkn', 'Answer_lemma']].head()
# Out:
#                                           Answer_tkn  \
# 0  [penjelasan, susah, fokus, susah, fokus, menan...
# 1  [pertanyaannya, adhd, gejalanya, kisaran, usia...
# 2  [pertanyaannya, cemas, gugup, tegang, sulit, k...
# 3  [pertanyaannya, mudah, gelisah, rungsing, suli...
# 4  [pertanyaannya, adhd, attention, deficit, hype...
#
#                                         Answer_lemma
# 0  [jelas, susah, fokus, susah, fokus, tanda, ala...
# 1  [tanya, adhd, gejala, kisar, usia, gejala, adh...
# 2  [tanya, cemas, gugup, tegang, sulit, konsentra...
# 3  [tanya, mudah, gelisah, rungsing, sulit, fokus...
# 4  [tanya, adhd, attention, deficit, hyperactivit...

# %% [markdown]
# ### Cleaning hasil lemma

# %%
# Buat kolom baru 'Answer_untoken' yang berisi teks yang telah diuntoken
df['Answer_lemma_cln'] = df['Answer_lemma'].apply(lambda tokens: ' '.join(tokens))

# normalisasi
df['Answer_lemma_cln'] = df['Answer_lemma_cln'].apply(lambda x: normalize_text(x, normalization_dict))
df['Answer_lemma_cln'] = df['Answer_lemma_cln'].apply(remove_tweet_special)

# stopword
df['Answer_lemma_cln'] = df['Answer_lemma_cln'].apply(remove_stop_words)
df['Answer_lemma_cln'] = df['Answer_lemma_cln'].apply(remove_tweet_special)

df['Answer_lemma_cln'] = df['Answer_lemma_cln'].apply(word_tokenize_wrapper)

# %%
df[['topik', 'Answer_lemma_cln']].head()
# Out:
#   topik                                   Answer_lemma_cln
# 0  adhd  [susah, fokus, susah, fokus, tanda, alami, adh...
# 1  adhd  [adhd, gejala, kisar, usia, gejala, adhd, taha...
# 2  adhd  [cemas, gugup, tegang, sulit, konsentrasi, mud...
# 3  adhd  [mudah, gelisah, rungsing, sulit, fokus, tanda...
# 4  adhd  [adhd, attention, deficit, hyperactivity, diso...

# %% [markdown]
# ### menghitung frekuensi kata

# %%
from collections import Counter
# Menghitung frekuensi kata-kata dalam kolom 'Answer_lemma_cln'
word_freq = Counter()
for tokens in df['Answer_lemma_cln']:
    word_freq.update(tokens)

# Konversi hasil Counter ke DataFrame untuk ditampilkan
word_freq_df = pd.DataFrame(list(word_freq.items()), columns=['Kata', 'Frekuensi'])

# Menampilkan hasil berdasarkan frekuensi tertinggi
word_freq_df.sort_values(by='Frekuensi', ascending=False, inplace=True)
word_freq_df
# Out:
#                  Kata  Frekuensi
# 7              ganggu      57049
# 40            kondisi      28632
# 3               alami      26042
# 41             dokter      26030
# 100             keluh      22173
# ...               ...        ...
# 11946  psikopatologis          1
# 11945         istiana          1
# 11944  keseharaiannya          1
# 11943         hidupya          1
# 15971    clomipramine          1
#
# [15972 rows x 2 columns]

# %%
# Filter kata-kata yang frekuensinya > 1500
filtered_words_df = word_freq_df[word_freq_df['Frekuensi'] > 1500]
filtered_words_df.head(10)
# Out:
#         Kata  Frekuensi
# 7     ganggu      57049
# 40   kondisi      28632
# 3      alami      26042
# 41    dokter      26030
# 100    keluh      22173
# 43   periksa      19126
# 82      obat      18567
# 38     bantu      16730
# 90     cemas      16549
# 46    gejala      15172

# %% [markdown]
# ### melihat kata-kata yang tidak umum muncul secara keseluruhan row data

# %%
# Menghitung frekuensi munculnya setiap kata di seluruh kolom 'Answer_lemma_cln'
all_tokens = [token for tokens in df['Answer_lemma_cln'] for token in tokens]
word_counts = Counter(all_tokens)

# Menyaring kata-kata yang frekuensinya kurang dari 5
rare_words = [word for word, count in word_counts.items() if count < 3]

# %%
rare_words
# Out:
# ['rungsing',
#  'edukatif',
#  'kehialng',
#  'sepertihitung',
#  'danmriotak',
#  'seesorang',
#  'sial',
#  'terutam',
#  'contognya',
#  'diperhintakan',
#  'mendapingi',
#  'elo',
#  'intruksi',
#  'mengahabiskan',
#  'meningaktkan',
#  'logiknya',
#  'deficithyperactivity',
#  'inklusif',
#  'dificit',
#  'rash',
#  'frozen',
#  'talkshow',
#  'maurha',
#  'note',
#  'kegiatn',
#  'bsdtalia',
#  'anakgejala',
#  'hiperaktifdan',
#  'huriyatul',
#  'honi',
#  'adh',
#  'penananganan',
#  'ajaka',
#  'haryati',
#  'priotitas',
#  'attentian',
#  'aran',
#  'keponaan',
#  'cd',
#  'tintin',
#  'aritmatiknya',
#  'pos',
#  'tutor',
#  'kalkulator',
#  'nailun',
#  'hilly',
#  'slcenderung',
#  'faldy',
#  'developmental',
#  'khya',
#  'unvoluntary',
#  'epidemiologi',
#  'elya',
#  'mustinya',
#  'tuh',
#  'ngeh',
#  'bagan',
#  'utisme',
#  'babbling',
#  'frase',
#  'kelimpungan',
#  'kejangggalam',
#  'anaksulit',
#  'iniberdampak',
#  'gelaja',
#  'mamass',
#  'maslaha',
#  'volunter',
#  'gait',
#  'hyperactivitu',
#  'geliat',
#  'anisah',
#  'mukulkan',
#  'furnitur',
#  'asar',
#  'bebicara',
#  'bilingual',
#  'definis',
#  'perhatiaj',
#  'najmi',
#  'dideritaya',
#  'dileksia',
#  'gunawandjoe',
#  'multifactor',
#  'neuro',
#  'adeknya',
#  'chachaicha',
#  'yahya',
#  'megonsultasikan',
#  'dominansi',
#  'junor',
#  'tersembut',
#  'jewer',
#  'tamtrum',
#  'suryanto',
#  'dapet',
#  'metilfenidat',
#  'dexametamin',
#  'lisdexamfetamin',
#  'mengung',
#  'memhamai',
#  'sry',
#  'attentiondeficithyperactivedisorder',
#  'dapatbicarakan',
#  'psekolah',
#  'stasi',
#  'selanjutnyua',
#  'mayolafhr',
#  'fisikm',
#  'andnarkolepsi',
#  'chewing',
#  'kapsul',
#  'gerus',
#  'suspensi',
#  'kocok',
#  'yanuar',
#  'ribat',
#  'belajr',
#  'zharfan',
#  'mika',
#  'adhdatau',
#  'tonus',
#  'toleh',
#  'florence',
#  'atttention',
#  'dissorders',
#  'neurobehaviour',
#  'impulsifitas',
#  'adhdpun',
#  'dollan',
#  'landau',
#  'kleffner',
#  'komprehensi',
#  'mitokondria',
#  'dispraksia',
#  'hiperactivity',
#  'muscular',
#  'distrofi',
#  'dexamfetamine',
#  'lisdexamfetamine',
#  'dexamphetamine',
#  'setiawati',
#  'disgrafia',
#  'reseptif',
#  'emosianya',
#  'yuchib',
#  'tahunanak',
#  'odokter',
#  'reaksai',
#  'aghi',
#  'lumuh',
#  'konsenstrasi',
#  'rachmaniah',
#  'deficits',
#  'elektroensefalogram',
#  'kale',
#  'fortifikasi',
#  'andrew',
#  'hiperaktivity',
#  'disampaika',
#  'bersosilaisasi',
#  'interupsi',
#  'dibuthkan',
#  'komperhensif',
#  'lengsung',
#  'semgoa',
#  'psikostimulan',
#  'malik',
#  'berlebihanm',
#  'ganglia',
#  'lakukann',
#  'permasalaha',
#  'tourett',
#  'falaila',
#  'inatentif',
#  'hiperaktifitasnya',
#  'herman',
#  'melajar',
#  'reterdasi',
#  'ekspektansi',
#  'imobilitas',
#  'neuropsikiatrik',
#  'uacapan',
#  'geleng',
#  'angguk',
#  'vocal',
#  'dehem',
#  'tourtte',
#  'optmal',
#  'menetahui',
#  'sitimarf',
#  'sensoriknya',
#  'agoraphbia',
#  'berekringat',
#  'kepalaa',
#  'thika',
#  'arip',
#  'mengggali',
#  'tertenetu',
#  'euthymia',
#  'menengangkan',
#  'kekal',
#  'berubahn',
#  'sautu',
#  'yanag',
#  'peceraian',
#  'psosedur',
#  'aktivis',
#  'speak',
#  'relaps',
#  'berkurnag',
#  'gnetik',
#  'perubahanmoodyang',
#  'andsocialrhythmtherapy',
#  'noni',
#  'psychastenia',
#  'diktehai',
#  'embak',
#  'komptensi',
#  'tugass',
#  'daffa',
#  'carbamazepine',
#  'colestiramine',
#  'phenytoin',
#  'lansoprazol',
#  'kindisi',
#  'sentra',
#  'pemicuny',
#  'mutifaktorial',
#  'lukas',
#  'rainny',
#  'mengolala',
#  'kehiduapan',
#  'sars',
#  'cov',
#  'merugaikan',
#  'lau',
#  'mengaruhi',
#  'eksentrik',
#  'elisabet',
#  'famakologi',
#  'antipiretik',
#  'untyuk',
#  'warfarin',
#  'carbamazepin',
#  'fenitoin',
#  'cholestyramine',
#  'imatinib',
#  'menurnkan',
#  'busulfan',
#  'metoclopramide',
#  'domperidone',
#  'probenecid',
#  'kendisi',
#  'pemikirna',
#  'penngobatan',
#  'melody',
#  'seragkaian',
#  'alva',
#  'rosalia',
#  'psychoeducation',
#  'urgent',
#  'sbb',
#  'melisha',
#  'taylor',
#  'gengguan',
#  'keyataan',
#  'sgera',
#  'demokratis',
#  'kyusyuk',
#  'komuniksi',
#  'sepertimengantuk',
#  'menjadisangat',
#  'emngatasi',
#  'emringankan',
#  'angelman',
#  'shermanita',
#  'konsumtif',
#  'ridhonya',
#  'kerika',
#  'empatu',
#  'emsoional',
#  'sesk',
#  'skizofrenuia',
#  'desktruktif',
#  'joulin',
#  'teratu',
#  'safaah',
#  'dingi',
#  'kelurag',
#  'soonie',
#  'pertnayaan',
#  'menaggapi',
#  'gerat',
#  'kis',
#  'dianyaranya',
#  'sskit',
#  'ceita',
#  'psikitiatri',
#  'elyani',
#  'seingga',
#  'cognitiive',
#  'terapy',
#  'daopat',
#  'neurotrasnmiter',
#  'dapattidak',
#  'bermaksu',
#  'depacote',
#  'seijin',
#  'perebdaan',
#  'aswagandha',
#  'leboh',
#  'ataulebih',
#  'tidakbiasanya',
#  'berikutnyayang',
#  'khaerunnisa',
#  'peneriksaan',
#  'menuntuk',
#  'illnes',
#  'tsebagai',
#  'lanjutdari',
#  'nadina',
#  'kepribadianya',
#  'berolaharaga',
#  'jd',
#  'kejadin',
#  'lerja',
#  'erupakan',
#  'lengkat',
#  'solusia',
#  'toksikologi',
#  'wisma',
#  'rany',
#  'wawancaraa',
#  'defngan',
#  'melatarbelalangi',
#  'indian',
#  'mngonsultasikan',
#  'gaby',
#  'anasta',
#  'althovina',
#  'produktivita',
#  'sevagai',
#  'adrenokortikotropik',
#  'acth',
#  'nay',
#  'kakakk',
#  'patria',
#  'teriamaksih',
#  'pemnghentian',
#  'menja',
#  'itirahat',
#  'rtuin',
#  'mengcari',
#  'diangap',
#  'ola',
#  'adaepisode',
#  'seperticognitive',
#  'fft',
#  'drastism',
#  'modd',
#  'rubianti',
#  'ruah',
#  'coca',
#  'daisuke',
#  'ceirakan',
#  'melotot',
#  'devxxx',
#  'memitikkan',
#  'becengkrama',
#  'shifa',
#  'beupa',
#  'mesnturasi',
#  'membauat',
#  'tsya',
#  'pn',
#  'thania',
#  'alfides',
#  'swalayan',
#  'acapkali',
#  'pasein',
#  'hinadri',
#  'ketaukatan',
#  'kegelisahn',
#  'kerumumnan',
#  'kebahagaiaan',
#  'deibantu',
#  'fengan',
#  'siri',
#  'niskat',
#  'fektif',
#  'mneganggu',
#  'dokters',
#  'reni',
#  'kejaidan',
#  'vrirus',
#  'kulalitas',
#  'berengeri',
#  'tersebutmaka',
#  'halk',
#  'lakukna',
#  'alrania',
#  'dopomine',
#  'berlebihandikaitkan',
#  'dangangguan',
#  'horomon',
#  'inda',
#  'denganmengasah',
#  'triani',
#  'meinda',
#  'dinrumah',
#  'dominasisifat',
#  'egomenguasai',
#  'maelakukan',
#  'perharitikan',
#  'seslalu',
#  'topitopik',
#  'sevcara',
#  'menunjakan',
#  'ygn',
#  'medy',
#  'ktiteria',
#  'aupin',
#  'pensatbil',
#  'fachry',
#  'polapikir',
#  'salling',
#  'sebelumhal',
#  'seandung',
#  'monica',
#  'andatermasuk',
#  'gilaloh',
#  'daapat',
#  'berbagilan',
#  'ervina',
#  'gambrakan',
#  'menecritakan',
#  'aurellivia',
#  'dissociativeidentity',
#  'rhal',
#  'sisrin',
#  'dengansuasana',
#  'ekstreim',
#  'beristirahan',
#  'anterograde',
#  'olivart',
#  'engonsumsi',
#  'menbutuhkan',
#  'penyakitbipolar',
#  'percerceraian',
#  'memkai',
#  'jude',
#  'tsmpak',
#  'sebaikbya',
#  'scarlett',
#  'premenstruation',
#  'meningkatkanrisiko',
#  'esti',
#  'emotionally',
#  'unstable',
#  'eupd',
#  'borderliner',
#  'dynamic',
#  'deconstructive',
#  'mununjukan',
#  'menetep',
#  'berkonsutasilah',
#  'cok',
#  'kejadina',
#  'mendiagnosakan',
#  'kosnutlasi',
#  'angkasa',
#  'menagis',
#  'sika',
#  'mixxy',
#  'membingunkan',
#  'menyebabkankeinginan',
#  'lizzy',
#  'aderianaputri',
#  'than',
#  'durota',
#  'hyuk',
#  'stevanie',
#  'drastid',
#  'ebrlebihan',
#  'bergantinmenjadi',
#  'pweasaan',
#  'ceciliaayaa',
#  'motivasisulit',
#  'stefanya',
#  'practice',
#  'biaaanya',
#  'dja',
#  'sizoafektif',
#  'melahit',
#  'melly',
#  'ryo',
#  'antidepresif',
#  'lakak',
#  'ronald',
#  'ambivalen',
#  'diringa',
#  'bini',
#  'akmalrisw',
#  'timba',
#  'neuroleptic',
#  'malignant',
#  'mungkinu',
#  'beeminggu',
#  'kau',
#  'datangani',
#  'nurohmah',
#  'girang',
#  'berikir',
#  'sertaperubahan',
#  'didandingkan',
#  'faseperalihan',
#  'danpenyesuaian',
#  'danpemecahan',
#  'berpengaruhpada',
#  'komitmenpenyelesaian',
#  'peljaran',
#  'tujuanpendidikan',
#  'terhadapprosespenyesuaian',
#  'kegitana',
#  'osis',
#  'jellyviss',
#  'mendak',
#  'yangvterkadang',
#  'terlapas',
#  'pengatuhi',
#  'beraktvitas',
#  'rhany',
#  'keluhankeluhan',
#  'piskosomatis',
#  'khan',
#  'drasti',
#  'defresif',
#  'ryushine',
#  'awkador',
#  'moodsebenarnya',
#  'elektromiogram',
#  'salisil',
#  'kalamin',
#  'iindrii',
#  'hanum',
#  'lauw',
#  'deva',
#  'drastisatau',
#  'depresiyaitu',
#  'aksis',
#  'syamsul',
#  'musabab',
#  'lesat',
#  'elevasi',
#  'psikiaer',
#  'rmrt',
#  'yobi',
#  'ibatan',
#  'segeralag',
#  'usuk',
#  'hamyung',
#  'os',
#  'organisaisi',
#  'abidatul',
#  'tryhexa',
#  'megatasi',
#  'olanzapin',
#  'pandangna',
#  'pskiologi',
#  'masalak',
#  'aegypti',
#  'perkembangbiakan',
#  'menraktir',
#  'band',
#  'shira',
#  'sakita',
#  'riana',
#  'annisah',
#  'salahsatu',
#  'stevani',
#  'ahirnya',
#  'melakuai',
#  'cuba',
#  'regulation',
#  'talktherapy',
#  'rhytm',
#  'renny',
#  'interasksi',
#  'shazrena',
#  'histrionic',
#  'defina',
#  'putrimega',
#  'pradani',
#  'septia',
#  'aras',
#  'fhitry',
#  'nipolar',
#  'charamel',
#  'nadifani',
#  'ketidakseragaman',
#  'pemberin',
#  'ariyani',
#  'schizoactive',
#  'pemicumya',
#  'akinari',
#  'berwelasasih',
#  'serakah',
#  'connia',
#  'fumei',
#  'skizotypal',
#  'berlakuk',
#  'putricalysta',
#  'thomas',
#  'kegemarananya',
#  'hipophrenia',
#  'edo',
#  'satrio',
#  'kaibat',
#  'distima',
#  'terhdao',
#  'niar',
#  'menifestasi',
#  'iyen',
#  'selanjunya',
#  'fitra',
#  'diantaraya',
#  'menkhayal',
#  'mendandak',
#  'elen',
#  'dianniv',
#  'ammonia',
#  'fiani',
#  'wisdar',
#  'tipa',
#  'hanafiah',
#  'dperesif',
#  'mengiuti',
#  'cutter',
#  'geledah',
#  'sebgian',
#  'belinda',
#  'nafi',
#  'berantas',
#  'mukenah',
#  'mukena',
#  'yaman',
#  'tasted',
#  'antidepressant',
#  'nyna',
#  'ninuh',
#  'menanganani',
#  'pendekatam',
#  'mambuat',
#  'persisi',
#  'soasana',
#  'lubuk',
#  'personaluty',
#  'mnegalaminya',
#  'tayeb',
#  'saffron',
#  'evalauasi',
#  'maulida',
#  'kemungkinannnya',
#  'tuberkulosa',
#  'bronkiektasis',
#  'dilatasi',
#  'etawa',
#  'carissa',
#  'kluster',
#  'ngucek',
#  'riskyamal',
#  'tatkala',
#  'grievers',
#  'diebut',
#  'terdapatdua',
#  'stabilizier',
#  'muram',
#  'mengeloal',
#  'miza',
#  'sepela',
#  'mentari',
#  'paramedis',
#  'rivia',
#  'charlene',
#  'trelihat',
#  'nicaahasna',
#  'arthur',
#  'skhizofren',
#  'nuntuk',
#  'juls',
#  'wardhani',
#  'valproa',
#  'lipid',
#  'hipesomnia',
#  'raf',
#  'andira',
#  'drahadi',
#  'supriyono',
#  'hypothyroid',
#  'hyperthyroid',
#  'chaca',
#  'hypoprenia',
#  'seigo',
#  'neurotrasmitter',
#  'sehungga',
#  'kotra',
#  'measa',
#  'kerta',
#  'atr',
#  'dengat',
#  'isal',
#  'sosialiasai',
#  'aditif',
#  'meyalahgunakan',
#  'denganmasalah',
#  'gembleng',
#  'pertanggungjawabannya',
#  'savela',
#  'safira',
#  'lero',
#  'bipoilar',
#  'imajunasi',
#  'sesuatubyang',
#  'riyorid',
#  'jun',
#  'pyo',
#  'beresdih',
#  'pisitif',
#  'sebananrnya',
#  'dapasty',
#  'ahlo',
#  'didampinngi',
#  'dejat',
#  'selfharming',
#  'aatu',
#  'beber',
#  'dinyakatan',
#  'dihadapin',
#  'bedoa',
#  'homron',
#  'betin',
#  'memicususah',
#  'coban',
#  'helikopter',
#  'mendalm',
#  'jangaka',
#  'produkstifitas',
#  'smiling',
#  'menyecewakan',
#  'perubahanmood',
#  'dikarenakaan',
#  'ybag',
#  'morfologi',
#  'driasakan',
#  'mengeskpersikan',
#  'kuis',
#  'dikonsusmi',
#  'wakatu',
#  'sulif',
#  'mengjungi',
#  'hingag',
#  'unspecified',
#  'dankehilangan',
#  'mematasi',
#  'dikasigi',
#  'segitu',
#  'perantra',
#  'pei',
#  'sepai',
#  'kedaan',
#  'trintimidasi',
#  'lecah',
#  'pelechan',
#  'psot',
#  'tarumatuc',
#  'saudarnya',
#  'terbaikl',
#  'mengcover',
#  'serebral',
#  'pramesty',
#  'misalnyagangguan',
#  'kecemasanatau',
#  'misalnyaobat',
#  'tiduratau',
#  'untukhipertensi',
#  'merasang',
#  'mengekpresikan',
#  'tifur',
#  'kanyatannya',
#  'masaah',
#  'purik',
#  'tropis',
#  'mnjauhi',
#  'penyembangan',
#  'windah',
#  'meruupakan',
#  'yga',
#  'fan',
#  'silaturrahim',
#  'tertetu',
#  'oror',
#  'ditabdai',
#  'membahayakn',
#  'mmebangun',
#  'joe',
#  'debby',
#  'termasuksaatmenghadapi',
#  'mungkinnadalah',
#  'makanyang',
#  'curthat',
#  'menyelsaikan',
#  'mngontrol',
#  'wajarjika',
#  'kapam',
#  'sasa',
#  'menjahuiorang',
#  'ulfah',
#  'ekstrenal',
#  'berlaurut',
#  'meninbulkan',
#  'berpikiralah',
#  'mencurhakan',
#  'stevia',
#  'cura',
#  'walaupin',
#  'febby',
#  'pembelajarn',
#  'prodi',
#  'bercetia',
#  'kusut',
#  'moodyang',
#  'sepertiberkurangnya',
#  'sehinggasaat',
#  'ramona',
#  'tolgen',
#  'perasaansedih',
#  'yaitumelihat',
#  'iswan',
#  'daja',
#  'cobalaah',
#  'lular',
#  'impact',
#  'autentik',
#  'antipdikotik',
#  'bermisuk',
#  'jk',
#  'terapkkan',
#  'stabiliser',
#  'zainura',
#  'saaj',
#  'sor',
#  'tsania',
#  'jesselyn',
#  'meghindari',
#  'lexotan',
#  'bromazepam',
#  'aminobutyric',
#  'grapefruit',
#  'saah',
#  'tendonitis',
#  'ahir',
#  'mengguiding',
#  'operatif',
#  'bidai',
#  'padahami',
#  'hububungan',
#  'ustadz',
#  'ustadzah',
#  'adniati',
#  'jernuh',
#  'aram',
#  'paripurna',
#  'bersukur',
#  'psikolosgi',
#  'berikutl',
#  'tenteu',
#  'depre',
#  'sadinor',
#  'dikatergorikan',
#  'adjustmens',
#  'christa',
#  'namnaya',
#  'halini',
#  'gangguandalam',
#  'laja',
#  'operational',
#  'hafi',
#  'jebi',
#  'premesntrual',
#  'ditumbulkan',
#  'ditimbulakan',
#  'bulutangkis',
#  'bowling',
#  'indry',
#  'bues',
#  'oja',
#  'azan',
#  'jurang',
#  'yaitumelakukan',
#  'dicetukan',
#  'alamidapat',
#  'termasukkedalam',
#  'ashy',
#  'oktha',
#  'representasi',
#  'komparasi',
#  'pangkas',
#  'concern',
#  'sponsor',
#  'piqi',
#  'christiin',
#  'lucretia',
#  'alohol',
#  'silahturahmi',
#  'pelrukan',
#  'afifah',
#  'kesehatanya',
#  'rendaha',
#  'ran',
#  'trumatis',
#  'mengonsunsi',
#  'sndiri',
#  'shavira',
#  'rosdiana',
#  'sebeum',
#  'mipir',
#  'terlbeih',
#  'deprisi',
#  'dansulit',
#  'mebdalam',
#  'menyndiri',
#  'kemungkunan',
#  'luamngkan',
#  'mnyenangkan',
#  'mempungaruhi',
#  'ditanagi',
#  'membebeni',
#  'mengikhklaskan',
#  'leingkungan',
#  'haldibawah',
#  'hidanri',
#  'cerlie',
#  'stage',
#  'moving',
#  'dyan',
#  'kekhatiran',
#  'mengujungidokter',
#  'munculkeluhan',
#  'berallkohol',
#  'terkaitkeluhan',
#  'lingkumngan',
#  'venesa',
#  'amaliah',
#  'riawayat',
#  'berpakaianan',
#  'memilikitingkatan',
#  'disesuain',
#  'tetanng',
#  'psikoterpai',
#  'tetang',
#  'deprresi',
#  'bermanfaatbagi',
#  'berkonsentrai',
#  'peimis',
#  'emndekatkan',
#  'len',
#  'alpha',
#  'pengunkapan',
#  'berkepnajangan',
#  'merupakanperubahan',
#  'terttu',
#  'menyikapiya',
#  'secaraa',
#  'elzha',
#  'julie',
#  'mempengarhui',
#  'essnsial',
#  'berolaharga',
#  'nurha',
#  'suana',
#  'cognitiv',
#  'berpa',
#  'keget',
#  'azanaldi',
#  'alfinningrum',
#  'karea',
#  'managamen',
#  'ebrbeda',
#  'emnyampaikan',
#  'tennag',
#  'maritsa',
#  'manisfestasi',
#  'naufal',
#  'cecil',
#  'maura',
#  'berkonsultsai',
#  'depresu',
#  'diantranta',
#  'bebeani',
#  ...]

# %%
# Menampilkan jumlah kata-kata yang langka
print("Jumlah kata-kata langka (rare words):", len(rare_words))
# Out:
# Jumlah kata-kata langka (rare words): 10319

# %%
sering_muncul = [word for word, count in word_counts.items() if count > 10000]
print("Jumlah kata-kata yang terlalu sering muncul:", len(sering_muncul))
# Out:
# Jumlah kata-kata yang terlalu sering muncul: 20

# %%
sering_muncul
# Out:
# ['alami',
#  'aktivitas',
#  'ganggu',
#  'laku',
#  'pikir',
#  'bantu',
#  'konsultasi',
#  'kondisi',
#  'dokter',
#  'periksa',
#  'gejala',
#  'psikiater',
#  'obat',
#  'cemas',
#  'keluh',
#  'hidup',
#  'sehat',
#  'jiwa',
#  'sakit',
#  'depresi']

# %% [markdown]
# ### Cleaning hasil lemma2

# %%
# Konversi rare_words menjadi set untuk efisiensi
rare_words_set = set(rare_words)

# Fungsi untuk melakukan stop word terhadap kolom 'Answer_fix'
def stop_words_rare_word(text, stop_words_set):
    tokens = text.split()
    filtered_tokens = [token for token in tokens if token not in stop_words_set]
    return ' '.join(filtered_tokens)

# %%
# Buat kolom baru 'Answer_untoken' yang berisi teks yang telah diuntoken
df['Answer_fix'] = df['Answer_lemma_cln'].apply(lambda tokens: ' '.join(tokens))

# Terapkan fungsi stop_words_rare_word ke kolom 'Answer_fix'
df['Answer_fix'] = df['Answer_fix'].apply(stop_words_rare_word, stop_words_set=rare_words_set)
df['Answer_fix'] = df['Answer_fix'].apply(remove_tweet_special)

df['Answer_fix'] = df['Answer_fix'].apply(word_tokenize_wrapper)

# %%
from collections import Counter
# Menghitung frekuensi kata-kata dalam kolom 'Answer_fix'
word_freq = Counter()
for tokens in df['Answer_fix']:
    word_freq.update(tokens)

# Konversi hasil Counter ke DataFrame untuk ditampilkan
word_freq_df = pd.DataFrame(list(word_freq.items()), columns=['Kata', 'Frekuensi'])

# Menampilkan hasil berdasarkan frekuensi tertinggi
word_freq_df.sort_values(by='Frekuensi', ascending=False, inplace=True)
print("frekuensi kata dalam dataset sekarang adalah: ",len(word_freq_df))
# Out:
# frekuensi kata dalam dataset sekarang adalah:  5653

# %%
df['Answer_fix'].head()
# Out:
# 0    [susah, fokus, susah, fokus, tanda, alami, adh...
# 1    [adhd, gejala, kisar, usia, gejala, adhd, taha...
# 2    [cemas, gugup, tegang, sulit, konsentrasi, mud...
# 3    [mudah, gelisah, sulit, fokus, tanda, alami, a...
# 4    [adhd, attention, deficit, hyperactivity, diso...
# Name: Answer_fix, dtype: object

# %% [markdown]
# # POS tagging

# %%
import pycrfsuite
import pandas as pd
from nltk import word_tokenize
from nltk.tag import CRFTagger

# Membuat objek CRFTagger
ct = CRFTagger()

# Menetapkan model yang sudah dilatih
ct.set_model_file('/content/drive/MyDrive/Colab Notebooks/RisetHibahPemerintah/all_indo_man_tag_corpus_model.crf.tagger')

# %%
pos_tagged_lemma = ct.tag_sents(df.Answer_fix)
df['POS'] = pos_tagged_lemma

# %%
df[['Answer_fix','POS']].head()
# Out:
#                                           Answer_fix  \
# 0  [susah, fokus, susah, fokus, tanda, alami, adh...
# 1  [adhd, gejala, kisar, usia, gejala, adhd, taha...
# 2  [cemas, gugup, tegang, sulit, konsentrasi, mud...
# 3  [mudah, gelisah, sulit, fokus, tanda, alami, a...
# 4  [adhd, attention, deficit, hyperactivity, diso...
#
#                                                  POS
# 0  [(susah, VB), (fokus, NN), (susah, NN), (fokus...
# 1  [(adhd, NN), (gejala, NN), (kisar, NN), (usia,...
# 2  [(cemas, NN), (gugup, NN), (tegang, NN), (suli...
# 3  [(mudah, JJ), (gelisah, VB), (sulit, JJ), (fok...
# 4  [(adhd, FW), (attention, FW), (deficit, FW), (...

# %%
# Fungsi untuk mencari kata-kata berdasarkan setiap jenis kode tag POS
def find_words_by_pos(df):
    pos_tags = set()
    words_by_pos = {}

    # Iterasi melalui setiap baris data
    for tags in df['POS']:
        for word, pos in tags:
            if pos not in words_by_pos:
                words_by_pos[pos] = set()
            words_by_pos[pos].add(word)
            pos_tags.add(pos)

    return words_by_pos

# Memanggil fungsi untuk mencari kata-kata berdasarkan setiap jenis kode tag POS
words_by_pos = find_words_by_pos(df)

# Menampilkan kata-kata untuk setiap jenis kode tag POS
for pos, words in words_by_pos.items():
    print(f"Kata-kata dengan tag POS '{pos}':")
    print(words)
    print()
# Out:
# Kata-kata dengan tag POS 'VB':
# {'simpati', 'urut', 'chat', 'sembuh', 'globus', 'kosong', 'indikasi', 'selesai', 'famili', 'pulang', 'tidur', 'saji', 'duda', 'bayang', 'lampias', 'rajut', 'telunjuk', 'masak', 'effect', 'santa', 'gegabah', 'pacar', 'badut', 'junjung', 'klarifikasi', 'sifat', 'hidung', 'saudari', 'tabrak', 'akut', 'campur', 'terang', 'hampar', 'psikotropika', 'legal', 'sedot', 'tikai', 'mendung', 'racau', 'rapi', 'residual', 'pipis', 'sejajar', 'emosi', 'memcoba', 'asosiasi', 'semprot', 'tata', 'angkuh', 'daun', 'kedut', 'embus', 'rebus', 'tunggu', 'intip', 'habis', 'rindu', 'panggung', 'abadi', 'psikopati', 'hilang', 'kenal', 'gerbong', 'abai', 'sampo', 'lendir', 'semangat', 'anamnesis', 'prima', 'konsul', 'tang', 'urung', 'aseksual', 'bunuh', 'suhu', 'textbook', 'main', 'terkam', 'subur', 'stop', 'wasir', 'pantang', 'bercak', 'piki', 'kalah', 'spesialis', 'rurut', 'keruh', 'jalar', 'aktivitias', 'muda', 'tutup', 'pisang', 'bawang', 'beda', 'mag', 'unggul', 'delusional', 'cegah', 'ponak
rutin', 'ability', 'spasme', 'paru', 'our', 'adik', 'dara', 'stimulating', 'drug', 'sklerosis', 'homo', 'off', 'medis', 'arthritis', 'jerawat', 'kursus', 'karet', 'hole', 'tanda', 'attention', 'skleroderma', 'simpul', 'cek', 'chronic', 'daydream', 'fidget', 'fetoskop', 'uring', 'feel', 'trauma', 'hasil', 'celiac', 'try', 'traumatic', 'negatif', 'displacement', 'group', 'gumam', 'movement', 'caffeine', 'porno', 'expert', 'timbun', 'schizoid', 'supporting', 'hak', 'several', 'sikap', 'persisten', 'dokter', 'star', 'vaskular', 'kromosom', 'tua', 'daring', 'medical', 'benzodiazepin', 'talk', 'proton', 'desensitization', 'klaster', 'condition', 'autistic', 'alergi', 'paralysis', 'smartphone', 'bedak', 'illness', 'schedule', 'healing', 'mirtazapine', 'pesek', 'buruk', 'liter', 'obsesive', 'cognitif', 'lahir', 'refluks', 'ringan', 'brother', 'behaviour', 'under', 'wujud', 'bicara', 'bersin', 'avoidance', 'feses', 'abilify', 'miring', 'stressor', 'space', 'minggu', 'jahe', 'libat', 'kendali', 'bsessive', 'irritable', 'duka', 'polycystic', 'maling', 'spinner', 'changing', 'kancing', 'up', 'yant', 'sociopath', 'vms', 'joging', 'fright', 'paranoid', 'ular', 'biar', 'jurnal', 'terror', 'sosok', 'permen', 'odgj', 'tegang', 'philophobia' ...
#
# Kata-kata dengan tag POS 'CC':
# {'perihal', 'merta', 'pantau', 'lamun', 'fisioterapi', 'autoimun', 'radioterapi', 'kemoterapi', 'sapi', 'terapi', 'rantau', 'talu', 'malu', 'umun', 'piskoterapi', 'hipnoterapi', 'psikiterapi', 'psikoterapi', 'imun', 'rapi', 'aromaterapi', 'kerumun', 'farmakoterapi'}
#
# Kata-kata dengan tag POS 'X':
# {'pasca', 'drastic', 'multi', 'motoric', 'lithromantic', 'karakteristik', 'genetic', 'traumatic'}
#
# Kata-kata dengan tag POS 'CD':
# {'persen', 'tujuh', 'khalayak', 'ikhtiar', 'luluh', 'sosiopat', 'psikopat', 'aroma', 'pensiun', 'capa', 'buluh', 'suruh', 'sepatu', 'dosen', 'paruh', 'olah', 'ataua', 'akua', 'butuh', 'batu', 'senam', 'delapan', 'siar', 'biar', 'suluh', 'juta', 'bimbing', 'bangun', 'curiga', 'keruh', 'tua', 'betapa', 'gelap', 'sakit', 'tanam', 'kol', 'prima', 'ratu', 'keluh', 'enam', 'buta', 'luruh', 'ribu', 'absen', 'layak', 'sapa', 'gelas', 'ratus', 'asupan', 'familiar', 'minyak', 'kelapa', 'nyenyak', 'taruh', 'puluh', 'sungguh', 'mayoritas', 'orangtua'}
#
# Kata-kata dengan tag POS 'NND':
# {'alter', 'liter', 'rendam', 'kuah', 'manis', 'telfon', 'gali', 'ulang', 'belah', 'anxiety', 'sang', 'psikolog', 'kg', 'oceh', 'kali', 'dbd', 'kaki', 'seringkali', 'hormon', 'dokter', 'adhd', 'psikiater', 'debar', 'otoriter', 'imbang', 'sebar', 'tenang', 'deg', 'lembar', 'jarang', 'barangkali', 'odgj', 'mood', 'ptsd', 'jenis', 'sabar', 'ton', 'karakter', 'mg', 'tips', 'parkinson', 'tonton', 'kembar', 'meter', 'gerd', 'mag', 'buah', 'kecuali', 'msg', 'cuci', 'toxic', 'bpd', 'ancam'}
#
# Kata-kata dengan tag POS 'SC':
# {'nerka', 'gapai', 'cerna', 'akrab', 'malapetaka', 'lampau', 'henti', 'sangga', 'sugar', 'sauna', 'amerika', 'kecewa', 'sempurna', 'eropa', 'dengar', 'narkotika', 'kantuk', 'nila', 'kendati', 'situ', 'galau', 'hermalina', 'ketawa', 'bela', 'silau', 'bab', 'marijuana', 'langgar', 'dewa', 'bina', 'kena', 'afrika', 'yoga', 'ngantuk', 'igau', 'mega', 'lembab', 'gitu', 'sila', 'semena', 'problematika', 'ampun', 'gila', 'berkah', 'akrena', 'hela', 'sederhana', 'bijaksana', 'psikotropika', 'logika', 'ketuk', 'bb', 'lupa', 'segar', 'alangkah', 'tika', 'vagina', 'hina', 'harimau', 'bangga', 'nikah', 'chikka', 'capa', 'rela', 'hirau', 'sarana', 'cika', 'celana', 'tertawa', 'celaka', 'antuk', 'stamina', 'etika', 'angina', 'psikofarmaka', 'asusila', 'suasana', 'laksana', 'batuk', 'sapa', 'bugar', 'tingkah', 'terka', 'kelapa', 'longgar', 'kadangkala', 'sosila', 'dinamika', 'gulana', 'capai', 'fenomena', 'lelah', 'ganti', 'tangga', 'maklum', 'warna', 'rongga', 'tuna', 'aritmatika', 'pustaka', 'kacau', 'beliau', 'serangga', 'pidana', 'metika', 'karantina', 'retina', 'betapa', 'tegar', 'matematika', 'lega', 'pandemi', 'terpa', 'puspa', 'tatalaksana'}
#
# Kata-kata dengan tag POS 'PRP':
# {'manda', 'spasmofilia', 'gurita', 'ganda', 'alami', 'maya', 'euthanasia', 'tunagrahita', 'via', 'sedia', 'lepidopterophobia', 'pedofilia', 'sia', 'bahagia', 'fibromyalgia', 'akathisia', 'distimia', 'cita', 'realita', 'derita', 'suami', 'parafilia', 'cerita', 'wijaya', 'boneka', 'miopia', 'echolalia', 'thalassophobia', 'peka', 'thanatophobia', 'phantosmia', 'benda', 'agoraphobia', 'tunda', 'osmophobia', 'dispepsia', 'paranoia', 'aniaya', 'nyctophobia', 'philophobia', 'onychophagia', 'bunda', 'fobia', 'bahaya', 'fonofobia', 'gamophobia', 'anemia', 'phonophobia', 'hipoglikemia', 'anoreksia', 'teka', 'phobia', 'mulia', 'amnesia', 'lansia', 'necrophilia', 'aneka', 'enochlophobia', 'bulimia', 'neuralgia', 'sita', 'demensia', 'agorafobia', 'siklotimia', 'diskalkulia', 'myalgia', 'theresia'}
#
# Kata-kata dengan tag POS 'NEG':
# {'non', 'mohon', 'tindak', 'hormon', 'tonton', 'dadak', 'sedak', 'bak', 'pundak', 'ledak', 'bedak'}
#
# Kata-kata dengan tag POS 'IN':
# {'pain', 'urut', 'main', 'ekstrakurikuler', 'handphone', 'ketimbang', 'silam', 'sangga', 'ajak', 'tama', 'rurut', 'datar', 'jari', 'cari', 'hama', 'kerut', 'perangai', 'strain', 'remeh', 'lada', 'desain', 'daftar', 'nada', 'hadap', 'migrain', 'drama', 'kena', 'oceh', 'komentar', 'bangkrut', 'star', 'irama', 'saudari', 'teh', 'semenjak', 'alprazolam', 'kelam', 'erti', 'sertraline', 'fluoxetine', 'pratama', 'tunai', 'hantar', 'bangga', 'dada', 'waspada', 'lontar', 'lantar', 'mama', 'rada', 'tari', 'putar', 'salam', 'brain', 'psikietar', 'depressive', 'parut', 'pintar', 'kokain', 'larut', 'kain', 'bercengkrama', 'sedap', 'bijak', 'tangga', 'rongga', 'sebentar', 'perut', 'picsstar', 'leceh', 'serangga', 'selagi', 'idap', 'tiada', 'endap', 'earphone', 'getar', 'surut', 'risperidone', 'pandemi', 'telantar', 'menegnai', 'latar', 'gemetar'}
#
# Kata-kata dengan tag POS 'NNP':
# {'vagina', 'hepatitis', 'hina', 'euthanasia', 'second', 'bully', 'porno', 'skizofrenia', 'pedofilia', 'bahagia', 'hiv', 'noradrenalin', 'dibully', 'serotonin', 'fibromyalgia', 'mohon', 'skizoid', 'hormon', 'manusiawi', 'insulin', 'parafilia', 'body', 'mania', 'kdrt', 'paranoid', 'hamil', 'adrenalin', 'jalin', 'karantina', 'stamina', 'pleura', 'pedoman', 'agoraphobia', 'repot', 'valentino', 'mood', 'nonton', 'info', 'ptsd', 'fobia', 'indonesia', 'pura', 'tv', 'bahasa', 'prasetyo', 'tonton', 'janin', 'ganggu', 'mulia', 'pneumothorax', 'enochlophobia', 'gerd', 'hpv', 'agalmatofilia', 'jahe', 'nekrofilia', 'demensia', 'ppdgj', 'agorafobia', 'inggris', 'cctv', 'theresia'}
#
# Kata-kata dengan tag POS 'MD':
# {'raih', 'paru', 'silah', 'sosiopat', 'psikopat', 'lelah', 'ibadah', 'lengah', 'kemih', 'lampau', 'lompat', 'sisih', 'oceh', 'umpat', 'pilah', 'lurus', 'ranah', 'olah', 'sedih', 'tiru', 'annisa', 'asih', 'analisa', 'faedah', 'gelisah', 'leceh', 'ulu', 'ludah', 'beliau', 'wadah', 'susah', 'mesti', 'pindah', 'bedah', 'sakit', 'teh', 'gundah', 'lidah', 'urus', 'tidah', 'muntah', 'rakit', 'majalah', 'risih', 'begah', 'remeh', 'haru', 'flu', 'indah', 'benah', 'simpat', 'perih', 'cegah', 'selisih', 'udah'}
#
# Kata-kata dengan tag POS 'OD':
# {'lahir', 'curiga'}
#
# Kata-kata dengan tag POS 'WH':
# {'sapa', 'sederhana', 'lupa', 'nikah', 'terpa', 'eropa', 'puspa', 'capa'}

# %% [markdown]
# # Simpan df

# %%
# # Simpan DataFrame
# df.to_csv('data_preprocessing.csv', index=False)
# df.to_excel('data_preprocessing.xlsx', index=False)

# %%
data_bersih = df[['topik','Answer','Year','Answer_fix']].copy()
data_bersih.to_csv('/content/drive/MyDrive/Colab Notebooks/RisetHibahPemerintah/data_fix.csv', index=False)
# data_bersih.to_excel('data_fix.xlsx', index=False)
