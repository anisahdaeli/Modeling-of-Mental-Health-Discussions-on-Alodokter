# %% [markdown]
# # Load Data

# %%
import pandas as pd
import numpy as np

# Definisikan path file
path = '/content/drive/MyDrive/Colab Notebooks/RisetHibahPemerintah/Eksperimen - Klasifikasi Teks/'

data = pd.read_csv(path + 'datamodel_klasifikasi_clean.csv')
df = data[['Answer_fix', 'topik']].copy()

# %%
df['Answer_fix'] = df['Answer_fix'].apply(eval)  # Konversi string list ke list

# %%
df.head()
# Out:
#                                           Answer_fix    topik
# 0  [insomnia, sakit, gejala, sakit, sakit, mental...  depresi
# 1  [asa, debar, debar, irama, jantung, atur, otot...    stres
# 2  [paham, asa, anak, tua, cerai, mudah, terkadan...  depresi
# 3  [maria, prihatin, kondisi, alami, pengaruh, am...  depresi
# 4  [depresi, bentuk, mental, perhati, masyarakat,...  depresi

# %%
from sklearn.feature_extraction.text import CountVectorizer

bow_vectorizer = CountVectorizer(analyzer=lambda x: x, token_pattern=None, max_features=100)
X_bow = bow_vectorizer.fit_transform(df['Answer_fix'])

# setting data
nama_ekstraksi = 'X_bow'
fitur = X_bow
y = df['topik']

# %% [markdown]
# # import modul

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn.neural_network import MLPClassifier
import json
import nltk

# Pastikan nltk sudah terinstall
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from sklearn.model_selection import cross_val_predict

# %%
# !pip install sklearn-genetic-opt
# Out:
# Collecting sklearn-genetic-opt
#   Downloading sklearn_genetic_opt-0.11.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: scikit-learn>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from sklearn-genetic-opt) (1.5.2)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from sklearn-genetic-opt) (1.26.4)
# Collecting deap>=1.3.3 (from sklearn-genetic-opt)
#   Downloading deap-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: tqdm>=4.61.1 in /usr/local/lib/python3.10/dist-packages (from sklearn-genetic-opt) (4.66.5)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.0->sklearn-genetic-opt) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.0->sklearn-genetic-opt) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.0->sklearn-genetic-opt) (3.5.0)
# Downloading sklearn_genetic_opt-0.11.1-py3-none-any.whl (35 kB)
# Downloading deap-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.4/135.4 kB 2.8 MB/s eta 0:00:00
# Installing collected packages: deap, sklearn-genetic-opt
# Successfully installed deap-1.4.1 sklearn-genetic-opt-0.11.1

# %%
from sklearn_genetic import GASearchCV
from sklearn_genetic.space import Categorical, Integer, Continuous

# %%
import joblib
import os
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="sklearn_genetic")

# Ganti backend joblib
joblib.parallel_backend('threading')

# Setel variabel lingkungan untuk joblib
os.environ['JOBLIB_TEMP_FOLDER'] = '/tmp'
os.environ['JOBLIB_PARALLEL_BACKEND'] = 'threading'

# %% [markdown]
# # BC SplitV modelling

# %%
# Define models
models = {
    'Naive Bayes': MultinomialNB(alpha=0.1),
    'KNN': KNeighborsClassifier(n_neighbors=10, weights='distance', algorithm='auto', p=2),
    'Random Forest': RandomForestClassifier(n_estimators=100, max_depth=15, min_samples_split=5, min_samples_leaf=2, bootstrap=True),
    'Neural Network': MLPClassifier(hidden_layer_sizes=(100, 50), activation='relu', solver='adam', learning_rate='adaptive', max_iter=1000, early_stopping=True, n_iter_no_change=5)
}

# Bagging classifier
optimasi = 'BC optimization'
def get_bagging_clf(base_estimator):
    return BaggingClassifier(estimator=base_estimator, n_estimators=10, random_state=42, n_jobs=-1)

# %%
# Define split ratios
splits = [(0.6, 0.4), (0.7, 0.3), (0.8, 0.2), (0.9, 0.1)]

# Initialize results dictionary
results = {}

for train_size, test_size in splits:
    print(f'Processing split {int(train_size*100)}:{int(test_size*100)}')

    # Split data
    X_train, X_test, y_train, y_test = train_test_split(fitur, y, test_size=test_size, random_state=42)

    for model_name, model in models.items():
        print(f'  Training {model_name} with Bagging Classifier')

        # Create Bagging Classifier with the current model
        bagging_clf = get_bagging_clf(model)
        bagging_clf.fit(X_train, y_train)
        y_pred = bagging_clf.predict(X_test)

        # Evaluation
        conf_matrix = confusion_matrix(y_test, y_pred)
        class_report = classification_report(y_test, y_pred, output_dict=True, zero_division=0)
        accuracy = accuracy_score(y_test, y_pred)

        # Convert tuple key to string
        result_key = f"{model_name}_{optimasi}_split {int(train_size*100)}:{int(test_size*100)}"

        # Save results
        results[result_key] = {
            'confusion_matrix': conf_matrix.tolist(),
            'classification_report': class_report,
            'accuracy': accuracy
        }

        print(f'    Accuracy: {accuracy:.4f}')
        print('    Classification Report:')
        print(classification_report(y_test, y_pred, zero_division=0))

# Save results to a JSON file
with open(path + f'{nama_ekstraksi}_bc_sv_experiment_results.json', 'w') as f:
    json.dump(results, f, indent=4)
# Out:
# Processing split 60:40
#   Training Naive Bayes with Bagging Classifier
#     Accuracy: 0.7631
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.76      0.69      0.73       397
#      depresi       0.76      0.84      0.80       591
#        stres       0.77      0.73      0.75       506
#
#     accuracy                           0.76      1494
#    macro avg       0.76      0.75      0.76      1494
# weighted avg       0.76      0.76      0.76      1494
#
#   Training KNN with Bagging Classifier
#     Accuracy: 0.7456
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.76      0.64      0.70       397
#      depresi       0.74      0.83      0.78       591
#        stres       0.75      0.73      0.74       506
#
#     accuracy                           0.75      1494
#    macro avg       0.75      0.73      0.74      1494
# weighted avg       0.75      0.75      0.74      1494
#
#   Training Random Forest with Bagging Classifier
#     Accuracy: 0.8179
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.83      0.75      0.79       397
#      depresi       0.80      0.90      0.85       591
#        stres       0.83      0.78      0.80       506
#
#     accuracy                           0.82      1494
#    macro avg       0.82      0.81      0.81      1494
# weighted avg       0.82      0.82      0.82      1494
#
#   Training Neural Network with Bagging Classifier
#     Accuracy: 0.8052
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.79      0.76      0.77       397
#      depresi       0.82      0.84      0.83       591
#        stres       0.79      0.80      0.80       506
#
#     accuracy                           0.81      1494
#    macro avg       0.80      0.80      0.80      1494
# weighted avg       0.80      0.81      0.80      1494
#
# Processing split 70:30
#   Training Naive Bayes with Bagging Classifier
#     Accuracy: 0.7618
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.76      0.68      0.72       304
#      depresi       0.75      0.83      0.79       439
#        stres       0.78      0.75      0.76       378
#
#     accuracy                           0.76      1121
#    macro avg       0.76      0.75      0.76      1121
# weighted avg       0.76      0.76      0.76      1121
#
#   Training KNN with Bagging Classifier
#     Accuracy: 0.7360
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.74      0.66      0.70       304
#      depresi       0.72      0.80      0.76       439
#        stres       0.75      0.73      0.74       378
#
#     accuracy                           0.74      1121
#    macro avg       0.74      0.73      0.73      1121
# weighted avg       0.74      0.74      0.73      1121
#
#   Training Random Forest with Bagging Classifier
#     Accuracy: 0.8109
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.81      0.75      0.78       304
#      depresi       0.81      0.88      0.84       439
#        stres       0.81      0.79      0.80       378
#
#     accuracy                           0.81      1121
#    macro avg       0.81      0.80      0.81      1121
# weighted avg       0.81      0.81      0.81      1121
#
#   Training Neural Network with Bagging Classifier
#     Accuracy: 0.8046
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.78      0.76      0.77       304
#      depresi       0.83      0.83      0.83       439
#        stres       0.79      0.81      0.80       378
#
#     accuracy                           0.80      1121
#    macro avg       0.80      0.80      0.80      1121
# weighted avg       0.80      0.80      0.80      1121
#
# Processing split 80:20
#   Training Naive Bayes with Bagging Classifier
#     Accuracy: 0.7456
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.75      0.64      0.69       202
#      depresi       0.73      0.83      0.78       286
#        stres       0.76      0.73      0.75       259
#
#     accuracy                           0.75       747
#    macro avg       0.75      0.73      0.74       747
# weighted avg       0.75      0.75      0.74       747
#
#   Training KNN with Bagging Classifier
#     Accuracy: 0.7323
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.73      0.66      0.69       202
#      depresi       0.72      0.79      0.75       286
#        stres       0.75      0.72      0.74       259
#
#     accuracy                           0.73       747
#    macro avg       0.73      0.72      0.73       747
# weighted avg       0.73      0.73      0.73       747
#
#   Training Random Forest with Bagging Classifier
#     Accuracy: 0.7965
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.83      0.71      0.77       202
#      depresi       0.77      0.88      0.82       286
#        stres       0.81      0.76      0.79       259
#
#     accuracy                           0.80       747
#    macro avg       0.80      0.79      0.79       747
# weighted avg       0.80      0.80      0.80       747
#
#   Training Neural Network with Bagging Classifier
#     Accuracy: 0.8019
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.81      0.74      0.78       202
#      depresi       0.81      0.85      0.83       286
#        stres       0.79      0.80      0.79       259
#
#     accuracy                           0.80       747
#    macro avg       0.80      0.80      0.80       747
# weighted avg       0.80      0.80      0.80       747
#
# Processing split 90:10
#   Training Naive Bayes with Bagging Classifier
#     Accuracy: 0.7406
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.78      0.65      0.71       110
#      depresi       0.68      0.84      0.75       131
#        stres       0.79      0.71      0.75       133
#
#     accuracy                           0.74       374
#    macro avg       0.75      0.74      0.74       374
# weighted avg       0.75      0.74      0.74       374
#
#   Training KNN with Bagging Classifier
#     Accuracy: 0.7594
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.84      0.69      0.76       110
#      depresi       0.70      0.84      0.76       131
#        stres       0.78      0.74      0.76       133
#
#     accuracy                           0.76       374
#    macro avg       0.77      0.76      0.76       374
# weighted avg       0.77      0.76      0.76       374
#
#   Training Random Forest with Bagging Classifier
#     Accuracy: 0.7968
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.84      0.69      0.76       110
#      depresi       0.74      0.91      0.82       131
#        stres       0.84      0.77      0.81       133
#
#     accuracy                           0.80       374
#    macro avg       0.81      0.79      0.79       374
# weighted avg       0.80      0.80      0.80       374
#
#   Training Neural Network with Bagging Classifier
#     Accuracy: 0.8235
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.86      0.75      0.81       110
#      depresi       0.79      0.87      0.83       131
#        stres       0.83      0.83      0.83       133
#
#     accuracy                           0.82       374
#    macro avg       0.83      0.82      0.82       374
# weighted avg       0.83      0.82      0.82       374

# %% [markdown]
# ## Menampilkan hasil model

# %%
import json

# Membaca file JSON
with open(path + f'{nama_ekstraksi}_bc_sv_experiment_results.json', 'r') as f:
    results = json.load(f)

# %% [markdown]
# ### Confusion Matrix (heatmap)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Known labels
labels = ["cemas", "depresi", "stres"]

# Set the figure size
plt.rcParams['figure.figsize'] = [20, 25]

# Create subplots for each confusion matrix
for i, (key, value) in enumerate(results.items()):
    cm = np.array(value['confusion_matrix'])
    plt.subplot(6, 4, i+1)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=labels, yticklabels=labels)
    plt.title(key)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.axis("on")

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Evaluasi kinerja model

# %%
# Inisialisasi list untuk menyimpan data
data = []

# Ekstrak split dan model dari keys di results
for key, value in results.items():
    model_name, split_info = key.split(f'_BC optimization_split')
    split_ratio = split_info.replace('_test', ':')
    accuracy = value['accuracy']

    # Tambahkan data ke dalam list
    data.append([split_ratio, model_name, accuracy])

# Konversi list ke DataFrame
accuracy_table = pd.DataFrame(data, columns=['Split', 'Model', 'Accuracy'])

# Pivot DataFrame agar model menjadi kolom
accuracy_table = accuracy_table.pivot(index='Split', columns='Model', values='Accuracy')

# Atur ulang kolom sesuai urutan yang diinginkan
accuracy_table = accuracy_table[['Naive Bayes', 'KNN', 'Random Forest', 'Neural Network']]

# Tampilkan tabel akurasi
accuracy_table
# Out:
# Model   Naive Bayes       KNN  Random Forest  Neural Network
# Split
#  60:40     0.763052  0.745649       0.817938        0.805221
#  70:30     0.761820  0.735950       0.810883        0.804639
#  80:20     0.745649  0.732262       0.796519        0.801874
#  90:10     0.740642  0.759358       0.796791        0.823529

# %%
# Initialize an empty list to store data for the DataFrame
data = []

# Extracting data for each model and split
for experiment_name, result in results.items():
    for label, metrics in result['classification_report'].items():
        if label not in ['accuracy', 'macro avg', 'weighted avg']:  # Skip overall metrics
            row = {
                'Experiment': experiment_name,
                'Label': label,
                'Precision': metrics['precision'],
                'Recall': metrics['recall'],
                'F1-Score': metrics['f1-score'],
                'Support': metrics['support']
            }
            data.append(row)

# Create DataFrame from the data list
df_results = pd.DataFrame(data)

# Display the first few rows of the DataFrame
df_results
# Out:
#                                     Experiment    Label  Precision    Recall  \
# 0      Naive Bayes_BC optimization_split 60:40    cemas   0.761773  0.692695
# 1      Naive Bayes_BC optimization_split 60:40  depresi   0.756881  0.837563
# 2      Naive Bayes_BC optimization_split 60:40    stres   0.772443  0.731225
# 3              KNN_BC optimization_split 60:40    cemas   0.759644  0.644836
# 4              KNN_BC optimization_split 60:40  depresi   0.737952  0.829103
# 5              KNN_BC optimization_split 60:40    stres   0.746450  0.727273
# 6    Random Forest_BC optimization_split 60:40    cemas   0.827778  0.750630
# 7    Random Forest_BC optimization_split 60:40  depresi   0.804249  0.896785
# 8    Random Forest_BC optimization_split 60:40    stres   0.829474  0.778656
# 9   Neural Network_BC optimization_split 60:40    cemas   0.790026  0.758186
# 10  Neural Network_BC optimization_split 60:40  depresi   0.823432  0.844332
# 11  Neural Network_BC optimization_split 60:40    stres   0.794872  0.796443
# 12     Naive Bayes_BC optimization_split 70:30    cemas   0.758242  0.680921
# 13     Naive Bayes_BC optimization_split 70:30  depresi   0.752066  0.829157
# 14     Naive Bayes_BC optimization_split 70:30    stres   0.777473  0.748677
# 15             KNN_BC optimization_split 70:30    cemas   0.740741  0.657895
# 16             KNN_BC optimization_split 70:30  depresi   0.721649  0.797267
# 17             KNN_BC optimization_split 70:30    stres   0.751366  0.727513
# 18   Random Forest_BC optimization_split 70:30    cemas   0.813620  0.746711
# 19   Random Forest_BC optimization_split 70:30  depresi   0.807128  0.876993
# 20   Random Forest_BC optimization_split 70:30    stres   0.813699  0.785714
# 21  Neural Network_BC optimization_split 70:30    cemas   0.780405  0.759868
# 22  Neural Network_BC optimization_split 70:30  depresi   0.834862  0.829157
# 23  Neural Network_BC optimization_split 70:30    stres   0.789203  0.812169
# 24     Naive Bayes_BC optimization_split 80:20    cemas   0.750000  0.638614
# 25     Naive Bayes_BC optimization_split 80:20  depresi   0.734568  0.832168
# 26     Naive Bayes_BC optimization_split 80:20    stres   0.756972  0.733591
# 27             KNN_BC optimization_split 80:20    cemas   0.726776  0.658416
# 28             KNN_BC optimization_split 80:20  depresi   0.718354  0.793706
# 29             KNN_BC optimization_split 80:20    stres   0.754032  0.722008
# 30   Random Forest_BC optimization_split 80:20    cemas   0.832370  0.712871
# 31   Random Forest_BC optimization_split 80:20  depresi   0.768997  0.884615
# 32   Random Forest_BC optimization_split 80:20    stres   0.808163  0.764479
# 33  Neural Network_BC optimization_split 80:20    cemas   0.810811  0.742574
# 34  Neural Network_BC optimization_split 80:20  depresi   0.807309  0.849650
# 35  Neural Network_BC optimization_split 80:20    stres   0.789272  0.795367
# 36     Naive Bayes_BC optimization_split 90:10    cemas   0.782609  0.654545
# 37     Naive Bayes_BC optimization_split 90:10  depresi   0.683230  0.839695
# 38     Naive Bayes_BC optimization_split 90:10    stres   0.785124  0.714286
# 39             KNN_BC optimization_split 90:10    cemas   0.835165  0.690909
# 40             KNN_BC optimization_split 90:10  depresi   0.696203  0.839695
# 41             KNN_BC optimization_split 90:10    stres   0.784000  0.736842
# 42   Random Forest_BC optimization_split 90:10    cemas   0.835165  0.690909
# 43   Random Forest_BC optimization_split 90:10  depresi   0.739130  0.908397
# 44   Random Forest_BC optimization_split 90:10    stres   0.844262  0.774436
# 45  Neural Network_BC optimization_split 90:10    cemas   0.864583  0.754545
# 46  Neural Network_BC optimization_split 90:10  depresi   0.791667  0.870229
# 47  Neural Network_BC optimization_split 90:10    stres   0.828358  0.834586
#
#     F1-Score  Support
# 0   0.725594    397.0
# 1   0.795181    591.0
# 2   0.751269    506.0
# 3   0.697548    397.0
# 4   0.780876    591.0
# 5   0.736737    506.0
# 6   0.787318    397.0
# 7   0.848000    591.0
# 8   0.803262    506.0
# 9   0.773779    397.0
# 10  0.833751    591.0
# 11  0.795656    506.0
# 12  0.717504    304.0
# 13  0.788732    439.0
# 14  0.762803    378.0
# 15  0.696864    304.0
# 16  0.757576    439.0
# 17  0.739247    378.0
# 18  0.778731    304.0
# 19  0.840611    439.0
# 20  0.799462    378.0
# 21  0.770000    304.0
# 22  0.832000    439.0
# 23  0.800522    378.0
# 24  0.689840    202.0
# 25  0.780328    286.0
# 26  0.745098    259.0
# 27  0.690909    202.0
# 28  0.754153    286.0
# 29  0.737673    259.0
# 30  0.768000    202.0
# 31  0.822764    286.0
# 32  0.785714    259.0
# 33  0.775194    202.0
# 34  0.827939    286.0
# 35  0.792308    259.0
# 36  0.712871    110.0
# 37  0.753425    131.0
# 38  0.748031    133.0
# 39  0.756219    110.0
# 40  0.761246    131.0
# 41  0.759690    133.0
# 42  0.756219    110.0
# 43  0.815068    131.0
# 44  0.807843    133.0
# 45  0.805825    110.0
# 46  0.829091    131.0
# 47  0.831461    133.0

# %% [markdown]
# # BC CrossV modelling

# %%
# Define models
models = {
    'Naive Bayes': MultinomialNB(alpha=0.1),
    'KNN': KNeighborsClassifier(n_neighbors=10, weights='distance', algorithm='auto', p=2),
    'Random Forest': RandomForestClassifier(n_estimators=100, max_depth=15, min_samples_split=5, min_samples_leaf=2, bootstrap=True),
    'Neural Network': MLPClassifier(hidden_layer_sizes=(100, 50), activation='relu', solver='adam', learning_rate='adaptive', max_iter=1000, early_stopping=True, n_iter_no_change=5)
}

# Bagging classifier function
optimasi = 'BC optimization'
def get_bagging_clf(base_estimator):
    return BaggingClassifier(estimator=base_estimator, n_estimators=10, random_state=42, n_jobs=-1)

# %%
# Define cross-validation folds
kf_values = [5, 10]

# Initialize results dictionary
results = {}

for k in kf_values:
    print(f'Processing cross-validation with k={k}')

    for model_name, model in models.items():
        print(f'  Training {model_name} with Bagging Classifier')

        # Create Bagging Classifier with the current model
        bagging_clf = get_bagging_clf(model)

        # Cross-validation predictions
        y_pred = cross_val_predict(bagging_clf, fitur, y, cv=k)

        # Evaluation
        conf_matrix = confusion_matrix(y, y_pred)
        class_report = classification_report(y, y_pred, output_dict=True, zero_division=0)
        accuracy = accuracy_score(y, y_pred)

        # Convert key to string, similar to the split validation
        result_key = f"{model_name}_{optimasi}_cross_val_k{k}"

        # Save results in the format similar to split validation
        results[result_key] = {
            'confusion_matrix': conf_matrix.tolist(),  # Convert array to list
            'classification_report': class_report,
            'accuracy': accuracy
        }

        print(f'    Accuracy: {accuracy:.4f}')
        print('    Classification Report:')
        print(classification_report(y, y_pred, zero_division=0))

# Save results to a JSON file
with open(path + f'{nama_ekstraksi}_bc_cv_experiment_results.json', 'w') as f:
    json.dump(results, f, indent=4)
# Out:
# Processing cross-validation with k=5
#   Training Naive Bayes with Bagging Classifier
#     Accuracy: 0.7660
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.78      0.69      0.73       956
#      depresi       0.74      0.85      0.79      1456
#        stres       0.79      0.73      0.76      1323
#
#     accuracy                           0.77      3735
#    macro avg       0.77      0.76      0.76      3735
# weighted avg       0.77      0.77      0.76      3735
#
#   Training KNN with Bagging Classifier
#     Accuracy: 0.7406
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.74      0.62      0.67       956
#      depresi       0.73      0.81      0.77      1456
#        stres       0.75      0.75      0.75      1323
#
#     accuracy                           0.74      3735
#    macro avg       0.74      0.73      0.73      3735
# weighted avg       0.74      0.74      0.74      3735
#
#   Training Random Forest with Bagging Classifier
#     Accuracy: 0.8126
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.82      0.73      0.78       956
#      depresi       0.80      0.90      0.85      1456
#        stres       0.82      0.78      0.80      1323
#
#     accuracy                           0.81      3735
#    macro avg       0.81      0.80      0.81      3735
# weighted avg       0.81      0.81      0.81      3735
#
#   Training Neural Network with Bagging Classifier
#     Accuracy: 0.8104
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.80      0.76      0.78       956
#      depresi       0.82      0.85      0.83      1456
#        stres       0.81      0.80      0.80      1323
#
#     accuracy                           0.81      3735
#    macro avg       0.81      0.80      0.81      3735
# weighted avg       0.81      0.81      0.81      3735
#
# Processing cross-validation with k=10
#   Training Naive Bayes with Bagging Classifier
#     Accuracy: 0.7668
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.78      0.69      0.73       956
#      depresi       0.74      0.85      0.79      1456
#        stres       0.79      0.73      0.76      1323
#
#     accuracy                           0.77      3735
#    macro avg       0.77      0.76      0.76      3735
# weighted avg       0.77      0.77      0.77      3735
#
#   Training KNN with Bagging Classifier
#     Accuracy: 0.7422
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.73      0.63      0.68       956
#      depresi       0.74      0.81      0.77      1456
#        stres       0.76      0.75      0.75      1323
#
#     accuracy                           0.74      3735
#    macro avg       0.74      0.73      0.73      3735
# weighted avg       0.74      0.74      0.74      3735
#
#   Training Random Forest with Bagging Classifier
#     Accuracy: 0.8137
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.83      0.73      0.78       956
#      depresi       0.80      0.90      0.85      1456
#        stres       0.82      0.78      0.80      1323
#
#     accuracy                           0.81      3735
#    macro avg       0.82      0.80      0.81      3735
# weighted avg       0.81      0.81      0.81      3735
#
#   Training Neural Network with Bagging Classifier
#     Accuracy: 0.8139
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.80      0.76      0.78       956
#      depresi       0.82      0.85      0.84      1456
#        stres       0.82      0.81      0.81      1323
#
#     accuracy                           0.81      3735
#    macro avg       0.81      0.81      0.81      3735
# weighted avg       0.81      0.81      0.81      3735

# %% [markdown]
# ## Menampilkan hasil model

# %%
import json

# Membaca file JSON
with open(path + f'{nama_ekstraksi}_bc_cv_experiment_results.json', 'r') as f:
    results = json.load(f)

# %% [markdown]
# ### Confusion Matrix (heatmap)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Known labels
labels = ["cemas", "depresi", "stres"]

# Set the figure size
plt.rcParams['figure.figsize'] = [20, 25]

# Create subplots for each confusion matrix
for i, (key, value) in enumerate(results.items()):
    # if i >= 20:  # Limit to 20 subplots (5 rows x 4 columns)
    #     break
    cm = np.array(value['confusion_matrix'])
    plt.subplot(6, 4, i+1)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=labels, yticklabels=labels)
    plt.title(key)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.axis("on")

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Evaluasi kinerja model

# %%
# Inisialisasi list untuk menyimpan data
data = []

# Ekstrak split dan model dari keys di results
for key, value in results.items():
    model_name, split_info = key.split(f'_k')
    split_ratio = split_info.replace('cross_val_', '')
    accuracy = value['accuracy']

    # Tambahkan data ke dalam list
    data.append([split_ratio, model_name, accuracy])

# Konversi list ke DataFrame
accuracy_table = pd.DataFrame(data, columns=['K-Fold', 'Model', 'Accuracy'])

# Pivot DataFrame agar model menjadi kolom
accuracy_table = accuracy_table.pivot(index='K-Fold', columns='Model', values='Accuracy')

# Rename columns to remove the extra text
accuracy_table.columns = accuracy_table.columns.str.replace('_BC optimization_cross_val', '')

# Atur ulang kolom sesuai urutan yang diinginkan
accuracy_table = accuracy_table[['Naive Bayes', 'KNN', 'Random Forest', 'Neural Network']]

# Tampilkan tabel akurasi
accuracy_table
# Out:
# Model   Naive Bayes       KNN  Random Forest  Neural Network
# K-Fold
# 10         0.766801  0.742169       0.813655        0.813922
# 5          0.765997  0.740562       0.812584        0.810442

# %%
# Initialize an empty list to store data for the DataFrame
data = []

# Extracting data for each model and split
for experiment_name, result in results.items():
    for label, metrics in result['classification_report'].items():
        if label not in ['accuracy', 'macro avg', 'weighted avg']:  # Skip overall metrics
            row = {
                'Experiment': experiment_name,
                'Label': label,
                'Precision': metrics['precision'],
                'Recall': metrics['recall'],
                'F1-Score': metrics['f1-score'],
                'Support': metrics['support']
            }
            data.append(row)

# Create DataFrame from the data list
df_results = pd.DataFrame(data)

# Display the first few rows of the DataFrame
df_results
# Out:
#                                       Experiment    Label  Precision  \
# 0       Naive Bayes_BC optimization_cross_val_k5    cemas   0.775029
# 1       Naive Bayes_BC optimization_cross_val_k5  depresi   0.741338
# 2       Naive Bayes_BC optimization_cross_val_k5    stres   0.793729
# 3               KNN_BC optimization_cross_val_k5    cemas   0.736318
# 4               KNN_BC optimization_cross_val_k5  depresi   0.731390
# 5               KNN_BC optimization_cross_val_k5    stres   0.754359
# 6     Random Forest_BC optimization_cross_val_k5    cemas   0.822014
# 7     Random Forest_BC optimization_cross_val_k5  depresi   0.800613
# 8     Random Forest_BC optimization_cross_val_k5    stres   0.821743
# 9    Neural Network_BC optimization_cross_val_k5    cemas   0.800439
# 10   Neural Network_BC optimization_cross_val_k5  depresi   0.819205
# 11   Neural Network_BC optimization_cross_val_k5    stres   0.807312
# 12     Naive Bayes_BC optimization_cross_val_k10    cemas   0.775439
# 13     Naive Bayes_BC optimization_cross_val_k10  depresi   0.744732
# 14     Naive Bayes_BC optimization_cross_val_k10    stres   0.790812
# 15             KNN_BC optimization_cross_val_k10    cemas   0.728589
# 16             KNN_BC optimization_cross_val_k10  depresi   0.736050
# 17             KNN_BC optimization_cross_val_k10    stres   0.758200
# 18   Random Forest_BC optimization_cross_val_k10    cemas   0.830769
# 19   Random Forest_BC optimization_cross_val_k10  depresi   0.801471
# 20   Random Forest_BC optimization_cross_val_k10    stres   0.817965
# 21  Neural Network_BC optimization_cross_val_k10    cemas   0.795852
# 22  Neural Network_BC optimization_cross_val_k10  depresi   0.822399
# 23  Neural Network_BC optimization_cross_val_k10    stres   0.816794
#
#       Recall  F1-Score  Support
# 0   0.688285  0.729086    956.0
# 1   0.852335  0.792971   1456.0
# 2   0.727135  0.758974   1323.0
# 3   0.619247  0.672727    956.0
# 4   0.809753  0.768579   1456.0
# 5   0.752079  0.753217   1323.0
# 6   0.734310  0.775691    956.0
# 7   0.896291  0.845755   1456.0
# 8   0.777022  0.798757   1323.0
# 9   0.763598  0.781585    956.0
# 10  0.849588  0.834120   1456.0
# 11  0.801209  0.804249   1323.0
# 12  0.693515  0.732192    956.0
# 13  0.849588  0.793712   1456.0
# 14  0.728647  0.758458   1323.0
# 15  0.631799  0.676751    956.0
# 16  0.806319  0.769584   1456.0
# 17  0.751323  0.754746   1323.0
# 18  0.734310  0.779567    956.0
# 19  0.898352  0.847150   1456.0
# 20  0.777778  0.797365   1323.0
# 21  0.762552  0.778846    956.0
# 22  0.852335  0.837099   1456.0
# 23  0.808768  0.812761   1323.0

# %% [markdown]
# # GA SplitV modelling

# %%
models = {
    'Naive Bayes': MultinomialNB(),
    'KNN': KNeighborsClassifier(),
    'Random Forest': RandomForestClassifier(),
    'Neural Network': MLPClassifier()
}
optimasi = 'GA optimization'

# %%
splits = [(0.6, 0.4), (0.7, 0.3), (0.8, 0.2), (0.9, 0.1)]
results = {}

def get_ga_search(model):
    param_grids = {
    'MultinomialNB': {'alpha': Continuous(0.01, 0.1, distribution='log-uniform')},
    'KNeighborsClassifier': {'n_neighbors': Integer(10, 30), 'weights': Categorical(['distance']), 'p': Integer(1, 2)},
    'RandomForestClassifier': {'n_estimators': Integer(50, 100), 'max_depth': Integer(10, 20)},
    'MLPClassifier': {'hidden_layer_sizes': Categorical([(100,), (100, 50)]), 'learning_rate_init': Continuous(0.001, 0.005), 'learning_rate': Categorical(['adaptive']), 'early_stopping': Categorical([True])}
    }

    model_name = type(model).__name__
    if model_name not in param_grids:
        raise ValueError(f"Parameter grid for {model_name} not defined")

    ga_search = GASearchCV(
        estimator=model,
        param_grid=param_grids[type(model).__name__],
        scoring='accuracy',
        cv=3,
        n_jobs=-1,
        verbose=True,
        population_size=20,
        generations=4
    )
    return ga_search

# %%
for train_size, test_size in splits:
    print(f'Processing split {int(train_size*100)}:{int(test_size*100)}')

    # Split data
    X_train, X_test, y_train, y_test = train_test_split(fitur, y, test_size=test_size, random_state=42)

    for model_name, model in models.items():
        print(f'  Training {model_name} with GASearchCV')

        # Create GASearchCV with the current model
        ga_search = get_ga_search(model)
        ga_search.fit(X_train, y_train)
        y_pred = ga_search.predict(X_test)

        # Evaluation
        conf_matrix = confusion_matrix(y_test, y_pred)
        class_report = classification_report(y_test, y_pred, output_dict=True, zero_division=0)
        accuracy = accuracy_score(y_test, y_pred)

        # Convert tuple key to string
        result_key = f"{model_name}_{optimasi}_split {int(train_size*100)}:{int(test_size*100)}"

        # Save results
        results[result_key] = {
            'best_params': ga_search.best_params_,
            'confusion_matrix': conf_matrix.tolist(),
            'classification_report': class_report,
            'accuracy': accuracy
        }

        print(f'    Accuracy: {accuracy:.4f}')
        print('    Best Params:', ga_search.best_params_)
        print('    Classification Report:')
        print(classification_report(y_test, y_pred, zero_division=0))

# Save results to a JSON file
with open(path + f'{nama_ekstraksi}_ga_sv_experiment_results.json', 'w') as f:
    json.dump(results, f, indent=4)
# Out:
# Processing split 60:40
#   Training Naive Bayes with GASearchCV
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.767515	0          	0.767515   	0.767515
# 1  	40    	0.767515	0          	0.767515   	0.767515
# 2  	40    	0.767515	0          	0.767515   	0.767515
# 3  	40    	0.767515	0          	0.767515   	0.767515
# 4  	40    	0.767515	0          	0.767515   	0.767515
#     Accuracy: 0.7624
#     Best Params: {'alpha': 0.09225429022155515}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.76      0.69      0.72       397
#      depresi       0.76      0.83      0.79       591
#        stres       0.77      0.73      0.75       506
#
#     accuracy                           0.76      1494
#    macro avg       0.76      0.75      0.76      1494
# weighted avg       0.76      0.76      0.76      1494
#
#   Training KNN with GASearchCV
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.707162	0.0123162  	0.729139   	0.689424
# 1  	40    	0.720928	0.0105893  	0.729139   	0.694779
# 2  	40    	0.728157	0.00135054 	0.729139   	0.722892
# 3  	40    	0.728983	0.000849888	0.731816   	0.7278
# 4  	40    	0.729652	0.00103958 	0.731816   	0.7278
#     Accuracy: 0.7396
#     Best Params: {'n_neighbors': 30, 'weights': 'distance', 'p': 2}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.84      0.57      0.68       397
#      depresi       0.72      0.83      0.77       591
#        stres       0.72      0.76      0.74       506
#
#     accuracy                           0.74      1494
#    macro avg       0.76      0.72      0.73      1494
# weighted avg       0.75      0.74      0.74      1494
#
#   Training Random Forest with GASearchCV
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.792392	0.00277192 	0.797858   	0.786256
# 1  	40    	0.795248	0.00318132 	0.801874   	0.790272
# 2  	40    	0.796854	0.00243543 	0.800982   	0.792503
# 3  	40    	0.797055	0.00208155 	0.798751   	0.791165
# 4  	40    	0.798304	0.00275797 	0.804552   	0.793842
#     Accuracy: 0.8159
#     Best Params: {'n_estimators': 84, 'max_depth': 19}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.81      0.77      0.79       397
#      depresi       0.81      0.88      0.84       591
#        stres       0.83      0.78      0.80       506
#
#     accuracy                           0.82      1494
#    macro avg       0.82      0.81      0.81      1494
# weighted avg       0.82      0.82      0.82      1494
#
#   Training Neural Network with GASearchCV
# gen	nevals	fitness	fitness_std	fitness_max	fitness_min
# 0  	20    	0.77992	0.00790796 	0.792503   	0.760821
# 1  	40    	0.787461	0.00448699 	0.793396   	0.777778
# 2  	40    	0.788844	0.00277811 	0.793396   	0.784025
# 3  	40    	0.788532	0.00299639 	0.792503   	0.783133
# 4  	40    	0.788398	0.00418981 	0.792503   	0.777332
#     Accuracy: 0.8019
#     Best Params: {'hidden_layer_sizes': (100, 50), 'learning_rate_init': 0.004883234112500331, 'learning_rate': 'adaptive', 'early_stopping': True}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.78      0.72      0.75       397
#      depresi       0.81      0.87      0.84       591
#        stres       0.80      0.79      0.80       506
#
#     accuracy                           0.80      1494
#    macro avg       0.80      0.79      0.79      1494
# weighted avg       0.80      0.80      0.80      1494
#
# Processing split 70:30
#   Training Naive Bayes with GASearchCV
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.767789	1.11022e-16	0.767789   	0.767789
# 1  	40    	0.767789	1.11022e-16	0.767789   	0.767789
# 2  	40    	0.767789	1.11022e-16	0.767789   	0.767789
# 3  	40    	0.767789	1.11022e-16	0.767789   	0.767789
# 4  	40    	0.767789	1.11022e-16	0.767789   	0.767789
#     Accuracy: 0.7591
#     Best Params: {'alpha': 0.0243126833116204}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.75      0.68      0.72       304
#      depresi       0.75      0.82      0.79       439
#        stres       0.77      0.75      0.76       378
#
#     accuracy                           0.76      1121
#    macro avg       0.76      0.75      0.75      1121
# weighted avg       0.76      0.76      0.76      1121
#
#   Training KNN with GASearchCV
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.721538	0.0149217  	0.737568   	0.687448
# 1  	40    	0.735234	0.00255886 	0.740246   	0.727232
# 2  	40    	0.73642 	0.00128079 	0.740246   	0.734122
# 3  	40    	0.736764	0.0016806  	0.740246   	0.734884
# 4  	40    	0.738047	0.00201992 	0.740246   	0.736038
#     Accuracy: 0.7645
#     Best Params: {'n_neighbors': 21, 'weights': 'distance', 'p': 2}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.82      0.65      0.73       304
#      depresi       0.75      0.83      0.79       439
#        stres       0.75      0.78      0.76       378
#
#     accuracy                           0.76      1121
#    macro avg       0.77      0.75      0.76      1121
# weighted avg       0.77      0.76      0.76      1121
#
#   Training Random Forest with GASearchCV
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.801298	0.00315605 	0.807954   	0.795328
# 1  	40    	0.80478 	0.00288966 	0.809108   	0.800303
# 2  	40    	0.806483	0.00325223 	0.810251   	0.800303
# 3  	40    	0.806922	0.00273868 	0.810251   	0.801066
# 4  	40    	0.806367	0.00270679 	0.810251   	0.802595
#     Accuracy: 0.8153
#     Best Params: {'n_estimators': 72, 'max_depth': 13}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.82      0.76      0.79       304
#      depresi       0.81      0.88      0.84       439
#        stres       0.83      0.79      0.81       378
#
#     accuracy                           0.82      1121
#    macro avg       0.82      0.81      0.81      1121
# weighted avg       0.82      0.82      0.81      1121
#
#   Training Neural Network with GASearchCV
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.787891	0.00734387 	0.797244   	0.766246
# 1  	40    	0.791526	0.00383315 	0.797244   	0.781176
# 2  	40    	0.792292	0.00256249 	0.796481   	0.785384
# 3  	40    	0.792139	0.00397644 	0.797244   	0.782709
# 4  	40    	0.792752	0.00345939 	0.79916    	0.785388
#     Accuracy: 0.8064
#     Best Params: {'hidden_layer_sizes': (100, 50), 'learning_rate_init': 0.0029940819728297664, 'learning_rate': 'adaptive', 'early_stopping': True}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.76      0.77      0.76       304
#      depresi       0.84      0.83      0.84       439
#        stres       0.80      0.81      0.81       378
#
#     accuracy                           0.81      1121
#    macro avg       0.80      0.80      0.80      1121
# weighted avg       0.81      0.81      0.81      1121
#
# Processing split 80:20
#   Training Naive Bayes with GASearchCV
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.768742	1.11022e-16	0.768742   	0.768742
# 1  	40    	0.768742	1.11022e-16	0.768742   	0.768742
# 2  	40    	0.768742	1.11022e-16	0.768742   	0.768742
# 3  	40    	0.768742	1.11022e-16	0.768742   	0.768742
# 4  	40    	0.768742	1.11022e-16	0.768742   	0.768742
#     Accuracy: 0.7456
#     Best Params: {'alpha': 0.03318216428010036}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.75      0.64      0.69       202
#      depresi       0.74      0.84      0.78       286
#        stres       0.76      0.73      0.74       259
#
#     accuracy                           0.75       747
#    macro avg       0.75      0.74      0.74       747
# weighted avg       0.75      0.75      0.74       747
#
#   Training KNN with GASearchCV
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.736931	0.0125122  	0.750335   	0.707162
# 1  	40    	0.74677 	0.0043857  	0.750335   	0.732597
# 2  	40    	0.748778	0.00244167 	0.750335   	0.743307
# 3  	40    	0.749665	0.00211135 	0.750335   	0.740629
# 4  	40    	0.750301	0.000100402	0.750335   	0.75
#     Accuracy: 0.7631
#     Best Params: {'n_neighbors': 24, 'weights': 'distance', 'p': 2}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.79      0.65      0.71       202
#      depresi       0.75      0.83      0.79       286
#        stres       0.76      0.78      0.77       259
#
#     accuracy                           0.76       747
#    macro avg       0.77      0.75      0.76       747
# weighted avg       0.77      0.76      0.76       747
#
#   Training Random Forest with GASearchCV
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.808266	0.00361988 	0.814926   	0.799866
# 1  	40    	0.810961	0.00262941 	0.81593    	0.807229
# 2  	40    	0.812082	0.00181311 	0.814926   	0.807564
# 3  	40    	0.811948	0.00204643 	0.8166     	0.808233
# 4  	40    	0.812918	0.00146646 	0.815596   	0.81091
#     Accuracy: 0.8126
#     Best Params: {'n_estimators': 84, 'max_depth': 20}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.85      0.74      0.79       202
#      depresi       0.78      0.89      0.83       286
#        stres       0.83      0.79      0.81       259
#
#     accuracy                           0.81       747
#    macro avg       0.82      0.80      0.81       747
# weighted avg       0.82      0.81      0.81       747
#
#   Training Neural Network with GASearchCV
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.796369	0.00327821 	0.802878   	0.790161
# 1  	40    	0.798896	0.0032186  	0.807898   	0.791834
# 2  	40    	0.802594	0.0031737  	0.807898   	0.797858
# 3  	40    	0.803213	0.00313772 	0.807898   	0.797858
# 4  	40    	0.803548	0.00367683 	0.808568   	0.79585
#     Accuracy: 0.7938
#     Best Params: {'hidden_layer_sizes': (100,), 'learning_rate_init': 0.004613261024539435, 'learning_rate': 'adaptive', 'early_stopping': True}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.78      0.72      0.75       202
#      depresi       0.79      0.83      0.81       286
#        stres       0.81      0.81      0.81       259
#
#     accuracy                           0.79       747
#    macro avg       0.79      0.79      0.79       747
# weighted avg       0.79      0.79      0.79       747
#
# Processing split 90:10
#   Training Naive Bayes with GASearchCV
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.770561	0.000106271	0.770605   	0.770308
# 1  	40    	0.770605	1.11022e-16	0.770605   	0.770605
# 2  	40    	0.770605	1.11022e-16	0.770605   	0.770605
# 3  	40    	0.770605	1.11022e-16	0.770605   	0.770605
# 4  	40    	0.770605	1.11022e-16	0.770605   	0.770605
#     Accuracy: 0.7406
#     Best Params: {'alpha': 0.025935704749288583}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.78      0.65      0.71       110
#      depresi       0.68      0.84      0.75       131
#        stres       0.79      0.71      0.75       133
#
#     accuracy                           0.74       374
#    macro avg       0.75      0.74      0.74       374
# weighted avg       0.75      0.74      0.74       374
#
#   Training KNN with GASearchCV
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.736846	0.011418   	0.747096   	0.709312
# 1  	40    	0.744952	0.00193286 	0.747988   	0.742333
# 2  	40    	0.746143	0.00154846 	0.747988   	0.743818
# 3  	40    	0.746828	0.00121914 	0.747988   	0.743823
# 4  	40    	0.747497	0.000499726	0.747988   	0.746798
#     Accuracy: 0.7540
#     Best Params: {'n_neighbors': 22, 'weights': 'distance', 'p': 2}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.80      0.67      0.73       110
#      depresi       0.68      0.84      0.75       131
#        stres       0.82      0.74      0.77       133
#
#     accuracy                           0.75       374
#    macro avg       0.77      0.75      0.75       374
# weighted avg       0.76      0.75      0.75       374
#
#   Training Random Forest with GASearchCV
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.808894	0.00272523 	0.813151   	0.804223
# 1  	40    	0.811289	0.00154283 	0.81315    	0.807197
# 2  	40    	0.813104	0.00180787 	0.815827   	0.80958
# 3  	40    	0.812837	0.00163367 	0.815827   	0.80958
# 4  	40    	0.813298	0.00153881 	0.815827   	0.809876
#     Accuracy: 0.8155
#     Best Params: {'n_estimators': 62, 'max_depth': 16}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.84      0.73      0.78       110
#      depresi       0.76      0.91      0.83       131
#        stres       0.87      0.80      0.83       133
#
#     accuracy                           0.82       374
#    macro avg       0.82      0.81      0.81       374
# weighted avg       0.82      0.82      0.81       374
#
#   Training Neural Network with GASearchCV
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.796206	0.00605868 	0.807502   	0.783695
# 1  	40    	0.801042	0.00344166 	0.806603   	0.792324
# 2  	40    	0.801994	0.00220376 	0.805712   	0.796491
# 3  	40    	0.801875	0.00317986 	0.807499   	0.793812
# 4  	40    	0.803556	0.00269766 	0.808094   	0.798271
#     Accuracy: 0.7968
#     Best Params: {'hidden_layer_sizes': (100,), 'learning_rate_init': 0.0010410878325041169, 'learning_rate': 'adaptive', 'early_stopping': True}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.79      0.78      0.79       110
#      depresi       0.79      0.82      0.80       131
#        stres       0.81      0.79      0.80       133
#
#     accuracy                           0.80       374
#    macro avg       0.80      0.80      0.80       374
# weighted avg       0.80      0.80      0.80       374

# %% [markdown]
# ## Menampilkan hasil model

# %%
import json

# Membaca file JSON
with open(path + f'{nama_ekstraksi}_ga_sv_experiment_results.json', 'r') as f:
    results = json.load(f)

# %% [markdown]
# ### Confusion Matrix (heatmap)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Known labels
labels = ["cemas", "depresi", "stres"]

# Set the figure size
plt.rcParams['figure.figsize'] = [20, 25]

# Create subplots for each confusion matrix
for i, (key, value) in enumerate(results.items()):
    cm = np.array(value['confusion_matrix'])
    plt.subplot(6, 4, i+1)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=labels, yticklabels=labels)
    plt.title(key)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.axis("on")

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Evaluasi kinerja model

# %%
# Inisialisasi list untuk menyimpan data
data = []

# Ekstrak split dan model dari keys di results
for key, value in results.items():
    model_name, split_info = key.split(f'_split ')
    split_ratio = split_info.replace('split ', '')
    accuracy = value['accuracy']

    # Tambahkan data ke dalam list
    data.append([split_ratio, model_name, accuracy])

# Konversi list ke DataFrame
accuracy_table = pd.DataFrame(data, columns=['Split', 'Model', 'Accuracy'])

# Pivot DataFrame agar model menjadi kolom
accuracy_table = accuracy_table.pivot(index='Split', columns='Model', values='Accuracy')

# Rename columns to remove the extra text
accuracy_table.columns = accuracy_table.columns.str.replace('_GA optimization', '')

# Atur ulang kolom sesuai urutan yang diinginkan
accuracy_table = accuracy_table[['Naive Bayes', 'KNN', 'Random Forest', 'Neural Network']]

# Tampilkan tabel akurasi
accuracy_table
# Out:
# Model  Naive Bayes       KNN  Random Forest  Neural Network
# Split
# 60:40     0.762383  0.739625       0.815930        0.801874
# 70:30     0.759144  0.764496       0.815343        0.806423
# 80:20     0.745649  0.763052       0.812584        0.793842
# 90:10     0.740642  0.754011       0.815508        0.796791

# %%
print(accuracy_table.columns)
# Out:
# Index(['Naive Bayes', 'KNN', 'Random Forest', 'Neural Network'], dtype='object', name='Model')

# %%
# Initialize an empty list to store data for the DataFrame
data = []

# Extracting data for each model and split
for experiment_name, result in results.items():
    for label, metrics in result['classification_report'].items():
        if label not in ['accuracy', 'macro avg', 'weighted avg']:  # Skip overall metrics
            row = {
                'Experiment': experiment_name,
                'Label': label,
                'Precision': metrics['precision'],
                'Recall': metrics['recall'],
                'F1-Score': metrics['f1-score'],
                'Support': metrics['support']
            }
            data.append(row)

# Create DataFrame from the data list
df_results = pd.DataFrame(data)

# Display the first few rows of the DataFrame
df_results
# Out:
#                                     Experiment    Label  Precision    Recall  \
# 0      Naive Bayes_GA optimization_split 60:40    cemas   0.757576  0.692695
# 1      Naive Bayes_GA optimization_split 60:40  depresi   0.757296  0.834179
# 2      Naive Bayes_GA optimization_split 60:40    stres   0.772917  0.733202
# 3              KNN_GA optimization_split 60:40    cemas   0.837037  0.569270
# 4              KNN_GA optimization_split 60:40  depresi   0.719708  0.834179
# 5              KNN_GA optimization_split 60:40    stres   0.716141  0.762846
# 6    Random Forest_GA optimization_split 60:40    cemas   0.808511  0.765743
# 7    Random Forest_GA optimization_split 60:40  depresi   0.808050  0.883249
# 8    Random Forest_GA optimization_split 60:40    stres   0.832627  0.776680
# 9   Neural Network_GA optimization_split 60:40    cemas   0.778689  0.717884
# 10  Neural Network_GA optimization_split 60:40  depresi   0.814286  0.868020
# 11  Neural Network_GA optimization_split 60:40    stres   0.803213  0.790514
# 12     Naive Bayes_GA optimization_split 70:30    cemas   0.752727  0.680921
# 13     Naive Bayes_GA optimization_split 70:30  depresi   0.751037  0.824601
# 14     Naive Bayes_GA optimization_split 70:30    stres   0.774725  0.746032
# 15             KNN_GA optimization_split 70:30    cemas   0.818182  0.651316
# 16             KNN_GA optimization_split 70:30  depresi   0.747951  0.831435
# 17             KNN_GA optimization_split 70:30    stres   0.751918  0.777778
# 18   Random Forest_GA optimization_split 70:30    cemas   0.816254  0.759868
# 19   Random Forest_GA optimization_split 70:30  depresi   0.807128  0.876993
# 20   Random Forest_GA optimization_split 70:30    stres   0.825485  0.788360
# 21  Neural Network_GA optimization_split 70:30    cemas   0.761438  0.766447
# 22  Neural Network_GA optimization_split 70:30  depresi   0.844548  0.829157
# 23  Neural Network_GA optimization_split 70:30    stres   0.799479  0.812169
# 24     Naive Bayes_GA optimization_split 80:20    cemas   0.747126  0.643564
# 25     Naive Bayes_GA optimization_split 80:20  depresi   0.735385  0.835664
# 26     Naive Bayes_GA optimization_split 80:20    stres   0.758065  0.725869
# 27             KNN_GA optimization_split 80:20    cemas   0.793939  0.648515
# 28             KNN_GA optimization_split 80:20  depresi   0.747634  0.828671
# 29             KNN_GA optimization_split 80:20    stres   0.762264  0.779923
# 30   Random Forest_GA optimization_split 80:20    cemas   0.846591  0.737624
# 31   Random Forest_GA optimization_split 80:20  depresi   0.781538  0.888112
# 32   Random Forest_GA optimization_split 80:20    stres   0.829268  0.787645
# 33  Neural Network_GA optimization_split 80:20    cemas   0.783784  0.717822
# 34  Neural Network_GA optimization_split 80:20  depresi   0.788079  0.832168
# 35  Neural Network_GA optimization_split 80:20    stres   0.807692  0.810811
# 36     Naive Bayes_GA optimization_split 90:10    cemas   0.782609  0.654545
# 37     Naive Bayes_GA optimization_split 90:10  depresi   0.683230  0.839695
# 38     Naive Bayes_GA optimization_split 90:10    stres   0.785124  0.714286
# 39             KNN_GA optimization_split 90:10    cemas   0.804348  0.672727
# 40             KNN_GA optimization_split 90:10  depresi   0.679012  0.839695
# 41             KNN_GA optimization_split 90:10    stres   0.816667  0.736842
# 42   Random Forest_GA optimization_split 90:10    cemas   0.842105  0.727273
# 43   Random Forest_GA optimization_split 90:10  depresi   0.757962  0.908397
# 44   Random Forest_GA optimization_split 90:10    stres   0.868852  0.796992
# 45  Neural Network_GA optimization_split 90:10    cemas   0.788991  0.781818
# 46  Neural Network_GA optimization_split 90:10  depresi   0.786765  0.816794
# 47  Neural Network_GA optimization_split 90:10    stres   0.813953  0.789474
#
#     F1-Score  Support
# 0   0.723684    397.0
# 1   0.793881    591.0
# 2   0.752535    506.0
# 3   0.677661    397.0
# 4   0.772727    591.0
# 5   0.738756    506.0
# 6   0.786546    397.0
# 7   0.843977    591.0
# 8   0.803681    506.0
# 9   0.747051    397.0
# 10  0.840295    591.0
# 11  0.796813    506.0
# 12  0.715026    304.0
# 13  0.786102    439.0
# 14  0.760108    378.0
# 15  0.725275    304.0
# 16  0.787487    439.0
# 17  0.764629    378.0
# 18  0.787053    304.0
# 19  0.840611    439.0
# 20  0.806495    378.0
# 21  0.763934    304.0
# 22  0.836782    439.0
# 23  0.805774    378.0
# 24  0.691489    202.0
# 25  0.782324    286.0
# 26  0.741617    259.0
# 27  0.713896    202.0
# 28  0.786070    286.0
# 29  0.770992    259.0
# 30  0.788360    202.0
# 31  0.831424    286.0
# 32  0.807921    259.0
# 33  0.749354    202.0
# 34  0.809524    286.0
# 35  0.809249    259.0
# 36  0.712871    110.0
# 37  0.753425    131.0
# 38  0.748031    133.0
# 39  0.732673    110.0
# 40  0.750853    131.0
# 41  0.774704    133.0
# 42  0.780488    110.0
# 43  0.826389    131.0
# 44  0.831373    133.0
# 45  0.785388    110.0
# 46  0.801498    131.0
# 47  0.801527    133.0

# %% [markdown]
# # GA CrossV modelling

# %%
models = {
    'Naive Bayes': MultinomialNB(),
    'KNN': KNeighborsClassifier(),
    'Random Forest': RandomForestClassifier(),
    'Neural Network': MLPClassifier()
}
optimasi = 'GA optimization'

# %%
def get_ga_search(model):
    param_grids = {
    'MultinomialNB': {'alpha': Continuous(0.01, 0.1, distribution='log-uniform')},
    'KNeighborsClassifier': {'n_neighbors': Integer(10, 30), 'weights': Categorical(['distance']), 'p': Integer(1, 2)},
    'RandomForestClassifier': {'n_estimators': Integer(50, 100), 'max_depth': Integer(10, 20)},
    'MLPClassifier': {'hidden_layer_sizes': Categorical([(100,), (100, 50)]), 'learning_rate_init': Continuous(0.001, 0.005), 'learning_rate': Categorical(['adaptive']), 'early_stopping': Categorical([True])}
    }

    model_name = type(model).__name__
    if model_name not in param_grids:
        raise ValueError(f"Parameter grid for {model_name} not defined")

    ga_search = GASearchCV(
        estimator=model,
        param_grid=param_grids[type(model).__name__],
        scoring='accuracy',
        cv=3,
        n_jobs=-1,
        verbose=True,
        population_size=20,
        generations=4
    )
    return ga_search

# %%
# Nilai k untuk Cross Validation
k_values = [5, 10]

results = {}

for k in k_values:
    for model_name, model in models.items():
        print(f'Training {model_name} with GASearchCV and Cross Validation (k={k})')

        # Create GASearchCV with the current model
        ga_search = get_ga_search(model)
        ga_search.fit(fitur, y)

        # Cross validation predictions with k-fold
        y_pred = cross_val_predict(ga_search.best_estimator_, fitur, y, cv=k)

        # Evaluation
        conf_matrix = confusion_matrix(y, y_pred)
        class_report = classification_report(y, y_pred, output_dict=True, zero_division=0)
        accuracy = accuracy_score(y, y_pred)

        # Convert model name and k value to a valid JSON key
        result_key = f"{model_name}_{optimasi}_cross_val_k{k}"

        # Save results
        results[result_key] = {
            'best_params': ga_search.best_params_,
            'confusion_matrix': conf_matrix.tolist(),
            'classification_report': class_report,
            'accuracy': accuracy
        }

        print(f'    Accuracy: {accuracy:.4f}')
        print('    Best Params:', ga_search.best_params_)
        print('    Classification Report:')
        print(classification_report(y, y_pred, zero_division=0))

# Save results to a JSON file
with open(path + f'{nama_ekstraksi}_ga_cv_experiment_results.json', 'w') as f:
    json.dump(results, f, indent=4)
# Out:
# Training Naive Bayes with GASearchCV and Cross Validation (k=5)
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.764659	0          	0.764659   	0.764659
# 1  	40    	0.764659	0          	0.764659   	0.764659
# 2  	40    	0.764659	0          	0.764659   	0.764659
# 3  	40    	0.764659	0          	0.764659   	0.764659
# 4  	40    	0.764659	0          	0.764659   	0.764659
#     Accuracy: 0.7652
#     Best Params: {'alpha': 0.037533816355923316}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.77      0.69      0.73       956
#      depresi       0.74      0.85      0.79      1456
#        stres       0.79      0.73      0.76      1323
#
#     accuracy                           0.77      3735
#    macro avg       0.77      0.76      0.76      3735
# weighted avg       0.77      0.77      0.76      3735
#
# Training KNN with GASearchCV and Cross Validation (k=5)
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.737564	0.0130931  	0.751272   	0.714592
# 1  	40    	0.748728	0.00286179 	0.751272   	0.741633
# 2  	40    	0.750295	0.00130966 	0.751272   	0.747791
# 3  	40    	0.750736	0.0019964  	0.751272   	0.742169
# 4  	40    	0.750656	0.00189527 	0.751272   	0.743775
#     Accuracy: 0.7513
#     Best Params: {'n_neighbors': 30, 'weights': 'distance', 'p': 2}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.77      0.62      0.69       956
#      depresi       0.72      0.85      0.78      1456
#        stres       0.78      0.74      0.76      1323
#
#     accuracy                           0.75      3735
#    macro avg       0.76      0.74      0.74      3735
# weighted avg       0.75      0.75      0.75      3735
#
# Training Random Forest with GASearchCV and Cross Validation (k=5)
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.809009	0.00312838 	0.815261   	0.802677
# 1  	40    	0.812236	0.00279283 	0.819009   	0.807764
# 2  	40    	0.812303	0.00180693 	0.815797   	0.807764
# 3  	40    	0.812972	0.00103858 	0.81419    	0.81071
# 4  	40    	0.814297	0.00105544 	0.816332   	0.812316
#     Accuracy: 0.8083
#     Best Params: {'n_estimators': 97, 'max_depth': 19}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.80      0.75      0.77       956
#      depresi       0.80      0.89      0.84      1456
#        stres       0.83      0.76      0.79      1323
#
#     accuracy                           0.81      3735
#    macro avg       0.81      0.80      0.80      3735
# weighted avg       0.81      0.81      0.81      3735
#
# Training Neural Network with GASearchCV and Cross Validation (k=5)
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.792222	0.00504703 	0.798394   	0.775368
# 1  	40    	0.797564	0.00196728 	0.800535   	0.793574
# 2  	40    	0.798675	0.00300949 	0.803213   	0.787952
# 3  	40    	0.799357	0.00168143 	0.802677   	0.796787
# 4  	40    	0.799036	0.00245298 	0.802677   	0.793307
#     Accuracy: 0.7944
#     Best Params: {'hidden_layer_sizes': (100,), 'learning_rate_init': 0.0038485317383976487, 'learning_rate': 'adaptive', 'early_stopping': True}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.77      0.73      0.75       956
#      depresi       0.81      0.84      0.82      1456
#        stres       0.80      0.79      0.79      1323
#
#     accuracy                           0.79      3735
#    macro avg       0.79      0.79      0.79      3735
# weighted avg       0.79      0.79      0.79      3735
#
# Training Naive Bayes with GASearchCV and Cross Validation (k=10)
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.764659	0          	0.764659   	0.764659
# 1  	40    	0.764659	0          	0.764659   	0.764659
# 2  	40    	0.764659	0          	0.764659   	0.764659
# 3  	40    	0.764659	0          	0.764659   	0.764659
# 4  	40    	0.764659	0          	0.764659   	0.764659
#     Accuracy: 0.7652
#     Best Params: {'alpha': 0.026934649748309628}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.77      0.69      0.73       956
#      depresi       0.74      0.85      0.79      1456
#        stres       0.79      0.72      0.76      1323
#
#     accuracy                           0.77      3735
#    macro avg       0.77      0.76      0.76      3735
# weighted avg       0.77      0.77      0.76      3735
#
# Training KNN with GASearchCV and Cross Validation (k=10)
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.732624	0.0140534  	0.751272   	0.713521
# 1  	40    	0.746493	0.0026911  	0.751272   	0.743775
# 2  	40    	0.747523	0.00412351 	0.751272   	0.733869
# 3  	40    	0.749558	0.00212409 	0.751272   	0.744043
# 4  	40    	0.751191	0.000350112	0.751272   	0.749665
#     Accuracy: 0.7620
#     Best Params: {'n_neighbors': 30, 'weights': 'distance', 'p': 2}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.79      0.63      0.70       956
#      depresi       0.73      0.86      0.79      1456
#        stres       0.79      0.75      0.77      1323
#
#     accuracy                           0.76      3735
#    macro avg       0.77      0.75      0.75      3735
# weighted avg       0.77      0.76      0.76      3735
#
# Training Random Forest with GASearchCV and Cross Validation (k=10)
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.809384	0.00326429 	0.813922   	0.803481
# 1  	40    	0.811473	0.00159135 	0.813922   	0.808835
# 2  	40    	0.812718	0.00129929 	0.814993   	0.81071
# 3  	40    	0.812932	0.0012243  	0.814726   	0.809906
# 4  	40    	0.813079	0.00135009 	0.814993   	0.810442
#     Accuracy: 0.8115
#     Best Params: {'n_estimators': 69, 'max_depth': 16}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.81      0.74      0.77       956
#      depresi       0.81      0.89      0.85      1456
#        stres       0.82      0.77      0.80      1323
#
#     accuracy                           0.81      3735
#    macro avg       0.81      0.80      0.81      3735
# weighted avg       0.81      0.81      0.81      3735
#
# Training Neural Network with GASearchCV and Cross Validation (k=10)
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.794056	0.00543817 	0.802677   	0.779116
# 1  	40    	0.798005	0.00245016 	0.802677   	0.794378
# 2  	40    	0.798072	0.00206106 	0.802677   	0.794378
# 3  	40    	0.799786	0.00257028 	0.805355   	0.795181
# 4  	40    	0.798795	0.00325992 	0.805355   	0.793039
#     Accuracy: 0.8011
#     Best Params: {'hidden_layer_sizes': (100, 50), 'learning_rate_init': 0.0011560001681559062, 'learning_rate': 'adaptive', 'early_stopping': True}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.80      0.75      0.77       956
#      depresi       0.80      0.85      0.82      1456
#        stres       0.80      0.79      0.79      1323
#
#     accuracy                           0.80      3735
#    macro avg       0.80      0.79      0.80      3735
# weighted avg       0.80      0.80      0.80      3735

# %% [markdown]
# ## Menampilkan hasil model

# %%
import json

# Membaca file JSON
with open(path + f'{nama_ekstraksi}_ga_cv_experiment_results.json', 'r') as f:
    results = json.load(f)

# %% [markdown]
# ### Confusion Matrix (heatmap)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Known labels
labels = ["cemas", "depresi", "stres"]

# Set the figure size
plt.rcParams['figure.figsize'] = [20, 25]

# Create subplots for each confusion matrix
for i, (key, value) in enumerate(results.items()):
    cm = np.array(value['confusion_matrix'])
    plt.subplot(6, 4, i+1)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=labels, yticklabels=labels)
    plt.title(key)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.axis("on")

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Evaluasi kinerja model

# %%
# Inisialisasi list untuk menyimpan data
data = []

# Ekstrak split dan model dari keys di results
for key, value in results.items():
    model_name, split_info = key.split(f'_k')
    split_ratio = split_info.replace('cross_val_', '')
    accuracy = value['accuracy']

    # Tambahkan data ke dalam list
    data.append([split_ratio, model_name, accuracy])

# Konversi list ke DataFrame
accuracy_table = pd.DataFrame(data, columns=['Split', 'Model', 'Accuracy'])

# Pivot DataFrame agar model menjadi kolom
accuracy_table = accuracy_table.pivot(index='Split', columns='Model', values='Accuracy')

# Rename columns to remove the extra text
accuracy_table.columns = accuracy_table.columns.str.replace('_GA optimization_cross_val', '')

# Atur ulang kolom sesuai urutan yang diinginkan
accuracy_table = accuracy_table[['Naive Bayes', 'KNN', 'Random Forest', 'Neural Network']]

# Tampilkan tabel akurasi
accuracy_table
# Out:
# Model  Naive Bayes       KNN  Random Forest  Neural Network
# Split
# 10        0.765194  0.761981       0.811513        0.801071
# 5         0.765194  0.751272       0.808300        0.794378

# %%
print(accuracy_table.columns)
# Out:
# Index(['Naive Bayes', 'KNN', 'Random Forest', 'Neural Network'], dtype='object', name='Model')

# %%
# Initialize an empty list to store data for the DataFrame
data = []

# Extracting data for each model and split
for experiment_name, result in results.items():
    for label, metrics in result['classification_report'].items():
        if label not in ['accuracy', 'macro avg', 'weighted avg']:  # Skip overall metrics
            row = {
                'Experiment': experiment_name,
                'Label': label,
                'Precision': metrics['precision'],
                'Recall': metrics['recall'],
                'F1-Score': metrics['f1-score'],
                'Support': metrics['support']
            }
            data.append(row)

# Create DataFrame from the data list
df_results = pd.DataFrame(data)

# Display the first few rows of the DataFrame
df_results
# Out:
#                                       Experiment    Label  Precision  \
# 0       Naive Bayes_GA optimization_cross_val_k5    cemas   0.769321
# 1       Naive Bayes_GA optimization_cross_val_k5  depresi   0.743251
# 2       Naive Bayes_GA optimization_cross_val_k5    stres   0.792422
# 3               KNN_GA optimization_cross_val_k5    cemas   0.773732
# 4               KNN_GA optimization_cross_val_k5  depresi   0.722709
# 5               KNN_GA optimization_cross_val_k5    stres   0.776536
# 6     Random Forest_GA optimization_cross_val_k5    cemas   0.800446
# 7     Random Forest_GA optimization_cross_val_k5  depresi   0.800000
# 8     Random Forest_GA optimization_cross_val_k5    stres   0.825020
# 9    Neural Network_GA optimization_cross_val_k5    cemas   0.773128
# 10   Neural Network_GA optimization_cross_val_k5  depresi   0.806345
# 11   Neural Network_GA optimization_cross_val_k5    stres   0.795282
# 12     Naive Bayes_GA optimization_cross_val_k10    cemas   0.773099
# 13     Naive Bayes_GA optimization_cross_val_k10  depresi   0.743544
# 14     Naive Bayes_GA optimization_cross_val_k10    stres   0.789300
# 15             KNN_GA optimization_cross_val_k10    cemas   0.788512
# 16             KNN_GA optimization_cross_val_k10  depresi   0.731465
# 17             KNN_GA optimization_cross_val_k10    stres   0.787420
# 18   Random Forest_GA optimization_cross_val_k10    cemas   0.805902
# 19   Random Forest_GA optimization_cross_val_k10  depresi   0.805090
# 20   Random Forest_GA optimization_cross_val_k10    stres   0.823813
# 21  Neural Network_GA optimization_cross_val_k10    cemas   0.799776
# 22  Neural Network_GA optimization_cross_val_k10  depresi   0.802863
# 23  Neural Network_GA optimization_cross_val_k10    stres   0.799847
#
#       Recall  F1-Score  Support
# 0   0.687238  0.725967    956.0
# 1   0.850962  0.793468   1456.0
# 2   0.727135  0.758376   1323.0
# 3   0.622385  0.689855    956.0
# 4   0.850275  0.781319   1456.0
# 5   0.735450  0.755435   1323.0
# 6   0.751046  0.774960    956.0
# 7   0.887363  0.841420   1456.0
# 8   0.762661  0.792616   1323.0
# 9   0.734310  0.753219    956.0
# 10  0.837912  0.821826   1456.0
# 11  0.789872  0.792567   1323.0
# 12  0.691423  0.729983    956.0
# 13  0.850275  0.793335   1456.0
# 14  0.724868  0.755713   1323.0
# 15  0.631799  0.701510    956.0
# 16  0.860577  0.790786   1456.0
# 17  0.747543  0.766964   1323.0
# 18  0.742678  0.772999    956.0
# 19  0.890797  0.845778   1456.0
# 20  0.773998  0.798129   1323.0
# 21  0.747908  0.772973    956.0
# 22  0.847527  0.824591   1456.0
# 23  0.788360  0.794062   1323.0

# %% [markdown]
# # Basic Split Validation Modelling (tanpa optimasi)

# %%
# Define models
models = {
    'Naive Bayes': MultinomialNB(),
    'KNN': KNeighborsClassifier(),
    'Random Forest': RandomForestClassifier(),
    'Neural Network': MLPClassifier()
}

# Define split ratios
splits = [(0.6, 0.4), (0.7, 0.3), (0.8, 0.2), (0.9, 0.1)]

# Initialize results dictionary
results = {}

for train_size, test_size in splits:
    print(f'Processing split {int(train_size*100)}:{int(test_size*100)}')

    # Split data
    X_train, X_test, y_train, y_test = train_test_split(fitur, y, test_size=test_size, random_state=42)

    for model_name, model in models.items():
        print(f'  Training {model_name} (basic model)')

        # Train the model directly
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)

        # Evaluation
        conf_matrix = confusion_matrix(y_test, y_pred)
        class_report = classification_report(y_test, y_pred, output_dict=True, zero_division=0)
        accuracy = accuracy_score(y_test, y_pred)

        # Convert tuple key to string
        result_key = f"{model_name}_basic_split {int(train_size*100)}:{int(test_size*100)}"

        # Save results
        results[result_key] = {
            'confusion_matrix': conf_matrix.tolist(),
            'classification_report': class_report,
            'accuracy': accuracy
        }

        print(f'    Accuracy: {accuracy:.4f}')
        print('    Classification Report:')
        print(classification_report(y_test, y_pred, zero_division=0))

# Save results to a JSON file
with open(path + f'{nama_ekstraksi}_basic_sv_experiment_results.json', 'w') as f:
    json.dump(results, f, indent=4)
# Out:
# Processing split 60:40
#   Training Naive Bayes (basic model)
#     Accuracy: 0.7624
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.76      0.69      0.72       397
#      depresi       0.76      0.83      0.79       591
#        stres       0.77      0.73      0.75       506
#
#     accuracy                           0.76      1494
#    macro avg       0.76      0.75      0.76      1494
# weighted avg       0.76      0.76      0.76      1494
#
#   Training KNN (basic model)
#     Accuracy: 0.7182
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.66      0.68      0.67       397
#      depresi       0.72      0.79      0.75       591
#        stres       0.77      0.66      0.71       506
#
#     accuracy                           0.72      1494
#    macro avg       0.72      0.71      0.71      1494
# weighted avg       0.72      0.72      0.72      1494
#
#   Training Random Forest (basic model)
#     Accuracy: 0.8226
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.82      0.78      0.80       397
#      depresi       0.82      0.89      0.85       591
#        stres       0.84      0.78      0.81       506
#
#     accuracy                           0.82      1494
#    macro avg       0.82      0.82      0.82      1494
# weighted avg       0.82      0.82      0.82      1494
#
#   Training Neural Network (basic model)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
#     Accuracy: 0.7865
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.76      0.75      0.75       397
#      depresi       0.81      0.82      0.82       591
#        stres       0.77      0.78      0.78       506
#
#     accuracy                           0.79      1494
#    macro avg       0.78      0.78      0.78      1494
# weighted avg       0.79      0.79      0.79      1494
#
# Processing split 70:30
#   Training Naive Bayes (basic model)
#     Accuracy: 0.7591
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.75      0.68      0.72       304
#      depresi       0.75      0.82      0.79       439
#        stres       0.77      0.75      0.76       378
#
#     accuracy                           0.76      1121
#    macro avg       0.76      0.75      0.75      1121
# weighted avg       0.76      0.76      0.76      1121
#
#   Training KNN (basic model)
#     Accuracy: 0.7333
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.67      0.73      0.70       304
#      depresi       0.73      0.78      0.75       439
#        stres       0.80      0.68      0.74       378
#
#     accuracy                           0.73      1121
#    macro avg       0.73      0.73      0.73      1121
# weighted avg       0.74      0.73      0.73      1121
#
#   Training Random Forest (basic model)
#     Accuracy: 0.8189
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.79      0.78      0.79       304
#      depresi       0.82      0.87      0.85       439
#        stres       0.84      0.79      0.81       378
#
#     accuracy                           0.82      1121
#    macro avg       0.82      0.81      0.81      1121
# weighted avg       0.82      0.82      0.82      1121
#
#   Training Neural Network (basic model)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
#     Accuracy: 0.7832
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.76      0.76      0.76       304
#      depresi       0.82      0.79      0.81       439
#        stres       0.76      0.79      0.78       378
#
#     accuracy                           0.78      1121
#    macro avg       0.78      0.78      0.78      1121
# weighted avg       0.78      0.78      0.78      1121
#
# Processing split 80:20
#   Training Naive Bayes (basic model)
#     Accuracy: 0.7456
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.75      0.64      0.69       202
#      depresi       0.74      0.84      0.78       286
#        stres       0.76      0.73      0.74       259
#
#     accuracy                           0.75       747
#    macro avg       0.75      0.74      0.74       747
# weighted avg       0.75      0.75      0.74       747
#
#   Training KNN (basic model)
#     Accuracy: 0.7095
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.63      0.71      0.67       202
#      depresi       0.72      0.74      0.73       286
#        stres       0.78      0.68      0.72       259
#
#     accuracy                           0.71       747
#    macro avg       0.71      0.71      0.71       747
# weighted avg       0.72      0.71      0.71       747
#
#   Training Random Forest (basic model)
#     Accuracy: 0.8059
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.82      0.74      0.78       202
#      depresi       0.79      0.88      0.83       286
#        stres       0.83      0.77      0.80       259
#
#     accuracy                           0.81       747
#    macro avg       0.81      0.80      0.80       747
# weighted avg       0.81      0.81      0.80       747
#
#   Training Neural Network (basic model)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
#     Accuracy: 0.7764
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.75      0.71      0.73       202
#      depresi       0.80      0.83      0.81       286
#        stres       0.77      0.78      0.77       259
#
#     accuracy                           0.78       747
#    macro avg       0.77      0.77      0.77       747
# weighted avg       0.78      0.78      0.78       747
#
# Processing split 90:10
#   Training Naive Bayes (basic model)
#     Accuracy: 0.7406
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.78      0.65      0.71       110
#      depresi       0.68      0.84      0.75       131
#        stres       0.79      0.71      0.75       133
#
#     accuracy                           0.74       374
#    macro avg       0.75      0.74      0.74       374
# weighted avg       0.75      0.74      0.74       374
#
#   Training KNN (basic model)
#     Accuracy: 0.7219
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.70      0.70      0.70       110
#      depresi       0.66      0.79      0.72       131
#        stres       0.84      0.67      0.74       133
#
#     accuracy                           0.72       374
#    macro avg       0.73      0.72      0.72       374
# weighted avg       0.74      0.72      0.72       374
#
#   Training Random Forest (basic model)
#     Accuracy: 0.7995
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.83      0.70      0.76       110
#      depresi       0.75      0.92      0.82       131
#        stres       0.85      0.77      0.81       133
#
#     accuracy                           0.80       374
#    macro avg       0.81      0.79      0.80       374
# weighted avg       0.81      0.80      0.80       374
#
#   Training Neural Network (basic model)
#     Accuracy: 0.7941
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.78      0.75      0.76       110
#      depresi       0.80      0.82      0.81       131
#        stres       0.80      0.80      0.80       133
#
#     accuracy                           0.79       374
#    macro avg       0.79      0.79      0.79       374
# weighted avg       0.79      0.79      0.79       374
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# ## Menampilkan hasil model

# %%
import json

# Membaca file JSON
with open(path + f'{nama_ekstraksi}_basic_sv_experiment_results.json', 'r') as f:
    results = json.load(f)

# %% [markdown]
# ### Confusion Matrix (heatmap)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Known labels
labels = ["cemas", "depresi", "stres"]

# Set the figure size
plt.rcParams['figure.figsize'] = [20, 25]

# Create subplots for each confusion matrix
for i, (key, value) in enumerate(results.items()):
    cm = np.array(value['confusion_matrix'])
    plt.subplot(6, 4, i+1)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=labels, yticklabels=labels)
    plt.title(key)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.axis("on")

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Evaluasi kinerja model

# %%
# Inisialisasi list untuk menyimpan data
data = []

# Ekstrak split dan model dari keys di results
for key, value in results.items():
    model_name, split_info = key.split(f'_basic_split')
    split_ratio = split_info.replace('_test', ':')
    accuracy = value['accuracy']

    # Tambahkan data ke dalam list
    data.append([split_ratio, model_name, accuracy])

# Konversi list ke DataFrame
accuracy_table = pd.DataFrame(data, columns=['Split', 'Model', 'Accuracy'])

# Pivot DataFrame agar model menjadi kolom
accuracy_table = accuracy_table.pivot(index='Split', columns='Model', values='Accuracy')

# Atur ulang kolom sesuai urutan yang diinginkan
accuracy_table = accuracy_table[['Naive Bayes', 'KNN', 'Random Forest', 'Neural Network']]

# Tampilkan tabel akurasi
accuracy_table
# Out:
# Model  Naive Bayes       KNN  Random Forest  Neural Network
# Split
# 60:40     0.762383  0.718206       0.822624        0.786479
# 70:30     0.759144  0.733274       0.818912        0.783229
# 80:20     0.745649  0.709505       0.805890        0.776439
# 90:10     0.740642  0.721925       0.799465        0.794118

# %%
# Initialize an empty list to store data for the DataFrame
data = []

# Extracting data for each model and split
for experiment_name, result in results.items():
    for label, metrics in result['classification_report'].items():
        if label not in ['accuracy', 'macro avg', 'weighted avg']:  # Skip overall metrics
            row = {
                'Experiment': experiment_name,
                'Label': label,
                'Precision': metrics['precision'],
                'Recall': metrics['recall'],
                'F1-Score': metrics['f1-score'],
                'Support': metrics['support']
            }
            data.append(row)

# Create DataFrame from the data list
df_results = pd.DataFrame(data)

# Display the first few rows of the DataFrame
df_results
# Out:
#                           Experiment    Label  Precision    Recall  F1-Score  \
# 0      Naive Bayes_basic_split 60:40    cemas   0.757576  0.692695  0.723684
# 1      Naive Bayes_basic_split 60:40  depresi   0.757296  0.834179  0.793881
# 2      Naive Bayes_basic_split 60:40    stres   0.772917  0.733202  0.752535
# 3              KNN_basic_split 60:40    cemas   0.659314  0.677582  0.668323
# 4              KNN_basic_split 60:40  depresi   0.720000  0.791878  0.754230
# 5              KNN_basic_split 60:40    stres   0.770642  0.664032  0.713376
# 6    Random Forest_basic_split 60:40    cemas   0.816976  0.775819  0.795866
# 7    Random Forest_basic_split 60:40  depresi   0.815504  0.890017  0.851133
# 8    Random Forest_basic_split 60:40    stres   0.836864  0.780632  0.807771
# 9   Neural Network_basic_split 60:40    cemas   0.760925  0.745592  0.753181
# 10  Neural Network_basic_split 60:40  depresi   0.814070  0.822335  0.818182
# 11  Neural Network_basic_split 60:40    stres   0.773622  0.776680  0.775148
# 12     Naive Bayes_basic_split 70:30    cemas   0.752727  0.680921  0.715026
# 13     Naive Bayes_basic_split 70:30  depresi   0.751037  0.824601  0.786102
# 14     Naive Bayes_basic_split 70:30    stres   0.774725  0.746032  0.760108
# 15             KNN_basic_split 70:30    cemas   0.672727  0.730263  0.700315
# 16             KNN_basic_split 70:30  depresi   0.727660  0.779043  0.752475
# 17             KNN_basic_split 70:30    stres   0.803738  0.682540  0.738197
# 18   Random Forest_basic_split 70:30    cemas   0.788079  0.782895  0.785479
# 19   Random Forest_basic_split 70:30  depresi   0.821505  0.870159  0.845133
# 20   Random Forest_basic_split 70:30    stres   0.841808  0.788360  0.814208
# 21  Neural Network_basic_split 70:30    cemas   0.759076  0.756579  0.757825
# 22  Neural Network_basic_split 70:30  depresi   0.818824  0.792711  0.805556
# 23  Neural Network_basic_split 70:30    stres   0.763359  0.793651  0.778210
# 24     Naive Bayes_basic_split 80:20    cemas   0.747126  0.643564  0.691489
# 25     Naive Bayes_basic_split 80:20  depresi   0.735385  0.835664  0.782324
# 26     Naive Bayes_basic_split 80:20    stres   0.758065  0.725869  0.741617
# 27             KNN_basic_split 80:20    cemas   0.629956  0.707921  0.666667
# 28             KNN_basic_split 80:20  depresi   0.718644  0.741259  0.729776
# 29             KNN_basic_split 80:20    stres   0.777778  0.675676  0.723140
# 30   Random Forest_basic_split 80:20    cemas   0.815217  0.742574  0.777202
# 31   Random Forest_basic_split 80:20  depresi   0.785714  0.884615  0.832237
# 32   Random Forest_basic_split 80:20    stres   0.825726  0.768340  0.796000
# 33  Neural Network_basic_split 80:20    cemas   0.748691  0.707921  0.727735
# 34  Neural Network_basic_split 80:20  depresi   0.802721  0.825175  0.813793
# 35  Neural Network_basic_split 80:20    stres   0.767176  0.776062  0.771593
# 36     Naive Bayes_basic_split 90:10    cemas   0.782609  0.654545  0.712871
# 37     Naive Bayes_basic_split 90:10  depresi   0.683230  0.839695  0.753425
# 38     Naive Bayes_basic_split 90:10    stres   0.785124  0.714286  0.748031
# 39             KNN_basic_split 90:10    cemas   0.700000  0.700000  0.700000
# 40             KNN_basic_split 90:10  depresi   0.658228  0.793893  0.719723
# 41             KNN_basic_split 90:10    stres   0.839623  0.669173  0.744770
# 42   Random Forest_basic_split 90:10    cemas   0.827957  0.700000  0.758621
# 43   Random Forest_basic_split 90:10  depresi   0.745342  0.916031  0.821918
# 44   Random Forest_basic_split 90:10    stres   0.850000  0.766917  0.806324
# 45  Neural Network_basic_split 90:10    cemas   0.775701  0.754545  0.764977
# 46  Neural Network_basic_split 90:10  depresi   0.800000  0.824427  0.812030
# 47  Neural Network_basic_split 90:10    stres   0.803030  0.796992  0.800000
#
#     Support
# 0     397.0
# 1     591.0
# 2     506.0
# 3     397.0
# 4     591.0
# 5     506.0
# 6     397.0
# 7     591.0
# 8     506.0
# 9     397.0
# 10    591.0
# 11    506.0
# 12    304.0
# 13    439.0
# 14    378.0
# 15    304.0
# 16    439.0
# 17    378.0
# 18    304.0
# 19    439.0
# 20    378.0
# 21    304.0
# 22    439.0
# 23    378.0
# 24    202.0
# 25    286.0
# 26    259.0
# 27    202.0
# 28    286.0
# 29    259.0
# 30    202.0
# 31    286.0
# 32    259.0
# 33    202.0
# 34    286.0
# 35    259.0
# 36    110.0
# 37    131.0
# 38    133.0
# 39    110.0
# 40    131.0
# 41    133.0
# 42    110.0
# 43    131.0
# 44    133.0
# 45    110.0
# 46    131.0
# 47    133.0

# %% [markdown]
# # Basic Cross Validation Modelling (tanpa optimasi)

# %%
# Define models
models = {
    'Naive Bayes': MultinomialNB(),
    'KNN': KNeighborsClassifier(),
    'Random Forest': RandomForestClassifier(),
    'Neural Network': MLPClassifier()
}

# Define cross-validation folds
kf_values = [5, 10]

# Initialize results dictionary
results = {}

for k in kf_values:
    print(f'Processing cross-validation with k={k}')

    for model_name, model in models.items():
        print(f'  Training {model_name} (basic model)')

        # Cross-validation predictions
        y_pred = cross_val_predict(model, fitur, y, cv=k)

        # Evaluation
        conf_matrix = confusion_matrix(y, y_pred)
        class_report = classification_report(y, y_pred, output_dict=True, zero_division=0)
        accuracy = accuracy_score(y, y_pred)

        # Convert key to string, similar to the split validation
        result_key = f"{model_name}_basic_cross_val_k{k}"

        # Save results in the format similar to split validation
        results[result_key] = {
            'confusion_matrix': conf_matrix.tolist(),
            'classification_report': class_report,
            'accuracy': accuracy
        }

        print(f'    Accuracy: {accuracy:.4f}')
        print('    Classification Report:')
        print(classification_report(y, y_pred, zero_division=0))

# Save results to a JSON file
with open(path + f'{nama_ekstraksi}_basic_cv_experiment_results.json', 'w') as f:
    json.dump(results, f, indent=4)
# Out:
# Processing cross-validation with k=5
#   Training Naive Bayes (basic model)
#     Accuracy: 0.7652
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.77      0.69      0.73       956
#      depresi       0.74      0.85      0.79      1456
#        stres       0.79      0.73      0.76      1323
#
#     accuracy                           0.77      3735
#    macro avg       0.77      0.76      0.76      3735
# weighted avg       0.77      0.77      0.76      3735
#
#   Training KNN (basic model)
#     Accuracy: 0.7058
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.61      0.67      0.64       956
#      depresi       0.72      0.76      0.74      1456
#        stres       0.78      0.67      0.72      1323
#
#     accuracy                           0.71      3735
#    macro avg       0.70      0.70      0.70      3735
# weighted avg       0.71      0.71      0.71      3735
#
#   Training Random Forest (basic model)
#     Accuracy: 0.8142
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.81      0.76      0.78       956
#      depresi       0.81      0.89      0.85      1456
#        stres       0.83      0.77      0.80      1323
#
#     accuracy                           0.81      3735
#    macro avg       0.81      0.81      0.81      3735
# weighted avg       0.81      0.81      0.81      3735
#
#   Training Neural Network (basic model)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
#     Accuracy: 0.7756
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.75      0.73      0.74       956
#      depresi       0.79      0.81      0.80      1456
#        stres       0.78      0.77      0.77      1323
#
#     accuracy                           0.78      3735
#    macro avg       0.77      0.77      0.77      3735
# weighted avg       0.78      0.78      0.78      3735
#
# Processing cross-validation with k=10
#   Training Naive Bayes (basic model)
#     Accuracy: 0.7652
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.77      0.69      0.73       956
#      depresi       0.74      0.85      0.79      1456
#        stres       0.79      0.72      0.76      1323
#
#     accuracy                           0.77      3735
#    macro avg       0.77      0.76      0.76      3735
# weighted avg       0.77      0.77      0.76      3735
#
#   Training KNN (basic model)
#     Accuracy: 0.7138
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.62      0.69      0.65       956
#      depresi       0.73      0.76      0.74      1456
#        stres       0.78      0.68      0.73      1323
#
#     accuracy                           0.71      3735
#    macro avg       0.71      0.71      0.71      3735
# weighted avg       0.72      0.71      0.71      3735
#
#   Training Random Forest (basic model)
#     Accuracy: 0.8110
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.80      0.75      0.77       956
#      depresi       0.80      0.89      0.84      1456
#        stres       0.83      0.77      0.80      1323
#
#     accuracy                           0.81      3735
#    macro avg       0.81      0.80      0.81      3735
# weighted avg       0.81      0.81      0.81      3735
#
#   Training Neural Network (basic model)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
#     Accuracy: 0.7815
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.75      0.75      0.75       956
#      depresi       0.80      0.80      0.80      1456
#        stres       0.78      0.78      0.78      1323
#
#     accuracy                           0.78      3735
#    macro avg       0.78      0.78      0.78      3735
# weighted avg       0.78      0.78      0.78      3735

# %% [markdown]
# ## Menampilkan hasil model

# %%
import json

# Membaca file JSON
with open(path + f'{nama_ekstraksi}_basic_cv_experiment_results.json', 'r') as f:
    results = json.load(f)

# %% [markdown]
# ### Confusion Matrix (heatmap)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Known labels
labels = ["cemas", "depresi", "stres"]

# Set the figure size
plt.rcParams['figure.figsize'] = [20, 25]

# Create subplots for each confusion matrix
for i, (key, value) in enumerate(results.items()):
    # if i >= 20:  # Limit to 20 subplots (5 rows x 4 columns)
    #     break
    cm = np.array(value['confusion_matrix'])
    plt.subplot(6, 4, i+1)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=labels, yticklabels=labels)
    plt.title(key)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.axis("on")

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Evaluasi kinerja model

# %%
# Inisialisasi list untuk menyimpan data
data = []

# Ekstrak split dan model dari keys di results
for key, value in results.items():
    model_name, split_info = key.split(f'_k')
    split_ratio = split_info.replace('cross_val_', '')
    accuracy = value['accuracy']

    # Tambahkan data ke dalam list
    data.append([split_ratio, model_name, accuracy])

# Konversi list ke DataFrame
accuracy_table = pd.DataFrame(data, columns=['K-Fold', 'Model', 'Accuracy'])

# Pivot DataFrame agar model menjadi kolom
accuracy_table = accuracy_table.pivot(index='K-Fold', columns='Model', values='Accuracy')

# Rename columns to remove the extra text
accuracy_table.columns = accuracy_table.columns.str.replace('_basic_cross_val', '')

# Atur ulang kolom sesuai urutan yang diinginkan
accuracy_table = accuracy_table[['Naive Bayes', 'KNN', 'Random Forest', 'Neural Network']]

# Tampilkan tabel akurasi
accuracy_table
# Out:
# Model   Naive Bayes       KNN  Random Forest  Neural Network
# K-Fold
# 10         0.765194  0.713788       0.810977        0.781526
# 5          0.765194  0.705756       0.814190        0.775636

# %%
# Initialize an empty list to store data for the DataFrame
data = []

# Extracting data for each model and split
for experiment_name, result in results.items():
    for label, metrics in result['classification_report'].items():
        if label not in ['accuracy', 'macro avg', 'weighted avg']:  # Skip overall metrics
            row = {
                'Experiment': experiment_name,
                'Label': label,
                'Precision': metrics['precision'],
                'Recall': metrics['recall'],
                'F1-Score': metrics['f1-score'],
                'Support': metrics['support']
            }
            data.append(row)

# Create DataFrame from the data list
df_results = pd.DataFrame(data)

# Display the first few rows of the DataFrame
df_results
# Out:
#                             Experiment    Label  Precision    Recall  \
# 0       Naive Bayes_basic_cross_val_k5    cemas   0.769321  0.687238
# 1       Naive Bayes_basic_cross_val_k5  depresi   0.743251  0.850962
# 2       Naive Bayes_basic_cross_val_k5    stres   0.792422  0.727135
# 3               KNN_basic_cross_val_k5    cemas   0.609848  0.673640
# 4               KNN_basic_cross_val_k5  depresi   0.717815  0.758242
# 5               KNN_basic_cross_val_k5    stres   0.778265  0.671202
# 6     Random Forest_basic_cross_val_k5    cemas   0.805310  0.761506
# 7     Random Forest_basic_cross_val_k5  depresi   0.807116  0.888049
# 8     Random Forest_basic_cross_val_k5    stres   0.829943  0.770975
# 9    Neural Network_basic_cross_val_k5    cemas   0.745745  0.733264
# 10   Neural Network_basic_cross_val_k5  depresi   0.794217  0.811126
# 11   Neural Network_basic_cross_val_k5    stres   0.775994  0.767196
# 12     Naive Bayes_basic_cross_val_k10    cemas   0.773099  0.691423
# 13     Naive Bayes_basic_cross_val_k10  depresi   0.743544  0.850275
# 14     Naive Bayes_basic_cross_val_k10    stres   0.789300  0.724868
# 15             KNN_basic_cross_val_k10    cemas   0.618557  0.690377
# 16             KNN_basic_cross_val_k10  depresi   0.727570  0.763049
# 17             KNN_basic_cross_val_k10    stres   0.784400  0.676493
# 18   Random Forest_basic_cross_val_k10    cemas   0.803371  0.747908
# 19   Random Forest_basic_cross_val_k10  depresi   0.804348  0.889423
# 20   Random Forest_basic_cross_val_k10    stres   0.825101  0.770219
# 21  Neural Network_basic_cross_val_k10    cemas   0.753943  0.750000
# 22  Neural Network_basic_cross_val_k10  depresi   0.798090  0.803571
# 23  Neural Network_basic_cross_val_k10    stres   0.783005  0.780045
#
#     F1-Score  Support
# 0   0.725967    956.0
# 1   0.793468   1456.0
# 2   0.758376   1323.0
# 3   0.640159    956.0
# 4   0.737475   1456.0
# 5   0.720779   1323.0
# 6   0.782796    956.0
# 7   0.845651   1456.0
# 8   0.799373   1323.0
# 9   0.739451    956.0
# 10  0.802582   1456.0
# 11  0.771570   1323.0
# 12  0.729983    956.0
# 13  0.793335   1456.0
# 14  0.755713   1323.0
# 15  0.652496    956.0
# 16  0.744888   1456.0
# 17  0.726461   1323.0
# 18  0.774648    956.0
# 19  0.844749   1456.0
# 20  0.796716   1323.0
# 21  0.751966    956.0
# 22  0.800821   1456.0
# 23  0.781522   1323.0
