# %% [markdown]
# # Load Data

# %%
import pandas as pd
import numpy as np

# Definisikan path file
path = '/content/drive/MyDrive/Colab Notebooks/RisetHibahPemerintah/Eksperimen - Klasifikasi Teks/'

data = pd.read_csv(path + 'datamodel_klasifikasi_clean.csv')
df = data[['Answer_fix', 'topik']].copy()

# %%
df.head()
# Out:
#                                           Answer_fix    topik
# 0  ['insomnia', 'sakit', 'gejala', 'sakit', 'saki...  depresi
# 1  ['asa', 'debar', 'debar', 'irama', 'jantung', ...    stres
# 2  ['paham', 'asa', 'anak', 'tua', 'cerai', 'muda...  depresi
# 3  ['maria', 'prihatin', 'kondisi', 'alami', 'pen...  depresi
# 4  ['depresi', 'bentuk', 'mental', 'perhati', 'ma...  depresi

# %%
df['Answer_fix'] = df['Answer_fix'].apply(eval)  # Konversi string list ke list

# %%
# Load GloVe model
def load_glove_model(glove_file):
    glove_model = {}
    with open(glove_file, 'r', encoding="utf-8") as f:
        for line in f:
            split_line = line.split()
            word = split_line[0]
            embedding = np.array([float(val) for val in split_line[1:]])
            glove_model[word] = embedding
    return glove_model

glove_model = load_glove_model('/content/drive/MyDrive/Colab Notebooks/RisetHibahPemerintah/Eksperimen - Klasifikasi Teks/glove_50dim_wiki.id.case.text.txt')

# Konversi Teks ke Vektor dengan GloVe
def text_to_glove_vector(text, glove_model, vector_size=50):
    words = [word for word in text if word in glove_model]
    if len(words) == 0:
        return np.zeros(vector_size)
    return np.mean([glove_model[word] for word in words], axis=0)

# Transform dataset
X_glove = np.array([text_to_glove_vector(text, glove_model) for text in df['Answer_fix']])

# %%
# setting data
nama_ekstraksi = 'X_glove'
fitur = X_glove
y = df['topik']

# %% [markdown]
# # import modul

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn.neural_network import MLPClassifier
import json
import nltk

# Pastikan nltk sudah terinstall
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from sklearn.model_selection import cross_val_predict

# %%
# !pip install sklearn-genetic-opt
# Out:
# Collecting sklearn-genetic-opt
#   Downloading sklearn_genetic_opt-0.11.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: scikit-learn>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from sklearn-genetic-opt) (1.5.2)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from sklearn-genetic-opt) (1.26.4)
# Collecting deap>=1.3.3 (from sklearn-genetic-opt)
#   Downloading deap-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: tqdm>=4.61.1 in /usr/local/lib/python3.10/dist-packages (from sklearn-genetic-opt) (4.66.5)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.0->sklearn-genetic-opt) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.0->sklearn-genetic-opt) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.3.0->sklearn-genetic-opt) (3.5.0)
# Downloading sklearn_genetic_opt-0.11.1-py3-none-any.whl (35 kB)
# Downloading deap-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.4/135.4 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: deap, sklearn-genetic-opt
# Successfully installed deap-1.4.1 sklearn-genetic-opt-0.11.1

# %%
from sklearn_genetic import GASearchCV
from sklearn_genetic.space import Categorical, Integer, Continuous

# %%
import joblib
import os
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="sklearn_genetic")

# Ganti backend joblib
joblib.parallel_backend('threading')

# Setel variabel lingkungan untuk joblib
os.environ['JOBLIB_TEMP_FOLDER'] = '/tmp'
os.environ['JOBLIB_PARALLEL_BACKEND'] = 'threading'

# %% [markdown]
# # BC SplitV modelling

# %%
# Define models
models = {
    'Naive Bayes': GaussianNB(var_smoothing=1e-9),
    'KNN': KNeighborsClassifier(n_neighbors=10, weights='distance', algorithm='auto', p=2),
    'Random Forest': RandomForestClassifier(n_estimators=100, max_depth=15, min_samples_split=5, min_samples_leaf=2, bootstrap=True),
    'Neural Network': MLPClassifier(hidden_layer_sizes=(100, 50), activation='relu', solver='adam', learning_rate='adaptive', max_iter=1000, early_stopping=True, n_iter_no_change=5)
}

# Bagging classifier
optimasi = 'BC optimization'
def get_bagging_clf(base_estimator):
    return BaggingClassifier(estimator=base_estimator, n_estimators=10, random_state=42, n_jobs=-1)

# %%
# Define split ratios
splits = [(0.6, 0.4), (0.7, 0.3), (0.8, 0.2), (0.9, 0.1)]

# Initialize results dictionary
results = {}

for train_size, test_size in splits:
    print(f'Processing split {int(train_size*100)}:{int(test_size*100)}')

    # Split data
    X_train, X_test, y_train, y_test = train_test_split(fitur, y, test_size=test_size, random_state=42)

    for model_name, model in models.items():
        print(f'  Training {model_name} with Bagging Classifier')

        # Create Bagging Classifier with the current model
        bagging_clf = get_bagging_clf(model)
        bagging_clf.fit(X_train, y_train)
        y_pred = bagging_clf.predict(X_test)

        # Evaluation
        conf_matrix = confusion_matrix(y_test, y_pred)
        class_report = classification_report(y_test, y_pred, output_dict=True, zero_division=0)
        accuracy = accuracy_score(y_test, y_pred)

        # Convert tuple key to string
        result_key = f"{model_name}_{optimasi}_split {int(train_size*100)}:{int(test_size*100)}"

        # Save results
        results[result_key] = {
            'confusion_matrix': conf_matrix.tolist(),
            'classification_report': class_report,
            'accuracy': accuracy
        }

        print(f'    Accuracy: {accuracy:.4f}')
        print('    Classification Report:')
        print(classification_report(y_test, y_pred, zero_division=0))

# Save results to a JSON file
with open(path + f'{nama_ekstraksi}_bc_sv_experiment_results.json', 'w') as f:
    json.dump(results, f, indent=4)
# Out:
# Processing split 60:40
#   Training Naive Bayes with Bagging Classifier
#     Accuracy: 0.6620
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.65      0.45      0.53       397
#      depresi       0.63      0.81      0.71       591
#        stres       0.72      0.65      0.69       506
#
#     accuracy                           0.66      1494
#    macro avg       0.67      0.64      0.64      1494
# weighted avg       0.67      0.66      0.65      1494
#
#   Training KNN with Bagging Classifier
#     Accuracy: 0.6841
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.65      0.52      0.58       397
#      depresi       0.65      0.84      0.73       591
#        stres       0.78      0.62      0.69       506
#
#     accuracy                           0.68      1494
#    macro avg       0.69      0.66      0.67      1494
# weighted avg       0.69      0.68      0.68      1494
#
#   Training Random Forest with Bagging Classifier
#     Accuracy: 0.6948
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.73      0.48      0.58       397
#      depresi       0.66      0.83      0.74       591
#        stres       0.72      0.71      0.72       506
#
#     accuracy                           0.69      1494
#    macro avg       0.71      0.67      0.68      1494
# weighted avg       0.70      0.69      0.69      1494
#
#   Training Neural Network with Bagging Classifier
#     Accuracy: 0.7149
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.69      0.58      0.63       397
#      depresi       0.70      0.81      0.75       591
#        stres       0.76      0.70      0.73       506
#
#     accuracy                           0.71      1494
#    macro avg       0.72      0.70      0.70      1494
# weighted avg       0.72      0.71      0.71      1494
#
# Processing split 70:30
#   Training Naive Bayes with Bagging Classifier
#     Accuracy: 0.6664
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.66      0.49      0.56       304
#      depresi       0.64      0.79      0.71       439
#        stres       0.71      0.66      0.69       378
#
#     accuracy                           0.67      1121
#    macro avg       0.67      0.65      0.65      1121
# weighted avg       0.67      0.67      0.66      1121
#
#   Training KNN with Bagging Classifier
#     Accuracy: 0.6887
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.65      0.51      0.57       304
#      depresi       0.65      0.83      0.73       439
#        stres       0.79      0.66      0.72       378
#
#     accuracy                           0.69      1121
#    macro avg       0.70      0.67      0.67      1121
# weighted avg       0.70      0.69      0.68      1121
#
#   Training Random Forest with Bagging Classifier
#     Accuracy: 0.6949
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.71      0.50      0.58       304
#      depresi       0.66      0.81      0.73       439
#        stres       0.73      0.72      0.73       378
#
#     accuracy                           0.69      1121
#    macro avg       0.70      0.68      0.68      1121
# weighted avg       0.70      0.69      0.69      1121
#
#   Training Neural Network with Bagging Classifier
#     Accuracy: 0.7208
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.67      0.60      0.63       304
#      depresi       0.70      0.81      0.75       439
#        stres       0.79      0.72      0.75       378
#
#     accuracy                           0.72      1121
#    macro avg       0.72      0.71      0.71      1121
# weighted avg       0.72      0.72      0.72      1121
#
# Processing split 80:20
#   Training Naive Bayes with Bagging Classifier
#     Accuracy: 0.6519
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.66      0.46      0.54       202
#      depresi       0.62      0.79      0.69       286
#        stres       0.70      0.66      0.68       259
#
#     accuracy                           0.65       747
#    macro avg       0.66      0.63      0.64       747
# weighted avg       0.66      0.65      0.65       747
#
#   Training KNN with Bagging Classifier
#     Accuracy: 0.6801
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.66      0.53      0.59       202
#      depresi       0.64      0.84      0.72       286
#        stres       0.78      0.62      0.69       259
#
#     accuracy                           0.68       747
#    macro avg       0.69      0.66      0.67       747
# weighted avg       0.69      0.68      0.68       747
#
#   Training Random Forest with Bagging Classifier
#     Accuracy: 0.6948
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.71      0.50      0.58       202
#      depresi       0.65      0.84      0.73       286
#        stres       0.76      0.69      0.72       259
#
#     accuracy                           0.69       747
#    macro avg       0.71      0.68      0.68       747
# weighted avg       0.70      0.69      0.69       747
#
#   Training Neural Network with Bagging Classifier
#     Accuracy: 0.7108
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.66      0.57      0.62       202
#      depresi       0.68      0.83      0.75       286
#        stres       0.80      0.68      0.74       259
#
#     accuracy                           0.71       747
#    macro avg       0.71      0.70      0.70       747
# weighted avg       0.72      0.71      0.71       747
#
# Processing split 90:10
#   Training Naive Bayes with Bagging Classifier
#     Accuracy: 0.6497
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.71      0.45      0.56       110
#      depresi       0.58      0.82      0.68       131
#        stres       0.73      0.64      0.68       133
#
#     accuracy                           0.65       374
#    macro avg       0.67      0.64      0.64       374
# weighted avg       0.67      0.65      0.64       374
#
#   Training KNN with Bagging Classifier
#     Accuracy: 0.6684
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.69      0.54      0.60       110
#      depresi       0.59      0.85      0.70       131
#        stres       0.81      0.59      0.69       133
#
#     accuracy                           0.67       374
#    macro avg       0.70      0.66      0.66       374
# weighted avg       0.70      0.67      0.67       374
#
#   Training Random Forest with Bagging Classifier
#     Accuracy: 0.6979
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.76      0.52      0.62       110
#      depresi       0.63      0.86      0.73       131
#        stres       0.76      0.68      0.72       133
#
#     accuracy                           0.70       374
#    macro avg       0.72      0.69      0.69       374
# weighted avg       0.72      0.70      0.69       374
#
#   Training Neural Network with Bagging Classifier
#     Accuracy: 0.7059
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.70      0.59      0.64       110
#      depresi       0.65      0.82      0.72       131
#        stres       0.79      0.69      0.74       133
#
#     accuracy                           0.71       374
#    macro avg       0.71      0.70      0.70       374
# weighted avg       0.71      0.71      0.70       374

# %% [markdown]
# ## Menampilkan hasil model

# %%
import json

# Membaca file JSON
with open(path + f'{nama_ekstraksi}_bc_sv_experiment_results.json', 'r') as f:
    results = json.load(f)

# %% [markdown]
# ### Confusion Matrix (heatmap)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Known labels
labels = ["cemas", "depresi", "stres"]

# Set the figure size
plt.rcParams['figure.figsize'] = [20, 25]

# Create subplots for each confusion matrix
for i, (key, value) in enumerate(results.items()):
    cm = np.array(value['confusion_matrix'])
    plt.subplot(6, 4, i+1)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=labels, yticklabels=labels)
    plt.title(key)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.axis("on")

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Evaluasi kinerja model

# %%
# Inisialisasi list untuk menyimpan data
data = []

# Ekstrak split dan model dari keys di results
for key, value in results.items():
    model_name, split_info = key.split(f'_BC optimization_split')
    split_ratio = split_info.replace('_test', ':')
    accuracy = value['accuracy']

    # Tambahkan data ke dalam list
    data.append([split_ratio, model_name, accuracy])

# Konversi list ke DataFrame
accuracy_table = pd.DataFrame(data, columns=['Split', 'Model', 'Accuracy'])

# Pivot DataFrame agar model menjadi kolom
accuracy_table = accuracy_table.pivot(index='Split', columns='Model', values='Accuracy')

# Atur ulang kolom sesuai urutan yang diinginkan
accuracy_table = accuracy_table[['Naive Bayes', 'KNN', 'Random Forest', 'Neural Network']]

# Tampilkan tabel akurasi
accuracy_table
# Out:
# Model   Naive Bayes       KNN  Random Forest  Neural Network
# Split
#  60:40     0.661981  0.684070       0.694779        0.714859
#  70:30     0.666369  0.688671       0.694915        0.720785
#  80:20     0.651941  0.680054       0.694779        0.710843
#  90:10     0.649733  0.668449       0.697861        0.705882

# %%
# Initialize an empty list to store data for the DataFrame
data = []

# Extracting data for each model and split
for experiment_name, result in results.items():
    for label, metrics in result['classification_report'].items():
        if label not in ['accuracy', 'macro avg', 'weighted avg']:  # Skip overall metrics
            row = {
                'Experiment': experiment_name,
                'Label': label,
                'Precision': metrics['precision'],
                'Recall': metrics['recall'],
                'F1-Score': metrics['f1-score'],
                'Support': metrics['support']
            }
            data.append(row)

# Create DataFrame from the data list
df_results = pd.DataFrame(data)

# Display the first few rows of the DataFrame
df_results
# Out:
#                                     Experiment    Label  Precision    Recall  \
# 0      Naive Bayes_BC optimization_split 60:40    cemas   0.652174  0.453401
# 1      Naive Bayes_BC optimization_split 60:40  depresi   0.629435  0.810491
# 2      Naive Bayes_BC optimization_split 60:40    stres   0.722101  0.652174
# 3              KNN_BC optimization_split 60:40    cemas   0.650000  0.523929
# 4              KNN_BC optimization_split 60:40  depresi   0.646373  0.844332
# 5              KNN_BC optimization_split 60:40    stres   0.783582  0.622530
# 6    Random Forest_BC optimization_split 60:40    cemas   0.731801  0.481108
# 7    Random Forest_BC optimization_split 60:40  depresi   0.662602  0.827411
# 8    Random Forest_BC optimization_split 60:40    stres   0.723232  0.707510
# 9   Neural Network_BC optimization_split 60:40    cemas   0.688427  0.584383
# 10  Neural Network_BC optimization_split 60:40  depresi   0.698113  0.813875
# 11  Neural Network_BC optimization_split 60:40    stres   0.758547  0.701581
# 12     Naive Bayes_BC optimization_split 70:30    cemas   0.657778  0.486842
# 13     Naive Bayes_BC optimization_split 70:30  depresi   0.640367  0.794989
# 14     Naive Bayes_BC optimization_split 70:30    stres   0.712251  0.661376
# 15             KNN_BC optimization_split 70:30    cemas   0.650000  0.513158
# 16             KNN_BC optimization_split 70:30  depresi   0.647163  0.831435
# 17             KNN_BC optimization_split 70:30    stres   0.791798  0.664021
# 18   Random Forest_BC optimization_split 70:30    cemas   0.708920  0.496711
# 19   Random Forest_BC optimization_split 70:30  depresi   0.664165  0.806378
# 20   Random Forest_BC optimization_split 70:30    stres   0.730667  0.724868
# 21  Neural Network_BC optimization_split 70:30    cemas   0.672862  0.595395
# 22  Neural Network_BC optimization_split 70:30  depresi   0.702170  0.810934
# 23  Neural Network_BC optimization_split 70:30    stres   0.785507  0.716931
# 24     Naive Bayes_BC optimization_split 80:20    cemas   0.657143  0.455446
# 25     Naive Bayes_BC optimization_split 80:20  depresi   0.618132  0.786713
# 26     Naive Bayes_BC optimization_split 80:20    stres   0.699588  0.656371
# 27             KNN_BC optimization_split 80:20    cemas   0.660494  0.529703
# 28             KNN_BC optimization_split 80:20  depresi   0.635884  0.842657
# 29             KNN_BC optimization_split 80:20    stres   0.776699  0.617761
# 30   Random Forest_BC optimization_split 80:20    cemas   0.714286  0.495050
# 31   Random Forest_BC optimization_split 80:20  depresi   0.646900  0.839161
# 32   Random Forest_BC optimization_split 80:20    stres   0.758475  0.691120
# 33  Neural Network_BC optimization_split 80:20    cemas   0.662857  0.574257
# 34  Neural Network_BC optimization_split 80:20  depresi   0.680000  0.832168
# 35  Neural Network_BC optimization_split 80:20    stres   0.797297  0.683398
# 36     Naive Bayes_BC optimization_split 90:10    cemas   0.714286  0.454545
# 37     Naive Bayes_BC optimization_split 90:10  depresi   0.577540  0.824427
# 38     Naive Bayes_BC optimization_split 90:10    stres   0.726496  0.639098
# 39             KNN_BC optimization_split 90:10    cemas   0.686047  0.536364
# 40             KNN_BC optimization_split 90:10  depresi   0.586387  0.854962
# 41             KNN_BC optimization_split 90:10    stres   0.814433  0.593985
# 42   Random Forest_BC optimization_split 90:10    cemas   0.760000  0.518182
# 43   Random Forest_BC optimization_split 90:10  depresi   0.627778  0.862595
# 44   Random Forest_BC optimization_split 90:10    stres   0.764706  0.684211
# 45  Neural Network_BC optimization_split 90:10    cemas   0.698925  0.590909
# 46  Neural Network_BC optimization_split 90:10  depresi   0.648485  0.816794
# 47  Neural Network_BC optimization_split 90:10    stres   0.793103  0.691729
#
#     F1-Score  Support
# 0   0.534918    397.0
# 1   0.708580    591.0
# 2   0.685358    506.0
# 3   0.580195    397.0
# 4   0.732208    591.0
# 5   0.693833    506.0
# 6   0.580547    397.0
# 7   0.735892    591.0
# 8   0.715285    506.0
# 9   0.632153    397.0
# 10  0.751562    591.0
# 11  0.728953    506.0
# 12  0.559546    304.0
# 13  0.709350    439.0
# 14  0.685871    378.0
# 15  0.573529    304.0
# 16  0.727817    439.0
# 17  0.722302    378.0
# 18  0.584139    304.0
# 19  0.728395    439.0
# 20  0.727756    378.0
# 21  0.631763    304.0
# 22  0.752643    439.0
# 23  0.749654    378.0
# 24  0.538012    202.0
# 25  0.692308    286.0
# 26  0.677291    259.0
# 27  0.587912    202.0
# 28  0.724812    286.0
# 29  0.688172    259.0
# 30  0.584795    202.0
# 31  0.730594    286.0
# 32  0.723232    259.0
# 33  0.615385    202.0
# 34  0.748428    286.0
# 35  0.735967    259.0
# 36  0.555556    110.0
# 37  0.679245    131.0
# 38  0.680000    133.0
# 39  0.602041    110.0
# 40  0.695652    131.0
# 41  0.686957    133.0
# 42  0.616216    110.0
# 43  0.726688    131.0
# 44  0.722222    133.0
# 45  0.640394    110.0
# 46  0.722973    131.0
# 47  0.738956    133.0

# %% [markdown]
# # BC CrossV modelling

# %%
# Define models
models = {
    'Naive Bayes': GaussianNB(var_smoothing=1e-9),
    'KNN': KNeighborsClassifier(n_neighbors=10, weights='distance', algorithm='auto', p=2),
    'Random Forest': RandomForestClassifier(n_estimators=100, max_depth=15, min_samples_split=5, min_samples_leaf=2, bootstrap=True),
    'Neural Network': MLPClassifier(hidden_layer_sizes=(100, 50), activation='relu', solver='adam', learning_rate='adaptive', max_iter=1000, early_stopping=True, n_iter_no_change=5)
}

# Bagging classifier function
optimasi = 'BC optimization'
def get_bagging_clf(base_estimator):
    return BaggingClassifier(estimator=base_estimator, n_estimators=10, random_state=42, n_jobs=-1)

# %%
# Define cross-validation folds
kf_values = [5, 10]

# Initialize results dictionary
results = {}

for k in kf_values:
    print(f'Processing cross-validation with k={k}')

    for model_name, model in models.items():
        print(f'  Training {model_name} with Bagging Classifier')

        # Create Bagging Classifier with the current model
        bagging_clf = get_bagging_clf(model)

        # Cross-validation predictions
        y_pred = cross_val_predict(bagging_clf, fitur, y, cv=k)

        # Evaluation
        conf_matrix = confusion_matrix(y, y_pred)
        class_report = classification_report(y, y_pred, output_dict=True, zero_division=0)
        accuracy = accuracy_score(y, y_pred)

        # Convert key to string, similar to the split validation
        result_key = f"{model_name}_{optimasi}_cross_val_k{k}"

        # Save results in the format similar to split validation
        results[result_key] = {
            'confusion_matrix': conf_matrix.tolist(),  # Convert array to list
            'classification_report': class_report,
            'accuracy': accuracy
        }

        print(f'    Accuracy: {accuracy:.4f}')
        print('    Classification Report:')
        print(classification_report(y, y_pred, zero_division=0))

# Save results to a JSON file
with open(path + f'{nama_ekstraksi}_bc_cv_experiment_results.json', 'w') as f:
    json.dump(results, f, indent=4)
# Out:
# Processing cross-validation with k=5
#   Training Naive Bayes with Bagging Classifier
#     Accuracy: 0.6768
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.62      0.51      0.56       956
#      depresi       0.66      0.81      0.72      1456
#        stres       0.74      0.65      0.70      1323
#
#     accuracy                           0.68      3735
#    macro avg       0.67      0.66      0.66      3735
# weighted avg       0.68      0.68      0.67      3735
#
#   Training KNN with Bagging Classifier
#     Accuracy: 0.6905
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.64      0.50      0.56       956
#      depresi       0.65      0.85      0.74      1456
#        stres       0.79      0.65      0.71      1323
#
#     accuracy                           0.69      3735
#    macro avg       0.69      0.67      0.67      3735
# weighted avg       0.70      0.69      0.68      3735
#
#   Training Random Forest with Bagging Classifier
#     Accuracy: 0.7047
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.70      0.47      0.56       956
#      depresi       0.67      0.84      0.75      1456
#        stres       0.75      0.72      0.73      1323
#
#     accuracy                           0.70      3735
#    macro avg       0.71      0.68      0.68      3735
# weighted avg       0.71      0.70      0.70      3735
#
#   Training Neural Network with Bagging Classifier
#     Accuracy: 0.7207
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.67      0.57      0.62       956
#      depresi       0.71      0.83      0.76      1456
#        stres       0.77      0.71      0.74      1323
#
#     accuracy                           0.72      3735
#    macro avg       0.72      0.70      0.71      3735
# weighted avg       0.72      0.72      0.72      3735
#
# Processing cross-validation with k=10
#   Training Naive Bayes with Bagging Classifier
#     Accuracy: 0.6752
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.62      0.50      0.56       956
#      depresi       0.65      0.81      0.72      1456
#        stres       0.74      0.66      0.70      1323
#
#     accuracy                           0.68      3735
#    macro avg       0.67      0.65      0.66      3735
# weighted avg       0.68      0.68      0.67      3735
#
#   Training KNN with Bagging Classifier
#     Accuracy: 0.6902
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.64      0.51      0.57       956
#      depresi       0.66      0.85      0.74      1456
#        stres       0.78      0.64      0.71      1323
#
#     accuracy                           0.69      3735
#    macro avg       0.69      0.67      0.67      3735
# weighted avg       0.70      0.69      0.68      3735
#
#   Training Random Forest with Bagging Classifier
#     Accuracy: 0.7071
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.71      0.48      0.57       956
#      depresi       0.68      0.84      0.75      1456
#        stres       0.75      0.72      0.73      1323
#
#     accuracy                           0.71      3735
#    macro avg       0.71      0.68      0.69      3735
# weighted avg       0.71      0.71      0.70      3735
#
#   Training Neural Network with Bagging Classifier
#     Accuracy: 0.7264
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.67      0.60      0.63       956
#      depresi       0.72      0.81      0.76      1456
#        stres       0.77      0.73      0.75      1323
#
#     accuracy                           0.73      3735
#    macro avg       0.72      0.71      0.71      3735
# weighted avg       0.73      0.73      0.72      3735

# %% [markdown]
# ## Menampilkan hasil model

# %%
import json

# Membaca file JSON
with open(path + f'{nama_ekstraksi}_bc_cv_experiment_results.json', 'r') as f:
    results = json.load(f)

# %% [markdown]
# ### Confusion Matrix (heatmap)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Known labels
labels = ["cemas", "depresi", "stres"]

# Set the figure size
plt.rcParams['figure.figsize'] = [20, 25]

# Create subplots for each confusion matrix
for i, (key, value) in enumerate(results.items()):
    # if i >= 20:  # Limit to 20 subplots (5 rows x 4 columns)
    #     break
    cm = np.array(value['confusion_matrix'])
    plt.subplot(6, 4, i+1)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=labels, yticklabels=labels)
    plt.title(key)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.axis("on")

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Evaluasi kinerja model

# %%
# Inisialisasi list untuk menyimpan data
data = []

# Ekstrak split dan model dari keys di results
for key, value in results.items():
    model_name, split_info = key.split(f'_k')
    split_ratio = split_info.replace('cross_val_', '')
    accuracy = value['accuracy']

    # Tambahkan data ke dalam list
    data.append([split_ratio, model_name, accuracy])

# Konversi list ke DataFrame
accuracy_table = pd.DataFrame(data, columns=['K-Fold', 'Model', 'Accuracy'])

# Pivot DataFrame agar model menjadi kolom
accuracy_table = accuracy_table.pivot(index='K-Fold', columns='Model', values='Accuracy')

# Rename columns to remove the extra text
accuracy_table.columns = accuracy_table.columns.str.replace('_BC optimization_cross_val', '')

# Atur ulang kolom sesuai urutan yang diinginkan
accuracy_table = accuracy_table[['Naive Bayes', 'KNN', 'Random Forest', 'Neural Network']]

# Tampilkan tabel akurasi
accuracy_table
# Out:
# Model   Naive Bayes       KNN  Random Forest  Neural Network
# K-Fold
# 10         0.675234  0.690228       0.707095        0.726372
# 5          0.676841  0.690495       0.704685        0.720750

# %%
# Initialize an empty list to store data for the DataFrame
data = []

# Extracting data for each model and split
for experiment_name, result in results.items():
    for label, metrics in result['classification_report'].items():
        if label not in ['accuracy', 'macro avg', 'weighted avg']:  # Skip overall metrics
            row = {
                'Experiment': experiment_name,
                'Label': label,
                'Precision': metrics['precision'],
                'Recall': metrics['recall'],
                'F1-Score': metrics['f1-score'],
                'Support': metrics['support']
            }
            data.append(row)

# Create DataFrame from the data list
df_results = pd.DataFrame(data)

# Display the first few rows of the DataFrame
df_results
# Out:
#                                       Experiment    Label  Precision  \
# 0       Naive Bayes_BC optimization_cross_val_k5    cemas   0.622137
# 1       Naive Bayes_BC optimization_cross_val_k5  depresi   0.656967
# 2       Naive Bayes_BC optimization_cross_val_k5    stres   0.744406
# 3               KNN_BC optimization_cross_val_k5    cemas   0.637816
# 4               KNN_BC optimization_cross_val_k5  depresi   0.654048
# 5               KNN_BC optimization_cross_val_k5    stres   0.791128
# 6     Random Forest_BC optimization_cross_val_k5    cemas   0.703588
# 7     Random Forest_BC optimization_cross_val_k5  depresi   0.674904
# 8     Random Forest_BC optimization_cross_val_k5    stres   0.747840
# 9    Neural Network_BC optimization_cross_val_k5    cemas   0.670747
# 10   Neural Network_BC optimization_cross_val_k5  depresi   0.708309
# 11   Neural Network_BC optimization_cross_val_k5    stres   0.771499
# 12     Naive Bayes_BC optimization_cross_val_k10    cemas   0.623698
# 13     Naive Bayes_BC optimization_cross_val_k10  depresi   0.652222
# 14     Naive Bayes_BC optimization_cross_val_k10    stres   0.744644
# 15             KNN_BC optimization_cross_val_k10    cemas   0.644562
# 16             KNN_BC optimization_cross_val_k10  depresi   0.656267
# 17             KNN_BC optimization_cross_val_k10    stres   0.780734
# 18   Random Forest_BC optimization_cross_val_k10    cemas   0.707430
# 19   Random Forest_BC optimization_cross_val_k10  depresi   0.678631
# 20   Random Forest_BC optimization_cross_val_k10    stres   0.747261
# 21  Neural Network_BC optimization_cross_val_k10    cemas   0.673709
# 22  Neural Network_BC optimization_cross_val_k10  depresi   0.720318
# 23  Neural Network_BC optimization_cross_val_k10    stres   0.770216
#
#       Recall  F1-Score  Support
# 0   0.511506  0.561424    956.0
# 1   0.806319  0.724021   1456.0
# 2   0.653817  0.696177   1323.0
# 3   0.501046  0.561219    956.0
# 4   0.854396  0.740917   1456.0
# 5   0.647014  0.711850   1323.0
# 6   0.471757  0.564809    956.0
# 7   0.844093  0.750076   1456.0
# 8   0.719577  0.733436   1323.0
# 9   0.573222  0.618161    956.0
# 10  0.825549  0.762448   1456.0
# 11  0.712018  0.740566   1323.0
# 12  0.501046  0.555684    956.0
# 13  0.806319  0.721130   1456.0
# 14  0.656841  0.697992   1323.0
# 15  0.508368  0.568421    956.0
# 16  0.852335  0.741560   1456.0
# 17  0.643235  0.705346   1323.0
# 18  0.478033  0.570537    956.0
# 19  0.844093  0.752372   1456.0
# 20  0.721844  0.734333   1323.0
# 21  0.600418  0.634956    956.0
# 22  0.808379  0.761812   1456.0
# 23  0.727135  0.748056   1323.0

# %% [markdown]
# # GA SplitV modelling

# %%
models = {
    'Naive Bayes': GaussianNB(),
    'KNN': KNeighborsClassifier(),
    'Random Forest': RandomForestClassifier(),
    'Neural Network': MLPClassifier()
}
optimasi = 'GA optimization'

# %%
splits = [(0.6, 0.4), (0.7, 0.3), (0.8, 0.2), (0.9, 0.1)]
results = {}

def get_ga_search(model):
    param_grids = {
        'GaussianNB': {'var_smoothing': Continuous(1e-9, 1e-7, distribution='log-uniform')},
        'KNeighborsClassifier': {'n_neighbors': Integer(10, 30), 'weights': Categorical(['distance']), 'p': Integer(1, 2)},
        'RandomForestClassifier': {'n_estimators': Integer(50, 100), 'max_depth': Integer(10, 20)},
        'MLPClassifier': {'hidden_layer_sizes': Categorical([(100,), (100, 50)]), 'learning_rate_init': Continuous(0.001, 0.005), 'learning_rate': Categorical(['adaptive']), 'early_stopping': Categorical([True])}
    }

    model_name = type(model).__name__
    if model_name not in param_grids:
        raise ValueError(f"Parameter grid for {model_name} not defined")

    ga_search = GASearchCV(
        estimator=model,
        param_grid=param_grids[type(model).__name__],
        scoring='accuracy',
        cv=3,
        n_jobs=-1,
        verbose=True,
        population_size=20,
        generations=4
    )
    return ga_search

# %%
for train_size, test_size in splits:
    print(f'Processing split {int(train_size*100)}:{int(test_size*100)}')

    # Split data
    X_train, X_test, y_train, y_test = train_test_split(fitur, y, test_size=test_size, random_state=42)

    for model_name, model in models.items():
        print(f'  Training {model_name} with GASearchCV')

        # Create GASearchCV with the current model
        ga_search = get_ga_search(model)
        ga_search.fit(X_train, y_train)
        y_pred = ga_search.predict(X_test)

        # Evaluation
        conf_matrix = confusion_matrix(y_test, y_pred)
        class_report = classification_report(y_test, y_pred, output_dict=True, zero_division=0)
        accuracy = accuracy_score(y_test, y_pred)

        # Convert tuple key to string
        result_key = f"{model_name}_{optimasi}_split {int(train_size*100)}:{int(test_size*100)}"

        # Save results
        results[result_key] = {
            'best_params': ga_search.best_params_,
            'confusion_matrix': conf_matrix.tolist(),
            'classification_report': class_report,
            'accuracy': accuracy
        }

        print(f'    Accuracy: {accuracy:.4f}')
        print('    Best Params:', ga_search.best_params_)
        print('    Classification Report:')
        print(classification_report(y_test, y_pred, zero_division=0))

# Save results to a JSON file
with open(path + f'{nama_ekstraksi}_ga_sv_experiment_results.json', 'w') as f:
    json.dump(results, f, indent=4)
# Out:
# Processing split 60:40
#   Training Naive Bayes with GASearchCV
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.664436	1.11022e-16	0.664436   	0.664436
# 1  	40    	0.664436	1.11022e-16	0.664436   	0.664436
# 2  	40    	0.664436	1.11022e-16	0.664436   	0.664436
# 3  	40    	0.664436	1.11022e-16	0.664436   	0.664436
# 4  	40    	0.664436	1.11022e-16	0.664436   	0.664436
#     Accuracy: 0.6647
#     Best Params: {'var_smoothing': 6.2927834761381796e-09}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.65      0.47      0.55       397
#      depresi       0.64      0.81      0.71       591
#        stres       0.72      0.65      0.68       506
#
#     accuracy                           0.66      1494
#    macro avg       0.67      0.64      0.65      1494
# weighted avg       0.67      0.66      0.66      1494
#
#   Training KNN with GASearchCV
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.672624	0.00416281 	0.679607   	0.662651
# 1  	40    	0.676417	0.00235816 	0.679607   	0.671575
# 2  	40    	0.678001	0.00164198 	0.679607   	0.675591
# 3  	40    	0.678893	0.00138547 	0.679607   	0.675591
# 4  	40    	0.679607	0          	0.679607   	0.679607
#     Accuracy: 0.6867
#     Best Params: {'n_neighbors': 17, 'weights': 'distance', 'p': 2}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.67      0.51      0.58       397
#      depresi       0.64      0.86      0.73       591
#        stres       0.80      0.62      0.70       506
#
#     accuracy                           0.69      1494
#    macro avg       0.70      0.66      0.67      1494
# weighted avg       0.70      0.69      0.68      1494
#
#   Training Random Forest with GASearchCV
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.693039	0.0047138  	0.700134   	0.68407
# 1  	40    	0.697233	0.0033018  	0.702811   	0.688532
# 2  	40    	0.697925	0.00177078 	0.701473   	0.695225
# 3  	40    	0.699777	0.00182136 	0.701919   	0.69701
# 4  	40    	0.699554	0.00223605 	0.701919   	0.692102
#     Accuracy: 0.7001
#     Best Params: {'n_estimators': 74, 'max_depth': 20}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.72      0.52      0.60       397
#      depresi       0.68      0.81      0.74       591
#        stres       0.73      0.71      0.72       506
#
#     accuracy                           0.70      1494
#    macro avg       0.71      0.68      0.69      1494
# weighted avg       0.70      0.70      0.70      1494
#
#   Training Neural Network with GASearchCV
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.705823	0.0059716  	0.717537   	0.69701
# 1  	40    	0.714123	0.00319381 	0.717537   	0.706381
# 2  	40    	0.713588	0.00458179 	0.717537   	0.701473
# 3  	40    	0.714703	0.00344284 	0.717537   	0.706827
# 4  	40    	0.712249	0.0040513  	0.717537   	0.706381
#     Accuracy: 0.7082
#     Best Params: {'hidden_layer_sizes': (100,), 'learning_rate_init': 0.001969535806972538, 'learning_rate': 'adaptive', 'early_stopping': True}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.72      0.52      0.60       397
#      depresi       0.69      0.83      0.75       591
#        stres       0.74      0.71      0.72       506
#
#     accuracy                           0.71      1494
#    macro avg       0.71      0.69      0.69      1494
# weighted avg       0.71      0.71      0.70      1494
#
# Processing split 70:30
#   Training Naive Bayes with GASearchCV
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.667562	1.11022e-16	0.667562   	0.667562
# 1  	40    	0.667562	1.11022e-16	0.667562   	0.667562
# 2  	40    	0.667562	1.11022e-16	0.667562   	0.667562
# 3  	40    	0.667562	1.11022e-16	0.667562   	0.667562
# 4  	40    	0.667562	1.11022e-16	0.667562   	0.667562
#     Accuracy: 0.6619
#     Best Params: {'var_smoothing': 1.1904345220795588e-08}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.65      0.47      0.55       304
#      depresi       0.63      0.79      0.70       439
#        stres       0.71      0.66      0.69       378
#
#     accuracy                           0.66      1121
#    macro avg       0.67      0.64      0.65      1121
# weighted avg       0.67      0.66      0.66      1121
#
#   Training KNN with GASearchCV
# gen	nevals	fitness	fitness_std	fitness_max	fitness_min
# 0  	20    	0.68313	0.00206067 	0.687838   	0.679039
# 1  	40    	0.684967	0.00150325 	0.687834   	0.682864
# 2  	40    	0.686   	0.00200373 	0.690895   	0.683247
# 3  	40    	0.688103	0.00209511 	0.690895   	0.684011
# 4  	40    	0.690283	0.00122368 	0.690895   	0.687834
#     Accuracy: 0.6753
#     Best Params: {'n_neighbors': 15, 'weights': 'distance', 'p': 2}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.66      0.49      0.56       304
#      depresi       0.62      0.85      0.72       439
#        stres       0.79      0.63      0.70       378
#
#     accuracy                           0.68      1121
#    macro avg       0.69      0.65      0.66      1121
# weighted avg       0.69      0.68      0.67      1121
#
#   Training Random Forest with GASearchCV
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.702529	0.00457212 	0.711557   	0.689752
# 1  	40    	0.706106	0.00391824 	0.711557   	0.698168
# 2  	40    	0.705972	0.00257919 	0.710792   	0.701994
# 3  	40    	0.706622	0.00263429 	0.71194    	0.70276
# 4  	40    	0.707388	0.00322556 	0.71194    	0.699314
#     Accuracy: 0.6976
#     Best Params: {'n_estimators': 83, 'max_depth': 16}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.70      0.52      0.60       304
#      depresi       0.68      0.80      0.73       439
#        stres       0.73      0.72      0.72       378
#
#     accuracy                           0.70      1121
#    macro avg       0.70      0.68      0.68      1121
# weighted avg       0.70      0.70      0.69      1121
#
#   Training Neural Network with GASearchCV
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.712283	0.00731787 	0.72418    	0.692038
# 1  	40    	0.716358	0.00279572 	0.719976   	0.708106
# 2  	40    	0.718998	0.00331048 	0.725712   	0.714235
# 3  	40    	0.718463	0.00449853 	0.725712   	0.709645
# 4  	40    	0.71745 	0.00436152 	0.725712   	0.708112
#     Accuracy: 0.7038
#     Best Params: {'hidden_layer_sizes': (100,), 'learning_rate_init': 0.0020779399514143965, 'learning_rate': 'adaptive', 'early_stopping': True}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.71      0.49      0.58       304
#      depresi       0.67      0.84      0.74       439
#        stres       0.76      0.72      0.74       378
#
#     accuracy                           0.70      1121
#    macro avg       0.71      0.68      0.69      1121
# weighted avg       0.71      0.70      0.70      1121
#
# Processing split 80:20
#   Training Naive Bayes with GASearchCV
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.671352	1.11022e-16	0.671352   	0.671352
# 1  	40    	0.671352	1.11022e-16	0.671352   	0.671352
# 2  	40    	0.671352	1.11022e-16	0.671352   	0.671352
# 3  	40    	0.671352	1.11022e-16	0.671352   	0.671352
# 4  	40    	0.671352	1.11022e-16	0.671352   	0.671352
#     Accuracy: 0.6506
#     Best Params: {'var_smoothing': 2.2746617457531454e-09}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.67      0.45      0.53       202
#      depresi       0.61      0.79      0.69       286
#        stres       0.70      0.65      0.67       259
#
#     accuracy                           0.65       747
#    macro avg       0.66      0.63      0.63       747
# weighted avg       0.66      0.65      0.64       747
#
#   Training KNN with GASearchCV
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.686094	0.00373946 	0.692102   	0.680723
# 1  	40    	0.688989	0.00261409 	0.692102   	0.6834
# 2  	40    	0.690161	0.00179167 	0.692102   	0.687082
# 3  	40    	0.691717	0.00130597 	0.69411    	0.68842
# 4  	40    	0.69252 	0.0010682  	0.69411    	0.690428
#     Accuracy: 0.6640
#     Best Params: {'n_neighbors': 10, 'weights': 'distance', 'p': 2}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.64      0.48      0.54       202
#      depresi       0.61      0.84      0.71       286
#        stres       0.78      0.62      0.69       259
#
#     accuracy                           0.66       747
#    macro avg       0.68      0.64      0.65       747
# weighted avg       0.68      0.66      0.66       747
#
#   Training Random Forest with GASearchCV
# gen	nevals	fitness	fitness_std	fitness_max	fitness_min
# 0  	20    	0.70077	0.00387252 	0.708835   	0.691767
# 1  	40    	0.703865	0.00317899 	0.709839   	0.699799
# 2  	40    	0.70574 	0.00300064 	0.711513   	0.701473
# 3  	40    	0.70594 	0.00182166 	0.709839   	0.702811
# 4  	40    	0.706677	0.00240749 	0.712182   	0.702811
#     Accuracy: 0.6867
#     Best Params: {'n_estimators': 99, 'max_depth': 18}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.70      0.50      0.58       202
#      depresi       0.65      0.81      0.72       286
#        stres       0.73      0.69      0.71       259
#
#     accuracy                           0.69       747
#    macro avg       0.69      0.67      0.67       747
# weighted avg       0.69      0.69      0.68       747
#
#   Training Neural Network with GASearchCV
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.713688	0.00618781 	0.726238   	0.702811
# 1  	40    	0.720465	0.0036812  	0.726238   	0.712851
# 2  	40    	0.72177 	0.00259727 	0.726238   	0.717871
# 3  	40    	0.722055	0.00365621 	0.726238   	0.713521
# 4  	40    	0.724632	0.003028   	0.729585   	0.717202
#     Accuracy: 0.7122
#     Best Params: {'hidden_layer_sizes': (100, 50), 'learning_rate_init': 0.001011067752529676, 'learning_rate': 'adaptive', 'early_stopping': True}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.67      0.55      0.61       202
#      depresi       0.68      0.84      0.75       286
#        stres       0.79      0.69      0.74       259
#
#     accuracy                           0.71       747
#    macro avg       0.72      0.70      0.70       747
# weighted avg       0.72      0.71      0.71       747
#
# Processing split 90:10
#   Training Naive Bayes with GASearchCV
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.670337	1.11022e-16	0.670337   	0.670337
# 1  	40    	0.670337	1.11022e-16	0.670337   	0.670337
# 2  	40    	0.670337	1.11022e-16	0.670337   	0.670337
# 3  	40    	0.670337	1.11022e-16	0.670337   	0.670337
# 4  	40    	0.670337	1.11022e-16	0.670337   	0.670337
#     Accuracy: 0.6471
#     Best Params: {'var_smoothing': 4.070403420374771e-09}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.71      0.45      0.55       110
#      depresi       0.58      0.82      0.68       131
#        stres       0.72      0.65      0.68       133
#
#     accuracy                           0.65       374
#    macro avg       0.67      0.64      0.64       374
# weighted avg       0.67      0.65      0.64       374
#
#   Training KNN with GASearchCV
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.683502	0.00260039 	0.690567   	0.680154
# 1  	40    	0.685718	0.0025664  	0.69265    	0.682832
# 2  	40    	0.686998	0.00232728 	0.69265    	0.68432
# 3  	40    	0.688277	0.00226194 	0.69265    	0.68432
# 4  	40    	0.689719	0.00191495 	0.69265    	0.686699
#     Accuracy: 0.6658
#     Best Params: {'n_neighbors': 13, 'weights': 'distance', 'p': 2}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.68      0.53      0.59       110
#      depresi       0.58      0.85      0.69       131
#        stres       0.82      0.60      0.70       133
#
#     accuracy                           0.67       374
#    macro avg       0.70      0.66      0.66       374
# weighted avg       0.70      0.67      0.66       374
#
#   Training Random Forest with GASearchCV
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.697427	0.00344471 	0.702768   	0.68938
# 1  	40    	0.700908	0.00241629 	0.704551   	0.696522
# 2  	40    	0.702545	0.00169108 	0.705446   	0.6989
# 3  	40    	0.702768	0.00207852 	0.70604    	0.699793
# 4  	40    	0.704761	0.00184604 	0.707826   	0.700983
#     Accuracy: 0.7086
#     Best Params: {'n_estimators': 86, 'max_depth': 20}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.73      0.55      0.62       110
#      depresi       0.64      0.84      0.73       131
#        stres       0.79      0.71      0.75       133
#
#     accuracy                           0.71       374
#    macro avg       0.72      0.70      0.70       374
# weighted avg       0.72      0.71      0.70       374
#
#   Training Neural Network with GASearchCV
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.710517	0.00563333 	0.719729   	0.70128
# 1  	40    	0.716838	0.00217204 	0.719125   	0.711094
# 2  	40    	0.718653	0.001901   	0.722404   	0.713776
# 3  	40    	0.719962	0.00172096 	0.722698   	0.715261
# 4  	40    	0.719411	0.00352054 	0.727161   	0.71169
#     Accuracy: 0.7166
#     Best Params: {'hidden_layer_sizes': (100, 50), 'learning_rate_init': 0.002021593301094521, 'learning_rate': 'adaptive', 'early_stopping': True}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.73      0.56      0.64       110
#      depresi       0.64      0.87      0.74       131
#        stres       0.84      0.69      0.76       133
#
#     accuracy                           0.72       374
#    macro avg       0.73      0.71      0.71       374
# weighted avg       0.74      0.72      0.71       374

# %% [markdown]
# ## Menampilkan hasil model

# %%
import json

# Membaca file JSON
with open(path + f'{nama_ekstraksi}_ga_sv_experiment_results.json', 'r') as f:
    results = json.load(f)

# %% [markdown]
# ### Confusion Matrix (heatmap)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Known labels
labels = ["cemas", "depresi", "stres"]

# Set the figure size
plt.rcParams['figure.figsize'] = [20, 25]

# Create subplots for each confusion matrix
for i, (key, value) in enumerate(results.items()):
    cm = np.array(value['confusion_matrix'])
    plt.subplot(6, 4, i+1)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=labels, yticklabels=labels)
    plt.title(key)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.axis("on")

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Evaluasi kinerja model

# %%
# Inisialisasi list untuk menyimpan data
data = []

# Ekstrak split dan model dari keys di results
for key, value in results.items():
    model_name, split_info = key.split(f'_split ')
    split_ratio = split_info.replace('split ', '')
    accuracy = value['accuracy']

    # Tambahkan data ke dalam list
    data.append([split_ratio, model_name, accuracy])

# Konversi list ke DataFrame
accuracy_table = pd.DataFrame(data, columns=['Split', 'Model', 'Accuracy'])

# Pivot DataFrame agar model menjadi kolom
accuracy_table = accuracy_table.pivot(index='Split', columns='Model', values='Accuracy')

# Rename columns to remove the extra text
accuracy_table.columns = accuracy_table.columns.str.replace('_GA optimization', '')

# Atur ulang kolom sesuai urutan yang diinginkan
accuracy_table = accuracy_table[['Naive Bayes', 'KNN', 'Random Forest', 'Neural Network']]

# Tampilkan tabel akurasi
accuracy_table
# Out:
# Model  Naive Bayes       KNN  Random Forest  Neural Network
# Split
# 60:40     0.664659  0.686747       0.700134        0.708166
# 70:30     0.661909  0.675290       0.697591        0.703836
# 80:20     0.650602  0.663989       0.686747        0.712182
# 90:10     0.647059  0.665775       0.708556        0.716578

# %%
print(accuracy_table.columns)
# Out:
# Index(['Naive Bayes', 'KNN', 'Random Forest', 'Neural Network'], dtype='object', name='Model')

# %%
# Initialize an empty list to store data for the DataFrame
data = []

# Extracting data for each model and split
for experiment_name, result in results.items():
    for label, metrics in result['classification_report'].items():
        if label not in ['accuracy', 'macro avg', 'weighted avg']:  # Skip overall metrics
            row = {
                'Experiment': experiment_name,
                'Label': label,
                'Precision': metrics['precision'],
                'Recall': metrics['recall'],
                'F1-Score': metrics['f1-score'],
                'Support': metrics['support']
            }
            data.append(row)

# Create DataFrame from the data list
df_results = pd.DataFrame(data)

# Display the first few rows of the DataFrame
df_results
# Out:
#                                     Experiment    Label  Precision    Recall  \
# 0      Naive Bayes_GA optimization_split 60:40    cemas   0.652632  0.468514
# 1      Naive Bayes_GA optimization_split 60:40  depresi   0.635279  0.810491
# 2      Naive Bayes_GA optimization_split 60:40    stres   0.720879  0.648221
# 3              KNN_GA optimization_split 60:40    cemas   0.674497  0.506297
# 4              KNN_GA optimization_split 60:40  depresi   0.637157  0.864636
# 5              KNN_GA optimization_split 60:40    stres   0.796954  0.620553
# 6    Random Forest_GA optimization_split 60:40    cemas   0.715278  0.518892
# 7    Random Forest_GA optimization_split 60:40  depresi   0.676056  0.812183
# 8    Random Forest_GA optimization_split 60:40    stres   0.725806  0.711462
# 9   Neural Network_GA optimization_split 60:40    cemas   0.716263  0.521411
# 10  Neural Network_GA optimization_split 60:40  depresi   0.686275  0.829103
# 11  Neural Network_GA optimization_split 60:40    stres   0.735234  0.713439
# 12     Naive Bayes_GA optimization_split 70:30    cemas   0.652968  0.470395
# 13     Naive Bayes_GA optimization_split 70:30  depresi   0.632727  0.792711
# 14     Naive Bayes_GA optimization_split 70:30    stres   0.713068  0.664021
# 15             KNN_GA optimization_split 70:30    cemas   0.659292  0.490132
# 16             KNN_GA optimization_split 70:30  depresi   0.624579  0.845103
# 17             KNN_GA optimization_split 70:30    stres   0.787375  0.626984
# 18   Random Forest_GA optimization_split 70:30    cemas   0.703540  0.523026
# 19   Random Forest_GA optimization_split 70:30  depresi   0.675000  0.799544
# 20   Random Forest_GA optimization_split 70:30    stres   0.725333  0.719577
# 21  Neural Network_GA optimization_split 70:30    cemas   0.710900  0.493421
# 22  Neural Network_GA optimization_split 70:30  depresi   0.667273  0.835991
# 23  Neural Network_GA optimization_split 70:30    stres   0.755556  0.719577
# 24     Naive Bayes_GA optimization_split 80:20    cemas   0.666667  0.445545
# 25     Naive Bayes_GA optimization_split 80:20  depresi   0.613514  0.793706
# 26     Naive Bayes_GA optimization_split 80:20    stres   0.698347  0.652510
# 27             KNN_GA optimization_split 80:20    cemas   0.635762  0.475248
# 28             KNN_GA optimization_split 80:20  depresi   0.614396  0.835664
# 29             KNN_GA optimization_split 80:20    stres   0.777778  0.621622
# 30   Random Forest_GA optimization_split 80:20    cemas   0.701389  0.500000
# 31   Random Forest_GA optimization_split 80:20  depresi   0.653521  0.811189
# 32   Random Forest_GA optimization_split 80:20    stres   0.725806  0.694981
# 33  Neural Network_GA optimization_split 80:20    cemas   0.674699  0.554455
# 34  Neural Network_GA optimization_split 80:20  depresi   0.677966  0.839161
# 35  Neural Network_GA optimization_split 80:20    stres   0.792952  0.694981
# 36     Naive Bayes_GA optimization_split 90:10    cemas   0.710145  0.445455
# 37     Naive Bayes_GA optimization_split 90:10  depresi   0.575269  0.816794
# 38     Naive Bayes_GA optimization_split 90:10    stres   0.722689  0.646617
# 39             KNN_GA optimization_split 90:10    cemas   0.682353  0.527273
# 40             KNN_GA optimization_split 90:10  depresi   0.578125  0.847328
# 41             KNN_GA optimization_split 90:10    stres   0.824742  0.601504
# 42   Random Forest_GA optimization_split 90:10    cemas   0.731707  0.545455
# 43   Random Forest_GA optimization_split 90:10  depresi   0.643275  0.839695
# 44   Random Forest_GA optimization_split 90:10    stres   0.785124  0.714286
# 45  Neural Network_GA optimization_split 90:10    cemas   0.729412  0.563636
# 46  Neural Network_GA optimization_split 90:10  depresi   0.636872  0.870229
# 47  Neural Network_GA optimization_split 90:10    stres   0.836364  0.691729
#
#     F1-Score  Support
# 0   0.545455    397.0
# 1   0.712268    591.0
# 2   0.682622    506.0
# 3   0.578417    397.0
# 4   0.733668    591.0
# 5   0.697778    506.0
# 6   0.601460    397.0
# 7   0.737894    591.0
# 8   0.718563    506.0
# 9   0.603499    397.0
# 10  0.750958    591.0
# 11  0.724173    506.0
# 12  0.546845    304.0
# 13  0.703741    439.0
# 14  0.687671    378.0
# 15  0.562264    304.0
# 16  0.718296    439.0
# 17  0.698085    378.0
# 18  0.600000    304.0
# 19  0.732013    439.0
# 20  0.722444    378.0
# 21  0.582524    304.0
# 22  0.742164    439.0
# 23  0.737127    378.0
# 24  0.534125    202.0
# 25  0.692073    286.0
# 26  0.674651    259.0
# 27  0.543909    202.0
# 28  0.708148    286.0
# 29  0.690987    259.0
# 30  0.583815    202.0
# 31  0.723869    286.0
# 32  0.710059    259.0
# 33  0.608696    202.0
# 34  0.750000    286.0
# 35  0.740741    259.0
# 36  0.547486    110.0
# 37  0.675079    131.0
# 38  0.682540    133.0
# 39  0.594872    110.0
# 40  0.687307    131.0
# 41  0.695652    133.0
# 42  0.625000    110.0
# 43  0.728477    131.0
# 44  0.748031    133.0
# 45  0.635897    110.0
# 46  0.735484    131.0
# 47  0.757202    133.0

# %% [markdown]
# # GA CrossV modelling

# %%
models = {
    'Naive Bayes': GaussianNB(),
    'KNN': KNeighborsClassifier(),
    'Random Forest': RandomForestClassifier(),
    'Neural Network': MLPClassifier()
}
optimasi = 'GA optimization'

# %%
def get_ga_search(model):
    param_grids = {
        'GaussianNB': {'var_smoothing': Continuous(1e-9, 1e-7, distribution='log-uniform')},
        'KNeighborsClassifier': {'n_neighbors': Integer(10, 30), 'weights': Categorical(['distance']), 'p': Integer(1, 2)},
        'RandomForestClassifier': {'n_estimators': Integer(50, 100), 'max_depth': Integer(10, 20)},
        'MLPClassifier': {'hidden_layer_sizes': Categorical([(100,), (100, 50)]), 'learning_rate_init': Continuous(0.001, 0.005), 'learning_rate': Categorical(['adaptive']), 'early_stopping': Categorical([True])}
    }

    model_name = type(model).__name__
    if model_name not in param_grids:
        raise ValueError(f"Parameter grid for {model_name} not defined")

    ga_search = GASearchCV(
        estimator=model,
        param_grid=param_grids[type(model).__name__],
        scoring='accuracy',
        cv=3,
        n_jobs=-1,
        verbose=True,
        population_size=20,
        generations=4
    )
    return ga_search

# %%
# Nilai k untuk Cross Validation
k_values = [5, 10]

results = {}

for k in k_values:
    for model_name, model in models.items():
        print(f'Training {model_name} with GASearchCV and Cross Validation (k={k})')

        # Create GASearchCV with the current model
        ga_search = get_ga_search(model)
        ga_search.fit(fitur, y)

        # Cross validation predictions with k-fold
        y_pred = cross_val_predict(ga_search.best_estimator_, fitur, y, cv=k)

        # Evaluation
        conf_matrix = confusion_matrix(y, y_pred)
        class_report = classification_report(y, y_pred, output_dict=True, zero_division=0)
        accuracy = accuracy_score(y, y_pred)

        # Convert model name and k value to a valid JSON key
        result_key = f"{model_name}_{optimasi}_cross_val_k{k}"

        # Save results
        results[result_key] = {
            'best_params': ga_search.best_params_,
            'confusion_matrix': conf_matrix.tolist(),
            'classification_report': class_report,
            'accuracy': accuracy
        }

        print(f'    Accuracy: {accuracy:.4f}')
        print('    Best Params:', ga_search.best_params_)
        print('    Classification Report:')
        print(classification_report(y, y_pred, zero_division=0))

# Save results to a JSON file
with open(path + f'{nama_ekstraksi}_ga_cv_experiment_results.json', 'w') as f:
    json.dump(results, f, indent=4)
# Out:
# Training Naive Bayes with GASearchCV and Cross Validation (k=5)
# gen	nevals	fitness	fitness_std	fitness_max	fitness_min
# 0  	20    	0.67577	1.11022e-16	0.67577    	0.67577
# 1  	40    	0.67577	1.11022e-16	0.67577    	0.67577
# 2  	40    	0.67577	1.11022e-16	0.67577    	0.67577
# 3  	40    	0.67577	1.11022e-16	0.67577    	0.67577
# 4  	40    	0.67577	1.11022e-16	0.67577    	0.67577
#     Accuracy: 0.6728
#     Best Params: {'var_smoothing': 8.193135425690236e-09}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.62      0.49      0.55       956
#      depresi       0.65      0.81      0.72      1456
#        stres       0.74      0.65      0.69      1323
#
#     accuracy                           0.67      3735
#    macro avg       0.67      0.65      0.65      3735
# weighted avg       0.68      0.67      0.67      3735
#
# Training KNN with GASearchCV and Cross Validation (k=5)
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.689572	0.00342921 	0.695315   	0.682195
# 1  	40    	0.692396	0.00181963 	0.695315   	0.68755
# 2  	40    	0.693842	0.00169226 	0.695315   	0.689424
# 3  	40    	0.695315	0          	0.695315   	0.695315
# 4  	40    	0.695315	0          	0.695315   	0.695315
#     Accuracy: 0.6905
#     Best Params: {'n_neighbors': 14, 'weights': 'distance', 'p': 1}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.63      0.50      0.56       956
#      depresi       0.65      0.86      0.74      1456
#        stres       0.80      0.63      0.71      1323
#
#     accuracy                           0.69      3735
#    macro avg       0.70      0.67      0.67      3735
# weighted avg       0.70      0.69      0.68      3735
#
# Training Random Forest with GASearchCV and Cross Validation (k=5)
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.700281	0.00383012 	0.706024   	0.689692
# 1  	40    	0.703079	0.00230938 	0.708166   	0.699866
# 2  	40    	0.704913	0.00203071 	0.708166   	0.701473
# 3  	40    	0.705515	0.00120601 	0.707363   	0.703079
# 4  	40    	0.705341	0.00212759 	0.71004    	0.702811
#     Accuracy: 0.7106
#     Best Params: {'n_estimators': 88, 'max_depth': 20}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.69      0.51      0.59       956
#      depresi       0.69      0.83      0.75      1456
#        stres       0.75      0.72      0.73      1323
#
#     accuracy                           0.71      3735
#    macro avg       0.71      0.69      0.69      3735
# weighted avg       0.71      0.71      0.70      3735
#
# Training Neural Network with GASearchCV and Cross Validation (k=5)
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.715422	0.00666871 	0.723963   	0.702008
# 1  	40    	0.72158 	0.0037444  	0.72664    	0.71245
# 2  	40    	0.724578	0.0054385  	0.73494    	0.715663
# 3  	40    	0.726198	0.00448592 	0.73494    	0.71834
# 4  	40    	0.725462	0.0037981  	0.73494    	0.719411
#     Accuracy: 0.7197
#     Best Params: {'hidden_layer_sizes': (100, 50), 'learning_rate_init': 0.0026711522033449754, 'learning_rate': 'adaptive', 'early_stopping': True}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.63      0.64      0.64       956
#      depresi       0.74      0.77      0.75      1456
#        stres       0.77      0.72      0.74      1323
#
#     accuracy                           0.72      3735
#    macro avg       0.71      0.71      0.71      3735
# weighted avg       0.72      0.72      0.72      3735
#
# Training Naive Bayes with GASearchCV and Cross Validation (k=10)
# gen	nevals	fitness	fitness_std	fitness_max	fitness_min
# 0  	20    	0.67577	1.11022e-16	0.67577    	0.67577
# 1  	40    	0.67577	1.11022e-16	0.67577    	0.67577
# 2  	40    	0.67577	1.11022e-16	0.67577    	0.67577
# 3  	40    	0.67577	1.11022e-16	0.67577    	0.67577
# 4  	40    	0.67577	1.11022e-16	0.67577    	0.67577
#     Accuracy: 0.6736
#     Best Params: {'var_smoothing': 4.76168391063837e-08}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.62      0.49      0.55       956
#      depresi       0.65      0.81      0.72      1456
#        stres       0.74      0.66      0.70      1323
#
#     accuracy                           0.67      3735
#    macro avg       0.67      0.65      0.66      3735
# weighted avg       0.68      0.67      0.67      3735
#
# Training KNN with GASearchCV and Cross Validation (k=10)
# gen	nevals	fitness	fitness_std	fitness_max	fitness_min
# 0  	20    	0.69008	0.00244724 	0.695315   	0.687015
# 1  	40    	0.691888	0.00117194 	0.693708   	0.688353
# 2  	40    	0.692544	0.000575947	0.693708   	0.691834
# 3  	40    	0.692811	0.000543942	0.693708   	0.691834
# 4  	40    	0.692959	0.000906362	0.693708   	0.689692
#     Accuracy: 0.6932
#     Best Params: {'n_neighbors': 14, 'weights': 'distance', 'p': 1}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.64      0.51      0.57       956
#      depresi       0.66      0.86      0.75      1456
#        stres       0.79      0.64      0.71      1323
#
#     accuracy                           0.69      3735
#    macro avg       0.70      0.67      0.67      3735
# weighted avg       0.70      0.69      0.69      3735
#
# Training Random Forest with GASearchCV and Cross Validation (k=10)
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.701539	0.00391746 	0.708701   	0.694244
# 1  	40    	0.704311	0.00330675 	0.708701   	0.695315
# 2  	40    	0.705448	0.00214737 	0.708701   	0.701473
# 3  	40    	0.705395	0.00322429 	0.709505   	0.697189
# 4  	40    	0.705863	0.00279449 	0.709505   	0.700402
#     Accuracy: 0.7141
#     Best Params: {'n_estimators': 82, 'max_depth': 17}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.69      0.51      0.59       956
#      depresi       0.69      0.84      0.76      1456
#        stres       0.76      0.72      0.74      1323
#
#     accuracy                           0.71      3735
#    macro avg       0.71      0.69      0.70      3735
# weighted avg       0.72      0.71      0.71      3735
#
# Training Neural Network with GASearchCV and Cross Validation (k=10)
# gen	nevals	fitness 	fitness_std	fitness_max	fitness_min
# 0  	20    	0.718394	0.0060869  	0.726104   	0.701205
# 1  	40    	0.722088	0.00312463 	0.726104   	0.717269
# 2  	40    	0.721874	0.00261863 	0.726104   	0.713788
# 3  	40    	0.723266	0.00279578 	0.728782   	0.716466
# 4  	40    	0.724672	0.00219524 	0.728782   	0.719411
#     Accuracy: 0.7237
#     Best Params: {'hidden_layer_sizes': (100, 50), 'learning_rate_init': 0.0017930224068912438, 'learning_rate': 'adaptive', 'early_stopping': True}
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.65      0.63      0.64       956
#      depresi       0.74      0.79      0.76      1456
#        stres       0.76      0.72      0.74      1323
#
#     accuracy                           0.72      3735
#    macro avg       0.72      0.71      0.71      3735
# weighted avg       0.72      0.72      0.72      3735

# %% [markdown]
# ## Menampilkan hasil model

# %%
import json

# Membaca file JSON
with open(path + f'{nama_ekstraksi}_ga_cv_experiment_results.json', 'r') as f:
    results = json.load(f)

# %% [markdown]
# ### Confusion Matrix (heatmap)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Known labels
labels = ["cemas", "depresi", "stres"]

# Set the figure size
plt.rcParams['figure.figsize'] = [20, 25]

# Create subplots for each confusion matrix
for i, (key, value) in enumerate(results.items()):
    cm = np.array(value['confusion_matrix'])
    plt.subplot(6, 4, i+1)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=labels, yticklabels=labels)
    plt.title(key)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.axis("on")

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Evaluasi kinerja model

# %%
# Inisialisasi list untuk menyimpan data
data = []

# Ekstrak split dan model dari keys di results
for key, value in results.items():
    model_name, split_info = key.split(f'_k')
    split_ratio = split_info.replace('cross_val_', '')
    accuracy = value['accuracy']

    # Tambahkan data ke dalam list
    data.append([split_ratio, model_name, accuracy])

# Konversi list ke DataFrame
accuracy_table = pd.DataFrame(data, columns=['Split', 'Model', 'Accuracy'])

# Pivot DataFrame agar model menjadi kolom
accuracy_table = accuracy_table.pivot(index='Split', columns='Model', values='Accuracy')

# Rename columns to remove the extra text
accuracy_table.columns = accuracy_table.columns.str.replace('_GA optimization_cross_val', '')

# Atur ulang kolom sesuai urutan yang diinginkan
accuracy_table = accuracy_table[['Naive Bayes', 'KNN', 'Random Forest', 'Neural Network']]

# Tampilkan tabel akurasi
accuracy_table
# Out:
# Model  Naive Bayes       KNN  Random Forest  Neural Network
# Split
# 10        0.673628  0.693173       0.714056        0.723695
# 5         0.672825  0.690495       0.710576        0.719679

# %%
print(accuracy_table.columns)
# Out:
# Index(['Naive Bayes', 'KNN', 'Random Forest', 'Neural Network'], dtype='object', name='Model')

# %%
# Initialize an empty list to store data for the DataFrame
data = []

# Extracting data for each model and split
for experiment_name, result in results.items():
    for label, metrics in result['classification_report'].items():
        if label not in ['accuracy', 'macro avg', 'weighted avg']:  # Skip overall metrics
            row = {
                'Experiment': experiment_name,
                'Label': label,
                'Precision': metrics['precision'],
                'Recall': metrics['recall'],
                'F1-Score': metrics['f1-score'],
                'Support': metrics['support']
            }
            data.append(row)

# Create DataFrame from the data list
df_results = pd.DataFrame(data)

# Display the first few rows of the DataFrame
df_results
# Out:
#                                       Experiment    Label  Precision  \
# 0       Naive Bayes_GA optimization_cross_val_k5    cemas   0.620053
# 1       Naive Bayes_GA optimization_cross_val_k5  depresi   0.649972
# 2       Naive Bayes_GA optimization_cross_val_k5    stres   0.743103
# 3               KNN_GA optimization_cross_val_k5    cemas   0.634565
# 4               KNN_GA optimization_cross_val_k5  depresi   0.652828
# 5               KNN_GA optimization_cross_val_k5    stres   0.800000
# 6     Random Forest_GA optimization_cross_val_k5    cemas   0.690141
# 7     Random Forest_GA optimization_cross_val_k5  depresi   0.689166
# 8     Random Forest_GA optimization_cross_val_k5    stres   0.751981
# 9    Neural Network_GA optimization_cross_val_k5    cemas   0.634375
# 10   Neural Network_GA optimization_cross_val_k5  depresi   0.735467
# 11   Neural Network_GA optimization_cross_val_k5    stres   0.766077
# 12     Naive Bayes_GA optimization_cross_val_k10    cemas   0.622163
# 13     Naive Bayes_GA optimization_cross_val_k10  depresi   0.649286
# 14     Naive Bayes_GA optimization_cross_val_k10    stres   0.744845
# 15             KNN_GA optimization_cross_val_k10    cemas   0.642480
# 16             KNN_GA optimization_cross_val_k10  depresi   0.657233
# 17             KNN_GA optimization_cross_val_k10    stres   0.793265
# 18   Random Forest_GA optimization_cross_val_k10    cemas   0.692958
# 19   Random Forest_GA optimization_cross_val_k10  depresi   0.692833
# 20   Random Forest_GA optimization_cross_val_k10    stres   0.755328
# 21  Neural Network_GA optimization_cross_val_k10    cemas   0.648128
# 22  Neural Network_GA optimization_cross_val_k10  depresi   0.740285
# 23  Neural Network_GA optimization_cross_val_k10    stres   0.759554
#
#       Recall  F1-Score  Support
# 0   0.491632  0.548425    956.0
# 1   0.811126  0.721662   1456.0
# 2   0.651550  0.694321   1323.0
# 3   0.503138  0.561260    956.0
# 4   0.864011  0.743719   1456.0
# 5   0.634921  0.707965   1323.0
# 6   0.512552  0.588235    956.0
# 7   0.834478  0.754893   1456.0
# 8   0.717309  0.734236   1323.0
# 9   0.637029  0.635699    956.0
# 10  0.773352  0.753934   1456.0
# 11  0.720333  0.742501   1323.0
# 12  0.487448  0.546628    956.0
# 13  0.812500  0.721782   1456.0
# 14  0.655329  0.697226   1323.0
# 15  0.509414  0.568261    956.0
# 16  0.861264  0.745541   1456.0
# 17  0.640967  0.709030   1323.0
# 18  0.514644  0.590636    956.0
# 19  0.836538  0.757934   1456.0
# 20  0.723356  0.738996   1323.0
# 21  0.633891  0.640931    956.0
# 22  0.785027  0.762000   1456.0
# 23  0.721088  0.739822   1323.0

# %% [markdown]
# # Basic Split Validation Modelling (tanpa optimasi)

# %%
# Define models
models = {
    'Naive Bayes': GaussianNB(),
    'KNN': KNeighborsClassifier(),
    'Random Forest': RandomForestClassifier(),
    'Neural Network': MLPClassifier()
}

# Define split ratios
splits = [(0.6, 0.4), (0.7, 0.3), (0.8, 0.2), (0.9, 0.1)]

# Initialize results dictionary
results = {}

for train_size, test_size in splits:
    print(f'Processing split {int(train_size*100)}:{int(test_size*100)}')

    # Split data
    X_train, X_test, y_train, y_test = train_test_split(fitur, y, test_size=test_size, random_state=42)

    for model_name, model in models.items():
        print(f'  Training {model_name} (basic model)')

        # Train the model directly
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)

        # Evaluation
        conf_matrix = confusion_matrix(y_test, y_pred)
        class_report = classification_report(y_test, y_pred, output_dict=True, zero_division=0)
        accuracy = accuracy_score(y_test, y_pred)

        # Convert tuple key to string
        result_key = f"{model_name}_basic_split {int(train_size*100)}:{int(test_size*100)}"

        # Save results
        results[result_key] = {
            'confusion_matrix': conf_matrix.tolist(),
            'classification_report': class_report,
            'accuracy': accuracy
        }

        print(f'    Accuracy: {accuracy:.4f}')
        print('    Classification Report:')
        print(classification_report(y_test, y_pred, zero_division=0))

# Save results to a JSON file
with open(path + f'{nama_ekstraksi}_basic_sv_experiment_results.json', 'w') as f:
    json.dump(results, f, indent=4)
# Out:
# Processing split 60:40
#   Training Naive Bayes (basic model)
#     Accuracy: 0.6647
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.65      0.47      0.55       397
#      depresi       0.64      0.81      0.71       591
#        stres       0.72      0.65      0.68       506
#
#     accuracy                           0.66      1494
#    macro avg       0.67      0.64      0.65      1494
# weighted avg       0.67      0.66      0.66      1494
#
#   Training KNN (basic model)
#     Accuracy: 0.6680
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.58      0.56      0.57       397
#      depresi       0.65      0.80      0.72       591
#        stres       0.78      0.60      0.68       506
#
#     accuracy                           0.67      1494
#    macro avg       0.67      0.65      0.66      1494
# weighted avg       0.68      0.67      0.67      1494
#
#   Training Random Forest (basic model)
#     Accuracy: 0.6954
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.69      0.51      0.59       397
#      depresi       0.68      0.81      0.74       591
#        stres       0.72      0.71      0.71       506
#
#     accuracy                           0.70      1494
#    macro avg       0.70      0.68      0.68      1494
# weighted avg       0.70      0.70      0.69      1494
#
#   Training Neural Network (basic model)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
#     Accuracy: 0.7303
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.68      0.63      0.65       397
#      depresi       0.74      0.80      0.77       591
#        stres       0.76      0.73      0.74       506
#
#     accuracy                           0.73      1494
#    macro avg       0.72      0.72      0.72      1494
# weighted avg       0.73      0.73      0.73      1494
#
# Processing split 70:30
#   Training Naive Bayes (basic model)
#     Accuracy: 0.6619
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.65      0.47      0.55       304
#      depresi       0.63      0.79      0.70       439
#        stres       0.71      0.66      0.69       378
#
#     accuracy                           0.66      1121
#    macro avg       0.67      0.64      0.65      1121
# weighted avg       0.67      0.66      0.66      1121
#
#   Training KNN (basic model)
#     Accuracy: 0.6548
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.57      0.55      0.56       304
#      depresi       0.64      0.78      0.70       439
#        stres       0.77      0.60      0.67       378
#
#     accuracy                           0.65      1121
#    macro avg       0.66      0.64      0.64      1121
# weighted avg       0.66      0.65      0.65      1121
#
#   Training Random Forest (basic model)
#     Accuracy: 0.7047
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.72      0.52      0.60       304
#      depresi       0.68      0.80      0.74       439
#        stres       0.73      0.74      0.74       378
#
#     accuracy                           0.70      1121
#    macro avg       0.71      0.69      0.69      1121
# weighted avg       0.71      0.70      0.70      1121
#
#   Training Neural Network (basic model)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
#     Accuracy: 0.7270
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.72      0.58      0.64       304
#      depresi       0.71      0.81      0.76       439
#        stres       0.75      0.75      0.75       378
#
#     accuracy                           0.73      1121
#    macro avg       0.73      0.71      0.72      1121
# weighted avg       0.73      0.73      0.72      1121
#
# Processing split 80:20
#   Training Naive Bayes (basic model)
#     Accuracy: 0.6506
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.67      0.45      0.53       202
#      depresi       0.61      0.79      0.69       286
#        stres       0.70      0.65      0.67       259
#
#     accuracy                           0.65       747
#    macro avg       0.66      0.63      0.63       747
# weighted avg       0.66      0.65      0.64       747
#
#   Training KNN (basic model)
#     Accuracy: 0.6493
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.56      0.56      0.56       202
#      depresi       0.63      0.78      0.70       286
#        stres       0.77      0.57      0.66       259
#
#     accuracy                           0.65       747
#    macro avg       0.66      0.64      0.64       747
# weighted avg       0.66      0.65      0.65       747
#
#   Training Random Forest (basic model)
#     Accuracy: 0.7055
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.69      0.53      0.60       202
#      depresi       0.68      0.82      0.74       286
#        stres       0.75      0.71      0.73       259
#
#     accuracy                           0.71       747
#    macro avg       0.71      0.69      0.69       747
# weighted avg       0.71      0.71      0.70       747
#
#   Training Neural Network (basic model)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
#     Accuracy: 0.7028
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.68      0.55      0.61       202
#      depresi       0.67      0.82      0.74       286
#        stres       0.76      0.69      0.73       259
#
#     accuracy                           0.70       747
#    macro avg       0.71      0.69      0.69       747
# weighted avg       0.71      0.70      0.70       747
#
# Processing split 90:10
#   Training Naive Bayes (basic model)
#     Accuracy: 0.6471
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.71      0.45      0.55       110
#      depresi       0.58      0.82      0.68       131
#        stres       0.72      0.65      0.68       133
#
#     accuracy                           0.65       374
#    macro avg       0.67      0.64      0.64       374
# weighted avg       0.67      0.65      0.64       374
#
#   Training KNN (basic model)
#     Accuracy: 0.6497
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.59      0.61      0.60       110
#      depresi       0.60      0.79      0.68       131
#        stres       0.83      0.54      0.65       133
#
#     accuracy                           0.65       374
#    macro avg       0.67      0.65      0.65       374
# weighted avg       0.68      0.65      0.65       374
#
#   Training Random Forest (basic model)
#     Accuracy: 0.7032
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.74      0.52      0.61       110
#      depresi       0.64      0.87      0.74       131
#        stres       0.77      0.69      0.73       133
#
#     accuracy                           0.70       374
#    macro avg       0.72      0.69      0.69       374
# weighted avg       0.72      0.70      0.70       374
#
#   Training Neural Network (basic model)
#     Accuracy: 0.7112
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.67      0.63      0.65       110
#      depresi       0.66      0.82      0.73       131
#        stres       0.83      0.68      0.75       133
#
#     accuracy                           0.71       374
#    macro avg       0.72      0.71      0.71       374
# weighted avg       0.72      0.71      0.71       374
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# ## Menampilkan hasil model

# %%
import json

# Membaca file JSON
with open(path + f'{nama_ekstraksi}_basic_sv_experiment_results.json', 'r') as f:
    results = json.load(f)

# %% [markdown]
# ### Confusion Matrix (heatmap)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Known labels
labels = ["cemas", "depresi", "stres"]

# Set the figure size
plt.rcParams['figure.figsize'] = [20, 25]

# Create subplots for each confusion matrix
for i, (key, value) in enumerate(results.items()):
    cm = np.array(value['confusion_matrix'])
    plt.subplot(6, 4, i+1)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=labels, yticklabels=labels)
    plt.title(key)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.axis("on")

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Evaluasi kinerja model

# %%
# Inisialisasi list untuk menyimpan data
data = []

# Ekstrak split dan model dari keys di results
for key, value in results.items():
    model_name, split_info = key.split(f'_basic_split')
    split_ratio = split_info.replace('_test', ':')
    accuracy = value['accuracy']

    # Tambahkan data ke dalam list
    data.append([split_ratio, model_name, accuracy])

# Konversi list ke DataFrame
accuracy_table = pd.DataFrame(data, columns=['Split', 'Model', 'Accuracy'])

# Pivot DataFrame agar model menjadi kolom
accuracy_table = accuracy_table.pivot(index='Split', columns='Model', values='Accuracy')

# Atur ulang kolom sesuai urutan yang diinginkan
accuracy_table = accuracy_table[['Naive Bayes', 'KNN', 'Random Forest', 'Neural Network']]

# Tampilkan tabel akurasi
accuracy_table
# Out:
# Model  Naive Bayes       KNN  Random Forest  Neural Network
# Split
# 60:40     0.664659  0.668005       0.695448        0.730254
# 70:30     0.661909  0.654773       0.704728        0.727029
# 80:20     0.650602  0.649264       0.705489        0.702811
# 90:10     0.647059  0.649733       0.703209        0.711230

# %%
# Initialize an empty list to store data for the DataFrame
data = []

# Extracting data for each model and split
for experiment_name, result in results.items():
    for label, metrics in result['classification_report'].items():
        if label not in ['accuracy', 'macro avg', 'weighted avg']:  # Skip overall metrics
            row = {
                'Experiment': experiment_name,
                'Label': label,
                'Precision': metrics['precision'],
                'Recall': metrics['recall'],
                'F1-Score': metrics['f1-score'],
                'Support': metrics['support']
            }
            data.append(row)

# Create DataFrame from the data list
df_results = pd.DataFrame(data)

# Display the first few rows of the DataFrame
df_results
# Out:
#                           Experiment    Label  Precision    Recall  F1-Score  \
# 0      Naive Bayes_basic_split 60:40    cemas   0.652632  0.468514  0.545455
# 1      Naive Bayes_basic_split 60:40  depresi   0.635279  0.810491  0.712268
# 2      Naive Bayes_basic_split 60:40    stres   0.720879  0.648221  0.682622
# 3              KNN_basic_split 60:40    cemas   0.583113  0.556675  0.569588
# 4              KNN_basic_split 60:40  depresi   0.651934  0.798646  0.717871
# 5              KNN_basic_split 60:40    stres   0.780051  0.602767  0.680045
# 6    Random Forest_basic_split 60:40    cemas   0.689420  0.508816  0.585507
# 7    Random Forest_basic_split 60:40  depresi   0.677966  0.812183  0.739030
# 8    Random Forest_basic_split 60:40    stres   0.724138  0.705534  0.714715
# 9   Neural Network_basic_split 60:40    cemas   0.676550  0.632242  0.653646
# 10  Neural Network_basic_split 60:40  depresi   0.742496  0.795262  0.767974
# 11  Neural Network_basic_split 60:40    stres   0.755102  0.731225  0.742972
# 12     Naive Bayes_basic_split 70:30    cemas   0.652968  0.470395  0.546845
# 13     Naive Bayes_basic_split 70:30  depresi   0.632727  0.792711  0.703741
# 14     Naive Bayes_basic_split 70:30    stres   0.713068  0.664021  0.687671
# 15             KNN_basic_split 70:30    cemas   0.569966  0.549342  0.559464
# 16             KNN_basic_split 70:30  depresi   0.636872  0.779043  0.700820
# 17             KNN_basic_split 70:30    stres   0.773196  0.595238  0.672646
# 18   Random Forest_basic_split 70:30    cemas   0.716216  0.523026  0.604563
# 19   Random Forest_basic_split 70:30  depresi   0.679537  0.801822  0.735632
# 20   Random Forest_basic_split 70:30    stres   0.732283  0.738095  0.735178
# 21  Neural Network_basic_split 70:30    cemas   0.718367  0.578947  0.641166
# 22  Neural Network_basic_split 70:30  depresi   0.711155  0.813212  0.758767
# 23  Neural Network_basic_split 70:30    stres   0.754011  0.746032  0.750000
# 24     Naive Bayes_basic_split 80:20    cemas   0.666667  0.445545  0.534125
# 25     Naive Bayes_basic_split 80:20  depresi   0.613514  0.793706  0.692073
# 26     Naive Bayes_basic_split 80:20    stres   0.698347  0.652510  0.674651
# 27             KNN_basic_split 80:20    cemas   0.556650  0.559406  0.558025
# 28             KNN_basic_split 80:20  depresi   0.634561  0.783217  0.701095
# 29             KNN_basic_split 80:20    stres   0.774869  0.571429  0.657778
# 30   Random Forest_basic_split 80:20    cemas   0.692308  0.534653  0.603352
# 31   Random Forest_basic_split 80:20  depresi   0.677233  0.821678  0.742496
# 32   Random Forest_basic_split 80:20    stres   0.754098  0.710425  0.731610
# 33  Neural Network_basic_split 80:20    cemas   0.682927  0.554455  0.612022
# 34  Neural Network_basic_split 80:20  depresi   0.670487  0.818182  0.737008
# 35  Neural Network_basic_split 80:20    stres   0.764957  0.691120  0.726166
# 36     Naive Bayes_basic_split 90:10    cemas   0.710145  0.445455  0.547486
# 37     Naive Bayes_basic_split 90:10  depresi   0.575269  0.816794  0.675079
# 38     Naive Bayes_basic_split 90:10    stres   0.722689  0.646617  0.682540
# 39             KNN_basic_split 90:10    cemas   0.587719  0.609091  0.598214
# 40             KNN_basic_split 90:10  depresi   0.601156  0.793893  0.684211
# 41             KNN_basic_split 90:10    stres   0.827586  0.541353  0.654545
# 42   Random Forest_basic_split 90:10    cemas   0.740260  0.518182  0.609626
# 43   Random Forest_basic_split 90:10  depresi   0.640449  0.870229  0.737864
# 44   Random Forest_basic_split 90:10    stres   0.773109  0.691729  0.730159
# 45  Neural Network_basic_split 90:10    cemas   0.669903  0.627273  0.647887
# 46  Neural Network_basic_split 90:10  depresi   0.656442  0.816794  0.727891
# 47  Neural Network_basic_split 90:10    stres   0.833333  0.676692  0.746888
#
#     Support
# 0     397.0
# 1     591.0
# 2     506.0
# 3     397.0
# 4     591.0
# 5     506.0
# 6     397.0
# 7     591.0
# 8     506.0
# 9     397.0
# 10    591.0
# 11    506.0
# 12    304.0
# 13    439.0
# 14    378.0
# 15    304.0
# 16    439.0
# 17    378.0
# 18    304.0
# 19    439.0
# 20    378.0
# 21    304.0
# 22    439.0
# 23    378.0
# 24    202.0
# 25    286.0
# 26    259.0
# 27    202.0
# 28    286.0
# 29    259.0
# 30    202.0
# 31    286.0
# 32    259.0
# 33    202.0
# 34    286.0
# 35    259.0
# 36    110.0
# 37    131.0
# 38    133.0
# 39    110.0
# 40    131.0
# 41    133.0
# 42    110.0
# 43    131.0
# 44    133.0
# 45    110.0
# 46    131.0
# 47    133.0

# %% [markdown]
# # Basic Cross Validation Modelling (tanpa optimasi)

# %%
# Define models
models = {
    'Naive Bayes': GaussianNB(),
    'KNN': KNeighborsClassifier(),
    'Random Forest': RandomForestClassifier(),
    'Neural Network': MLPClassifier()
}

# Define cross-validation folds
kf_values = [5, 10]

# Initialize results dictionary
results = {}

for k in kf_values:
    print(f'Processing cross-validation with k={k}')

    for model_name, model in models.items():
        print(f'  Training {model_name} (basic model)')

        # Cross-validation predictions
        y_pred = cross_val_predict(model, fitur, y, cv=k)

        # Evaluation
        conf_matrix = confusion_matrix(y, y_pred)
        class_report = classification_report(y, y_pred, output_dict=True, zero_division=0)
        accuracy = accuracy_score(y, y_pred)

        # Convert key to string, similar to the split validation
        result_key = f"{model_name}_basic_cross_val_k{k}"

        # Save results in the format similar to split validation
        results[result_key] = {
            'confusion_matrix': conf_matrix.tolist(),
            'classification_report': class_report,
            'accuracy': accuracy
        }

        print(f'    Accuracy: {accuracy:.4f}')
        print('    Classification Report:')
        print(classification_report(y, y_pred, zero_division=0))

# Save results to a JSON file
with open(path + f'{nama_ekstraksi}_basic_cv_experiment_results.json', 'w') as f:
    json.dump(results, f, indent=4)
# Out:
# Processing cross-validation with k=5
#   Training Naive Bayes (basic model)
#     Accuracy: 0.6728
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.62      0.49      0.55       956
#      depresi       0.65      0.81      0.72      1456
#        stres       0.74      0.65      0.69      1323
#
#     accuracy                           0.67      3735
#    macro avg       0.67      0.65      0.65      3735
# weighted avg       0.68      0.67      0.67      3735
#
#   Training KNN (basic model)
#     Accuracy: 0.6776
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.58      0.56      0.57       956
#      depresi       0.67      0.81      0.73      1456
#        stres       0.79      0.61      0.69      1323
#
#     accuracy                           0.68      3735
#    macro avg       0.68      0.66      0.66      3735
# weighted avg       0.69      0.68      0.68      3735
#
#   Training Random Forest (basic model)
#     Accuracy: 0.7074
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.68      0.51      0.58       956
#      depresi       0.68      0.83      0.75      1456
#        stres       0.76      0.71      0.73      1323
#
#     accuracy                           0.71      3735
#    macro avg       0.71      0.68      0.69      3735
# weighted avg       0.71      0.71      0.70      3735
#
#   Training Neural Network (basic model)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
#     Accuracy: 0.7363
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.68      0.63      0.66       956
#      depresi       0.73      0.83      0.78      1456
#        stres       0.78      0.71      0.75      1323
#
#     accuracy                           0.74      3735
#    macro avg       0.73      0.72      0.73      3735
# weighted avg       0.74      0.74      0.73      3735
#
# Processing cross-validation with k=10
#   Training Naive Bayes (basic model)
#     Accuracy: 0.6736
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.62      0.49      0.55       956
#      depresi       0.65      0.81      0.72      1456
#        stres       0.74      0.66      0.70      1323
#
#     accuracy                           0.67      3735
#    macro avg       0.67      0.65      0.66      3735
# weighted avg       0.68      0.67      0.67      3735
#
#   Training KNN (basic model)
#     Accuracy: 0.6793
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.58      0.57      0.57       956
#      depresi       0.67      0.81      0.74      1456
#        stres       0.78      0.61      0.69      1323
#
#     accuracy                           0.68      3735
#    macro avg       0.68      0.66      0.67      3735
# weighted avg       0.69      0.68      0.68      3735
#
#   Training Random Forest (basic model)
#     Accuracy: 0.7084
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.68      0.51      0.58       956
#      depresi       0.69      0.83      0.75      1456
#        stres       0.75      0.72      0.74      1323
#
#     accuracy                           0.71      3735
#    macro avg       0.71      0.69      0.69      3735
# weighted avg       0.71      0.71      0.70      3735
#
#   Training Neural Network (basic model)
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
#     Accuracy: 0.7288
#     Classification Report:
#               precision    recall  f1-score   support
#
#        cemas       0.69      0.61      0.64       956
#      depresi       0.72      0.81      0.77      1456
#        stres       0.76      0.73      0.74      1323
#
#     accuracy                           0.73      3735
#    macro avg       0.72      0.71      0.72      3735
# weighted avg       0.73      0.73      0.73      3735

# %% [markdown]
# ## Menampilkan hasil model

# %%
import json

# Membaca file JSON
with open(path + f'{nama_ekstraksi}_basic_cv_experiment_results.json', 'r') as f:
    results = json.load(f)

# %% [markdown]
# ### Confusion Matrix (heatmap)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Known labels
labels = ["cemas", "depresi", "stres"]

# Set the figure size
plt.rcParams['figure.figsize'] = [20, 25]

# Create subplots for each confusion matrix
for i, (key, value) in enumerate(results.items()):
    # if i >= 20:  # Limit to 20 subplots (5 rows x 4 columns)
    #     break
    cm = np.array(value['confusion_matrix'])
    plt.subplot(6, 4, i+1)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=labels, yticklabels=labels)
    plt.title(key)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.axis("on")

# Show the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Evaluasi kinerja model

# %%
# Inisialisasi list untuk menyimpan data
data = []

# Ekstrak split dan model dari keys di results
for key, value in results.items():
    model_name, split_info = key.split(f'_k')
    split_ratio = split_info.replace('cross_val_', '')
    accuracy = value['accuracy']

    # Tambahkan data ke dalam list
    data.append([split_ratio, model_name, accuracy])

# Konversi list ke DataFrame
accuracy_table = pd.DataFrame(data, columns=['K-Fold', 'Model', 'Accuracy'])

# Pivot DataFrame agar model menjadi kolom
accuracy_table = accuracy_table.pivot(index='K-Fold', columns='Model', values='Accuracy')

# Rename columns to remove the extra text
accuracy_table.columns = accuracy_table.columns.str.replace('_basic_cross_val', '')

# Atur ulang kolom sesuai urutan yang diinginkan
accuracy_table = accuracy_table[['Naive Bayes', 'KNN', 'Random Forest', 'Neural Network']]

# Tampilkan tabel akurasi
accuracy_table
# Out:
# Model   Naive Bayes       KNN  Random Forest  Neural Network
# K-Fold
# 10         0.673628  0.679250       0.708434        0.728782
# 5          0.672825  0.677644       0.707363        0.736278

# %%
# Initialize an empty list to store data for the DataFrame
data = []

# Extracting data for each model and split
for experiment_name, result in results.items():
    for label, metrics in result['classification_report'].items():
        if label not in ['accuracy', 'macro avg', 'weighted avg']:  # Skip overall metrics
            row = {
                'Experiment': experiment_name,
                'Label': label,
                'Precision': metrics['precision'],
                'Recall': metrics['recall'],
                'F1-Score': metrics['f1-score'],
                'Support': metrics['support']
            }
            data.append(row)

# Create DataFrame from the data list
df_results = pd.DataFrame(data)

# Display the first few rows of the DataFrame
df_results
# Out:
#                             Experiment    Label  Precision    Recall  \
# 0       Naive Bayes_basic_cross_val_k5    cemas   0.620053  0.491632
# 1       Naive Bayes_basic_cross_val_k5  depresi   0.649972  0.811126
# 2       Naive Bayes_basic_cross_val_k5    stres   0.743103  0.651550
# 3               KNN_basic_cross_val_k5    cemas   0.575269  0.559623
# 4               KNN_basic_cross_val_k5  depresi   0.667795  0.813187
# 5               KNN_basic_cross_val_k5    stres   0.786822  0.613757
# 6     Random Forest_basic_cross_val_k5    cemas   0.676389  0.509414
# 7     Random Forest_basic_cross_val_k5  depresi   0.684715  0.833791
# 8     Random Forest_basic_cross_val_k5    stres   0.757649  0.711262
# 9    Neural Network_basic_cross_val_k5    cemas   0.684091  0.629707
# 10   Neural Network_basic_cross_val_k5  depresi   0.729305  0.828984
# 11   Neural Network_basic_cross_val_k5    stres   0.784167  0.711262
# 12     Naive Bayes_basic_cross_val_k10    cemas   0.622163  0.487448
# 13     Naive Bayes_basic_cross_val_k10  depresi   0.649286  0.812500
# 14     Naive Bayes_basic_cross_val_k10    stres   0.744845  0.655329
# 15             KNN_basic_cross_val_k10    cemas   0.577004  0.572176
# 16             KNN_basic_cross_val_k10  depresi   0.672738  0.811813
# 17             KNN_basic_cross_val_k10    stres   0.784466  0.610733
# 18   Random Forest_basic_cross_val_k10    cemas   0.677285  0.511506
# 19   Random Forest_basic_cross_val_k10  depresi   0.689359  0.827610
# 20   Random Forest_basic_cross_val_k10    stres   0.752569  0.719577
# 21  Neural Network_basic_cross_val_k10    cemas   0.686833  0.605649
# 22  Neural Network_basic_cross_val_k10  depresi   0.724816  0.810440
# 23  Neural Network_basic_cross_val_k10    stres   0.761867  0.727891
#
#     F1-Score  Support
# 0   0.548425    956.0
# 1   0.721662   1456.0
# 2   0.694321   1323.0
# 3   0.567338    956.0
# 4   0.733354   1456.0
# 5   0.689597   1323.0
# 6   0.581146    956.0
# 7   0.751936   1456.0
# 8   0.733723   1323.0
# 9   0.655773    956.0
# 10  0.775956   1456.0
# 11  0.745937   1323.0
# 12  0.546628    956.0
# 13  0.721782   1456.0
# 14  0.697226   1323.0
# 15  0.574580    956.0
# 16  0.735761   1456.0
# 17  0.686783   1323.0
# 18  0.582837    956.0
# 19  0.752185   1456.0
# 20  0.735703   1323.0
# 21  0.643691    956.0
# 22  0.765240   1456.0
# 23  0.744492   1323.0
